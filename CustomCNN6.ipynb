# %%
"""
Fragment 1 — Data Loading
==========================
Custom CNN Mould/Fruit Multiclass Classification Pipeline

- Loads train data from shared augmented folder
- Loads validation data from val folder
- Test data not loaded here
- No augmentation performed — augmented folder already exists
- Uses simple rescale normalisation — custom CNN has no
  pretrained preprocessing requirements
"""

import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ── Configuration ─────────────────────────────────────────────────────────────

DATA_DIR   = r"D:\Mold Studies\Mould Studies Multiclass"
AUG_DIR    = os.path.join(DATA_DIR, "augmented")   # shared augmented folder
VALID_DIR  = os.path.join(DATA_DIR, "val")

IMG_SIZE   = (224, 224)
BATCH_SIZE = 32

# ── Safety Guards ─────────────────────────────────────────────────────────────

assert os.path.exists(AUG_DIR), \
    f"Augmented folder not found: {AUG_DIR}"
assert os.path.exists(VALID_DIR), \
    f"Validation folder not found: {VALID_DIR}"

# ── Step 1: Build Generators ──────────────────────────────────────────────────

def build_generators(aug_dir: str, valid_dir: str):
    """
    Builds train generator from shared augmented folder.
    Builds validation generator from val folder.
    Custom CNN has no pretrained preprocessing so simple
    rescale to [0, 1] is applied — standard for training
    from scratch.
    Test data is not loaded here.
    """

    train_datagen   = ImageDataGenerator(rescale=1.0 / 255)
    train_generator = train_datagen.flow_from_directory(
        aug_dir,
        target_size = IMG_SIZE,
        batch_size  = BATCH_SIZE,
        class_mode  = "categorical",
        shuffle     = True,
    )

    valid_datagen   = ImageDataGenerator(rescale=1.0 / 255)
    valid_generator = valid_datagen.flow_from_directory(
        valid_dir,
        target_size = IMG_SIZE,
        batch_size  = BATCH_SIZE,
        class_mode  = "categorical",
        shuffle     = False,
    )

    return train_generator, valid_generator

# ── Step 2: Run and Summarise ─────────────────────────────────────────────────

train_generator, valid_generator = build_generators(AUG_DIR, VALID_DIR)

CLASS_NAMES = list(train_generator.class_indices.keys())
NUM_CLASSES = len(CLASS_NAMES)

print("=" * 60)
print("  Fragment 1 — Data Generators Ready")
print("=" * 60)
print(f"  Architecture  : Custom CNN (6 layers)")
print(f"  Train source  : augmented/   (shared, no new aug)")
print(f"  Valid source  : val/")
print(f"  Test source   : not loaded here")
print(f"  Preprocessing : rescale 1/255")
print(f"  Train samples : {train_generator.samples}")
print(f"  Valid samples : {valid_generator.samples}")
print(f"  Classes ({NUM_CLASSES})  : {CLASS_NAMES}")
print(f"  Image size    : {IMG_SIZE}")
print(f"  Batch size    : {BATCH_SIZE}")
print("=" * 60)

print("\n  ✓ Fragment 1 complete. train_generator and valid_generator are ready.")
print("     Proceed to Fragment 2 — Custom CNN Model Building.\n")
# Out:
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 8833 images belonging to 11 classes.
# Found 644 images belonging to 11 classes.
# ============================================================
#   Fragment 1 — Data Generators Ready
# ============================================================
#   Architecture  : Custom CNN (6 layers)
#   Train source  : augmented/   (shared, no new aug)
#   Valid source  : val/
#   Test source   : not loaded here
#   Preprocessing : rescale 1/255
#   Train samples : 8833
#   Valid samples : 644
#   Classes (11)  : ['Blackberry', 'Blueberry', 'Carrots', 'Cheese', 'Cream Cheese', 'Mixed Bread', 'Onion', 'Orange', 'Raspberry', 'Toast', 'Tomatoes']
#   Image size    : (224, 224)
#   Batch size    : 32
# ============================================================
#
#   ✓ Fragment 1 complete. train_generator and valid_generator are ready.
#      Proceed to Fragment 2 — Custom CNN Model Building.

# %%
"""
Fragment 2 — Custom CNN Model Building (6 Convolutional Layers)
================================================================
- Builds a custom CNN from scratch — no pretrained weights
- 6 convolutional layers organised into 3 blocks of 2
- Each block followed by BatchNormalization, MaxPooling, Dropout
- Accepts learning rate and dropout rate as inputs
- No unfreeze parameter — all layers are always trainable
- Compiled and ready for training in Fragment 3
"""

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    BatchNormalization,
    Flatten,
    Dense,
    Dropout,
    Input,
)
from tensorflow.keras.optimizers import Adam

# ── Configuration ─────────────────────────────────────────────────────────────

IMG_SIZE    = (224, 224)
IMG_SHAPE   = IMG_SIZE + (3,)
NUM_CLASSES = len(train_generator.class_indices)
CLASS_NAMES = list(train_generator.class_indices.keys())

# ── Default values ────────────────────────────────────────────────────────────

DEFAULT_LEARNING_RATE = 1e-3     # custom CNNs train from scratch so
                                  # higher LR than transfer learning
DEFAULT_DROPOUT_RATE  = 0.5      # moderate dropout — no residual
                                  # connections for built-in regularisation
EPOCHS                = 25

# ── Step 1: Model Builder ─────────────────────────────────────────────────────

def build_custom_cnn(learning_rate, dropout_rate, epochs=EPOCHS):
    """
    Builds and compiles a 6-layer Custom CNN from scratch.

    Architecture — 3 convolutional blocks:
    ─────────────────────────────────────
    Block 1 : Conv2D(32)  → Conv2D(32)  → BN → MaxPool → Dropout
    Block 2 : Conv2D(64)  → Conv2D(64)  → BN → MaxPool → Dropout
    Block 3 : Conv2D(128) → Conv2D(128) → BN → MaxPool → Dropout
    Head    : Flatten → Dense(256) → Dropout → Dense(128) → Dropout
              → Dense(NUM_CLASSES, softmax)

    Parameters
    ----------
    learning_rate : float — Adam optimizer learning rate
                            Recommended range : 1e-4 to 1e-2
                            Training from scratch needs a higher
                            LR than transfer learning — 1e-3 is
                            a safe starting point

    dropout_rate  : float — dropout applied after each block
                            and in the classification head
                            Recommended range : 0.3 to 0.6
                            No pretrained regularisation so
                            dropout is more critical here

    epochs        : int   — number of training epochs
                            default : 25
                            Custom CNNs typically need more epochs
                            than transfer learning to converge
    """

    model = Sequential([

        Input(shape=IMG_SHAPE),

        # ── Block 1 — 2 conv layers, 32 filters ──────────────────────────────
        Conv2D(32, (3, 3), activation="relu", padding="same",
               name="conv1_1"),
        Conv2D(32, (3, 3), activation="relu", padding="same",
               name="conv1_2"),
        BatchNormalization(name="bn_1"),
        MaxPooling2D((2, 2), name="pool_1"),
        Dropout(dropout_rate / 2, name="drop_1"),

        # ── Block 2 — 2 conv layers, 64 filters ──────────────────────────────
        Conv2D(64, (3, 3), activation="relu", padding="same",
               name="conv2_1"),
        Conv2D(64, (3, 3), activation="relu", padding="same",
               name="conv2_2"),
        BatchNormalization(name="bn_2"),
        MaxPooling2D((2, 2), name="pool_2"),
        Dropout(dropout_rate / 2, name="drop_2"),

        # ── Block 3 — 2 conv layers, 128 filters ─────────────────────────────
        Conv2D(128, (3, 3), activation="relu", padding="same",
               name="conv3_1"),
        Conv2D(128, (3, 3), activation="relu", padding="same",
               name="conv3_2"),
        BatchNormalization(name="bn_3"),
        MaxPooling2D((2, 2), name="pool_3"),
        Dropout(dropout_rate / 2, name="drop_3"),

        # ── Classification head ───────────────────────────────────────────────
        Flatten(name="flatten"),
        Dense(256, activation="relu", name="dense_256"),
        Dropout(dropout_rate, name="dropout_head_1"),
        Dense(128, activation="relu", name="dense_128"),
        Dropout(dropout_rate / 2, name="dropout_head_2"),
        Dense(NUM_CLASSES, activation="softmax", name="output"),

    ], name="custom_cnn_6layer")

    model.compile(
        optimizer = Adam(learning_rate=learning_rate),
        loss      = "categorical_crossentropy",
        metrics   = ["accuracy"]
    )

    return model

# ── Step 2: Build default model and print summary ─────────────────────────────

model = build_custom_cnn(
    learning_rate = DEFAULT_LEARNING_RATE,
    dropout_rate  = DEFAULT_DROPOUT_RATE,
)

# ── Count parameters ──
total_params     = model.count_params()
trainable_params = sum(tf.size(w).numpy() for w in model.trainable_weights)
frozen_params    = sum(tf.size(w).numpy() for w in model.non_trainable_weights)

print("=" * 60)
print("  Fragment 2 — Custom CNN (6 Convolutional Layers)")
print("=" * 60)

print("\n  ── Inputs ──────────────────────────────────────────")
print(f"  Learning rate    : {DEFAULT_LEARNING_RATE}")
print(f"  Dropout rate     : {DEFAULT_DROPOUT_RATE}")
print(f"  Epochs           : {EPOCHS}")
print(f"  Pretrained       : None — trained from scratch")

print("\n  ── Architecture ────────────────────────────────────")
print(f"  Input shape      : {IMG_SHAPE}")
print(f"  Block 1          : Conv2D(32) → Conv2D(32) → BN → MaxPool → Dropout")
print(f"  Block 2          : Conv2D(64) → Conv2D(64) → BN → MaxPool → Dropout")
print(f"  Block 3          : Conv2D(128) → Conv2D(128) → BN → MaxPool → Dropout")

print("\n  ── Classification Head ─────────────────────────────")
print(f"  Flatten")
print(f"  Dense(256, relu)")
print(f"  Dropout({DEFAULT_DROPOUT_RATE})")
print(f"  Dense(128, relu)")
print(f"  Dropout({DEFAULT_DROPOUT_RATE / 2})")
print(f"  Dense({NUM_CLASSES}, softmax)  ← {NUM_CLASSES} classes")
print(f"  Classes          : {CLASS_NAMES}")

print("\n  ── Parameters ──────────────────────────────────────")
print(f"  Total params     : {total_params:,}")
print(f"  Trainable        : {trainable_params:,}")
print(f"  Frozen           : {frozen_params:,}")

print("\n  ── Recommended Search Space ────────────────────────")
print(f"  learning_rate    : 1e-4  → 1e-2  (log scale)")
print(f"  dropout_rate     : 0.3   → 0.6")
print(f"  epochs           : {EPOCHS}")
print("=" * 60)

print("\n  ✓ Fragment 2 complete. build_custom_cnn() is ready.")
print("     Proceed to Fragment 3 — Callbacks & Training.\n")
# Out:
# ============================================================
#   Fragment 2 — Custom CNN (6 Convolutional Layers)
# ============================================================
#
#   ── Inputs ──────────────────────────────────────────
#   Learning rate    : 0.001
#   Dropout rate     : 0.5
#   Epochs           : 25
#   Pretrained       : None — trained from scratch
#
#   ── Architecture ────────────────────────────────────
#   Input shape      : (224, 224, 3)
#   Block 1          : Conv2D(32) → Conv2D(32) → BN → MaxPool → Dropout
#   Block 2          : Conv2D(64) → Conv2D(64) → BN → MaxPool → Dropout
#   Block 3          : Conv2D(128) → Conv2D(128) → BN → MaxPool → Dropout
#
#   ── Classification Head ─────────────────────────────
#   Flatten
#   Dense(256, relu)
#   Dropout(0.5)
#   Dense(128, relu)
#   Dropout(0.25)
#   Dense(11, softmax)  ← 11 classes
#   Classes          : ['Blackberry', 'Blueberry', 'Carrots', 'Cheese', 'Cream Cheese', 'Mixed Bread', 'Onion', 'Orange', 'Raspberry', 'Toast', 'Tomatoes']
#
#   ── Parameters ──────────────────────────────────────
#   Total params     : 26,012,587
#   Trainable        : 26,012,139
#   Frozen           : 448
#
#   ── Recommended Search Space ────────────────────────
#   learning_rate    : 1e-4  → 1e-2  (log scale)
#   dropout_rate     : 0.3   → 0.6
#   epochs           : 25
# ============================================================
#
#   ✓ Fragment 2 complete. build_custom_cnn() is ready.
#      Proceed to Fragment 3 — Callbacks & Training.

# %%
"""
Fragment 3 — Callbacks & Model Training
========================================
Custom CNN (6 Layers) Mould/Fruit Multiclass Classification Pipeline

- Defines all callbacks:
    * ModelCheckpoint    — saves best model based on val_accuracy
    * EarlyStopping      — stops training if no improvement
    * ReduceLROnPlateau  — reduces LR when val_loss stalls
    * CSVLogger          — logs all metrics per epoch to CSV
- Trains Custom CNN using parameters defined in Fragment 2
- Validates on val set only
- Stores history for Fragment 4 evaluation:
    * Accuracy, Loss curves
    * Sensitivity, Specificity, Recall, F1, AUC/ROC
    * Confusion Matrix
"""

import os
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    EarlyStopping,
    ReduceLROnPlateau,
    CSVLogger,
)

# ── Configuration ─────────────────────────────────────────────────────────────

SAVE_DIR     = r"D:\Mold Studies\Models"
MODEL_NAME   = "custom_cnn_mould_best.keras"
CSV_LOG_NAME = "custom_cnn_training_log.csv"

os.makedirs(SAVE_DIR, exist_ok=True)

MODEL_PATH = os.path.join(SAVE_DIR, MODEL_NAME)
CSV_PATH   = os.path.join(SAVE_DIR, CSV_LOG_NAME)

# ── Callback Parameters ───────────────────────────────────────────────────────

# EarlyStopping
ES_PATIENCE   = 10       # stop after N epochs with no val_accuracy improvement
ES_MIN_DELTA  = 1e-4     # minimum change to count as improvement

# ReduceLROnPlateau
RLROP_FACTOR    = 0.5    # multiply LR by this on plateau
RLROP_PATIENCE  = 5      # epochs with no improvement before reducing LR
RLROP_MIN_LR    = 1e-7   # LR floor
RLROP_MIN_DELTA = 1e-4   # minimum change to count as improvement

# ── Step 1: Define Callbacks ──────────────────────────────────────────────────

checkpoint = ModelCheckpoint(
    filepath          = MODEL_PATH,
    monitor           = "val_accuracy",
    save_best_only    = True,
    save_weights_only = False,
    save_format       = "keras",
    mode              = "max",
    verbose           = 1,
)

early_stopping = EarlyStopping(
    monitor              = "val_accuracy",
    patience             = ES_PATIENCE,
    min_delta            = ES_MIN_DELTA,
    mode                 = "max",
    restore_best_weights = True,
    verbose              = 1,
)

reduce_lr = ReduceLROnPlateau(
    monitor   = "val_loss",
    factor    = RLROP_FACTOR,
    patience  = RLROP_PATIENCE,
    min_lr    = RLROP_MIN_LR,
    min_delta = RLROP_MIN_DELTA,
    mode      = "min",
    verbose   = 1,
)

csv_logger = CSVLogger(
    filename  = CSV_PATH,
    separator = ",",
    append    = False,
)

callbacks = [checkpoint, early_stopping, reduce_lr, csv_logger]

print("=" * 60)
print("  Step 1 — Callbacks Configured")
print("=" * 60)
print(f"  ModelCheckpoint  : best val_accuracy → {MODEL_PATH}")
print(f"  EarlyStopping    : patience={ES_PATIENCE} epochs, "
      f"restores best weights")
print(f"  ReduceLROnPlateau: factor={RLROP_FACTOR} after "
      f"{RLROP_PATIENCE} stale epochs, floor={RLROP_MIN_LR}")
print(f"  CSVLogger        : epoch log → {CSV_PATH}")
print("=" * 60)

# ── Step 2: Training Configuration ───────────────────────────────────────────

print("\n" + "=" * 60)
print("  Step 2 — Training Configuration")
print("=" * 60)
print(f"  Architecture     : Custom CNN (6 Convolutional Layers)")
print(f"  Pretrained       : None — trained from scratch")
print(f"  Train samples    : {train_generator.samples}")
print(f"  Valid samples    : {valid_generator.samples}")
print(f"  Test samples     : not touched here")
print(f"  Classes          : {NUM_CLASSES}")
print(f"  Epochs           : {EPOCHS}")
print(f"  Batch size       : {BATCH_SIZE}")
print(f"  Learning rate    : {DEFAULT_LEARNING_RATE:.6f}")
print(f"  Dropout rate     : {DEFAULT_DROPOUT_RATE:.4f}")
print("=" * 60 + "\n")

# ── Step 3: Build Final Model ─────────────────────────────────────────────────

model = build_custom_cnn(
    learning_rate = DEFAULT_LEARNING_RATE,
    dropout_rate  = DEFAULT_DROPOUT_RATE,
    epochs        = EPOCHS,
)

# ── Step 4: Train ─────────────────────────────────────────────────────────────

history = model.fit(
    train_generator,
    epochs           = EPOCHS,
    validation_data  = valid_generator,
    callbacks        = callbacks,
    steps_per_epoch  = train_generator.samples  // BATCH_SIZE,
    validation_steps = valid_generator.samples  // BATCH_SIZE,
)

# ── Step 5: Force Save in .keras Format ──────────────────────────────────────

model.save(MODEL_PATH)
print(f"\n  ✓ Model explicitly saved in .keras format → {MODEL_PATH}")

# ── Step 6: Training Summary ──────────────────────────────────────────────────

best_val_acc  = max(history.history["val_accuracy"])
best_val_loss = min(history.history["val_loss"])
epochs_run    = len(history.history["accuracy"])
best_epoch    = history.history["val_accuracy"].index(best_val_acc) + 1

print("\n" + "=" * 60)
print("  Step 6 — Training Complete")
print("=" * 60)
print(f"  Architecture     : Custom CNN (6 Convolutional Layers)")
print(f"  Epochs run       : {epochs_run} / {EPOCHS}")
print(f"  Best epoch       : {best_epoch}")
print(f"  Best val accuracy: {best_val_acc:.4f}  ({best_val_acc * 100:.2f}%)")
print(f"  Best val loss    : {best_val_loss:.4f}")
print(f"  Best model saved : {MODEL_PATH}")
print(f"  Training log     : {CSV_PATH}")
print("=" * 60)

print("\n  ── Metrics available for Fragment 4 evaluation ─────")
print("  ✓ Accuracy        — per epoch (train + val)")
print("  ✓ Loss            — per epoch (train + val)")
print("  ✓ Sensitivity     — will be computed from confusion matrix")
print("  ✓ Specificity     — will be computed from confusion matrix")
print("  ✓ Recall          — will be computed from confusion matrix")
print("  ✓ F1 Score        — will be computed from confusion matrix")
print("  ✓ AUC / ROC       — will be computed per class (one-vs-rest)")
print("  ✓ Confusion Matrix — full 11-class matrix")
print("=" * 60)

print("\n  ✓ Fragment 3 complete. history and model are ready.")
print("     Proceed to Fragment 3b — Multi-Run Training.\n")
# Out:
# ============================================================
#   Step 1 — Callbacks Configured
# ============================================================
#   ModelCheckpoint  : best val_accuracy → D:\Mold Studies\Models\custom_cnn_mould_best.keras
#   EarlyStopping    : patience=10 epochs, restores best weights
#   ReduceLROnPlateau: factor=0.5 after 5 stale epochs, floor=1e-07
#   CSVLogger        : epoch log → D:\Mold Studies\Models\custom_cnn_training_log.csv
# ============================================================
#
# ============================================================
#   Step 2 — Training Configuration
# ============================================================
#   Architecture     : Custom CNN (6 Convolutional Layers)
#   Pretrained       : None — trained from scratch
#   Train samples    : 8833
#   Valid samples    : 644
#   Test samples     : not touched here
#   Classes          : 11
#   Epochs           : 25
#   Batch size       : 32
#   Learning rate    : 0.001000
#   Dropout rate     : 0.5000
# ============================================================
#
# Epoch 1/25
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 276/276 [==============================] - ETA: 0s - loss: 5.5089 - accuracy: 0.4964
# Epoch 1: val_accuracy improved from -inf to 0.10938, saving model to D:\Mold Studies\Models\custom_cnn_mould_best.keras
# 276/276 [==============================] - 242s 872ms/step - loss: 5.5089 - accuracy: 0.4964 - val_loss: 49.0943 - val_accuracy: 0.1094 - lr: 0.0010
# Epoch 2/25
# 276/276 [==============================] - ETA: 0s - loss: 1.4768 - accuracy: 0.5618
# Epoch 2: val_accuracy improved from 0.10938 to 0.45937, saving model to D:\Mold Studies\Models\custom_cnn_mould_best.keras
# 276/276 [==============================] - 198s 718ms/step - loss: 1.4768 - accuracy: 0.5618 - val_loss: 3.8926 - val_accuracy: 0.4594 - lr: 0.0010
# Epoch 3/25
# 276/276 [==============================] - ETA: 0s - loss: 1.2780 - accuracy: 0.6363
# Epoch 3: val_accuracy improved from 0.45937 to 0.58281, saving model to D:\Mold Studies\Models\custom_cnn_mould_best.keras
# 276/276 [==============================] - 196s 709ms/step - loss: 1.2780 - accuracy: 0.6363 - val_loss: 1.9573 - val_accuracy: 0.5828 - lr: 0.0010
# Epoch 4/25
# 276/276 [==============================] - ETA: 0s - loss: 1.2041 - accuracy: 0.6712
# Epoch 4: val_accuracy did not improve from 0.58281
# 276/276 [==============================] - 195s 705ms/step - loss: 1.2041 - accuracy: 0.6712 - val_loss: 3.2741 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 5/25
# 276/276 [==============================] - ETA: 0s - loss: 1.0623 - accuracy: 0.7108
# Epoch 5: val_accuracy improved from 0.58281 to 0.59688, saving model to D:\Mold Studies\Models\custom_cnn_mould_best.keras
# 276/276 [==============================] - 195s 705ms/step - loss: 1.0623 - accuracy: 0.7108 - val_loss: 2.0121 - val_accuracy: 0.5969 - lr: 0.0010
# Epoch 6/25
# 276/276 [==============================] - ETA: 0s - loss: 0.8097 - accuracy: 0.7703
# Epoch 6: val_accuracy improved from 0.59688 to 0.62969, saving model to D:\Mold Studies\Models\custom_cnn_mould_best.keras
# 276/276 [==============================] - 195s 706ms/step - loss: 0.8097 - accuracy: 0.7703 - val_loss: 1.8109 - val_accuracy: 0.6297 - lr: 0.0010
# Epoch 7/25
# 276/276 [==============================] - ETA: 0s - loss: 0.7644 - accuracy: 0.7921
# Epoch 7: val_accuracy improved from 0.62969 to 0.80625, saving model to D:\Mold Studies\Models\custom_cnn_mould_best.keras
# 276/276 [==============================] - 195s 705ms/step - loss: 0.7644 - accuracy: 0.7921 - val_loss: 0.8335 - val_accuracy: 0.8062 - lr: 0.0010
# Epoch 8/25
# 276/276 [==============================] - ETA: 0s - loss: 0.6244 - accuracy: 0.8148
# Epoch 8: val_accuracy improved from 0.80625 to 0.91406, saving model to D:\Mold Studies\Models\custom_cnn_mould_best.keras
# 276/276 [==============================] - 229s 829ms/step - loss: 0.6244 - accuracy: 0.8148 - val_loss: 0.3809 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 9/25
# 276/276 [==============================] - ETA: 0s - loss: 0.8684 - accuracy: 0.7559
# Epoch 9: val_accuracy did not improve from 0.91406
# 276/276 [==============================] - 316s 1s/step - loss: 0.8684 - accuracy: 0.7559 - val_loss: 0.9308 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 10/25
# 276/276 [==============================] - ETA: 0s - loss: 0.5730 - accuracy: 0.8360
# Epoch 10: val_accuracy improved from 0.91406 to 0.94844, saving model to D:\Mold Studies\Models\custom_cnn_mould_best.keras
# 276/276 [==============================] - 321s 1s/step - loss: 0.5730 - accuracy: 0.8360 - val_loss: 0.2118 - val_accuracy: 0.9484 - lr: 0.0010
# Epoch 11/25
# 276/276 [==============================] - ETA: 0s - loss: 0.5067 - accuracy: 0.8569
# Epoch 11: val_accuracy did not improve from 0.94844
# 276/276 [==============================] - 317s 1s/step - loss: 0.5067 - accuracy: 0.8569 - val_loss: 0.5310 - val_accuracy: 0.8609 - lr: 0.0010
# Epoch 12/25
# 276/276 [==============================] - ETA: 0s - loss: 0.5539 - accuracy: 0.8466
# Epoch 12: val_accuracy did not improve from 0.94844
# 276/276 [==============================] - 318s 1s/step - loss: 0.5539 - accuracy: 0.8466 - val_loss: 3.4867 - val_accuracy: 0.5969 - lr: 0.0010
# Epoch 13/25
# 276/276 [==============================] - ETA: 0s - loss: 0.4685 - accuracy: 0.8643
# Epoch 13: val_accuracy did not improve from 0.94844
# 276/276 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9450
# Epoch 23: val_accuracy did not improve from 0.96562
# 276/276 [==============================] - 200s 723ms/step - loss: 0.1943 - accuracy: 0.9450 - val_loss: 0.1909 - val_accuracy: 0.9547 - lr: 5.0000e-04
# Epoch 24/25
# 276/276 [==============================] - ETA: 0s - loss: 0.1726 - accuracy: 0.9497
# Epoch 24: val_accuracy did not improve from 0.96562
# 276/276 [==============================] - 199s 723ms/step - loss: 0.1726 - accuracy: 0.9497 - val_loss: 0.1952 - val_accuracy: 0.9531 - lr: 5.0000e-04
# Epoch 25/25
# 276/276 [==============================] - ETA: 0s - loss: 0.1969 - accuracy: 0.9439
# Epoch 25: val_accuracy did not improve from 0.96562
# 276/276 [==============================] - 197s 712ms/step - loss: 0.1969 - accuracy: 0.9439 - val_loss: 0.2652 - val_accuracy: 0.9328 - lr: 5.0000e-04
#
#   ✓ Model explicitly saved in .keras format → D:\Mold Studies\Models\custom_cnn_mould_best.keras
#
# ============================================================
#   Step 6 — Training Complete
# ============================================================
#   Architecture     : Custom CNN (6 Convolutional Layers)
#   Epochs run       : 25 / 25
#   Best epoch       : 16
#   Best val accuracy: 0.9656  (96.56%)
#   Best val loss    : 0.1140
#   Best model saved : D:\Mold Studies\Models\custom_cnn_mould_best.keras
#   Training log     : D:\Mold Studies\Models\custom_cnn_training_log.csv
# ============================================================
#
#   ── Metrics available for Fragment 4 evaluation ─────
#   ✓ Accuracy        — per epoch (train + val)
#   ✓ Loss            — per epoch (train + val)
#   ✓ Sensitivity     — will be computed from confusion matrix
#   ✓ Specificity     — will be computed from confusion matrix
#   ✓ Recall          — will be computed from confusion matrix
#   ✓ F1 Score        — will be computed from confusion matrix
#   ✓ AUC / ROC       — will be computed per class (one-vs-rest)
#   ✓ Confusion Matrix — full 11-class matrix
# ============================================================
#
#   ✓ Fragment 3 complete. history and model are ready.
#      Proceed to Fragment 3b — Multi-Run Training.

# %%
"""
Fragment 3b — Multi-Run Training (Custom CNN)
==============================================
Custom CNN (6 Layers) Mould/Fruit Multiclass Classification Pipeline

Runs 4 additional independent training loops (Runs 2–5).
Run 1 was completed in Fragment 3 and its model is already saved.
Each run starts from randomly reinitialised weights — no
pretrained weights involved.

OUTPUT: 5 models saved to disk for statistical analysis
    custom_cnn_run1_best.keras   (copied from Fragment 3)
    custom_cnn_run2_best.keras
    custom_cnn_run3_best.keras
    custom_cnn_run4_best.keras
    custom_cnn_run5_best.keras

DATA BOUNDARIES — unchanged from Fragment 3:
    Training   : train_generator  (augmented folder)
    Validation : valid_generator  (val folder)
    Test       : NOT TOUCHED — Fragment 4 only
"""

import os
import shutil
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    EarlyStopping,
    ReduceLROnPlateau,
    CSVLogger,
)

# ── Configuration ─────────────────────────────────────────────────────────────

SAVE_DIR   = r"D:\Mold Studies\Models"
TOTAL_RUNS = 5

os.makedirs(SAVE_DIR, exist_ok=True)

# ── Step 1: Copy Fragment 3 model → Run 1 ────────────────────────────────────

src = os.path.join(SAVE_DIR, "custom_cnn_mould_best.keras")
dst = os.path.join(SAVE_DIR, "custom_cnn_run1_best.keras")

if os.path.exists(src) and not os.path.exists(dst):
    shutil.copy2(src, dst)
    print(f"  Copied  : custom_cnn_mould_best.keras → custom_cnn_run1_best.keras")
elif os.path.exists(dst):
    print(f"  Already exists : custom_cnn_run1_best.keras — skipping copy")
else:
    print(f"  WARNING : custom_cnn_mould_best.keras not found")
    print(f"            Ensure Fragment 3 completed successfully before continuing")

# ── Step 2: Collect Run 1 results from Fragment 3 ────────────────────────────

all_run_results = [
    {
        "run"          : 1,
        "best_val_acc" : best_val_acc,
        "best_val_loss": best_val_loss,
        "best_epoch"   : best_epoch,
        "checkpoint"   : "custom_cnn_run1_best.keras"
    }
]

print(f"\n  Run 1 loaded from Fragment 3")
print(f"    Architecture      : Custom CNN (6 Convolutional Layers)")
print(f"    Pretrained        : None — trained from scratch")
print(f"    Best val accuracy : {best_val_acc:.4f}")
print(f"    Best val loss     : {best_val_loss:.4f}")
print(f"    Best epoch        : {best_epoch}")

# ── Step 3: Runs 2–5 ──────────────────────────────────────────────────────────

print(f"\n{'='*60}")
print(f"  MULTI-RUN TRAINING — Runs 2 to {TOTAL_RUNS}")
print(f"  Architecture : Custom CNN (6 Convolutional Layers)")
print(f"  Each run     : fresh random weight initialisation")
print(f"  Epochs       : {EPOCHS}")
print(f"  LR           : {DEFAULT_LEARNING_RATE}")
print(f"  Dropout      : {DEFAULT_DROPOUT_RATE}")
print(f"{'='*60}")

for run_idx in range(2, TOTAL_RUNS + 1):

    print(f"\n{'='*60}")
    print(f"  RUN {run_idx} / {TOTAL_RUNS}  —  Custom CNN")
    print(f"{'='*60}\n")

    ckpt_path = os.path.join(SAVE_DIR, f"custom_cnn_run{run_idx}_best.keras")
    csv_path  = os.path.join(SAVE_DIR, f"custom_cnn_run{run_idx}_log.csv")

    # ── Fresh model — new random weight initialisation ────────────────────────
    run_model = build_custom_cnn(
        learning_rate = DEFAULT_LEARNING_RATE,
        dropout_rate  = DEFAULT_DROPOUT_RATE,
        epochs        = EPOCHS,
    )

    # ── Run-specific callbacks ─────────────────────────────────────────────────
    run_callbacks = [
        ModelCheckpoint(
            filepath          = ckpt_path,
            monitor           = "val_accuracy",
            save_best_only    = True,
            save_weights_only = False,
            save_format       = "keras",
            mode              = "max",
            verbose           = 1,
        ),
        EarlyStopping(
            monitor              = "val_accuracy",
            patience             = ES_PATIENCE,
            min_delta            = ES_MIN_DELTA,
            mode                 = "max",
            restore_best_weights = True,
            verbose              = 1,
        ),
        ReduceLROnPlateau(
            monitor   = "val_loss",
            factor    = RLROP_FACTOR,
            patience  = RLROP_PATIENCE,
            min_lr    = RLROP_MIN_LR,
            min_delta = RLROP_MIN_DELTA,
            mode      = "min",
            verbose   = 1,
        ),
        CSVLogger(
            filename  = csv_path,
            separator = ",",
            append    = False,
        ),
    ]

    # ── Train ──────────────────────────────────────────────────────────────────
    run_history = run_model.fit(
        train_generator,
        validation_data  = valid_generator,
        epochs           = EPOCHS,
        callbacks        = run_callbacks,
        steps_per_epoch  = train_generator.samples // BATCH_SIZE,
        validation_steps = valid_generator.samples // BATCH_SIZE,
    )

    # ── Extract best metrics ───────────────────────────────────────────────────
    run_best_val_acc  = max(run_history.history["val_accuracy"])
    run_best_val_loss = min(run_history.history["val_loss"])
    run_best_epoch    = run_history.history["val_accuracy"].index(run_best_val_acc) + 1
    run_epochs_run    = len(run_history.history["accuracy"])

    # ── Force save in .keras format ───────────────────────────────────────────
    run_model.save(ckpt_path)

    all_run_results.append({
        "run"          : run_idx,
        "best_val_acc" : run_best_val_acc,
        "best_val_loss": run_best_val_loss,
        "best_epoch"   : run_best_epoch,
        "checkpoint"   : f"custom_cnn_run{run_idx}_best.keras"
    })

    print(f"\n  Run {run_idx} complete")
    print(f"    Epochs run        : {run_epochs_run} / {EPOCHS}")
    print(f"    Best epoch        : {run_best_epoch}")
    print(f"    Best val accuracy : {run_best_val_acc:.4f}")
    print(f"    Best val loss     : {run_best_val_loss:.4f}")
    print(f"    Saved to          : {ckpt_path}")

# ── Step 4: Summary across all 5 runs ────────────────────────────────────────

val_accs   = [r["best_val_acc"]  for r in all_run_results]
val_losses = [r["best_val_loss"] for r in all_run_results]

print(f"\n{'='*60}")
print(f"  ALL RUNS COMPLETE — Custom CNN Summary")
print(f"{'='*60}")
print(f"  {'Run':<6} {'Val Acc':>10} {'Val Loss':>10} "
      f"{'Best Epoch':>12} {'Checkpoint'}")
print(f"  {'─'*70}")

for r in all_run_results:
    print(f"  {r['run']:<6} {r['best_val_acc']:>10.4f} "
          f"{r['best_val_loss']:>10.4f} {r['best_epoch']:>12} "
          f"{r['checkpoint']}")

best_run = max(all_run_results, key=lambda x: x["best_val_acc"])

print(f"\n  {'─'*60}")
print(f"  Mean val accuracy  : {np.mean(val_accs):.4f}")
print(f"  Std  val accuracy  : {np.std(val_accs):.4f}")
print(f"  Mean val loss      : {np.mean(val_losses):.4f}")
print(f"  Std  val loss      : {np.std(val_losses):.4f}")
print(f"\n  Best single run    : Run {best_run['run']} "
      f"— Val Acc {best_run['best_val_acc']:.4f}")
print(f"{'='*60}")

# ── Step 5: Expose checkpoint list for Fragment 4 ────────────────────────────

ensemble_checkpoints = [
    os.path.join(SAVE_DIR, r["checkpoint"]) for r in all_run_results
]

custom_cnn_all_run_results = all_run_results

print(f"\n  ✓ Fragment 3b complete.")
print(f"  ensemble_checkpoints = {ensemble_checkpoints}")
print(f"\n     Proceed to Fragment 4 — Evaluation & Metrics.\n")
# Out:
#   Copied  : custom_cnn_mould_best.keras → custom_cnn_run1_best.keras
#
#   Run 1 loaded from Fragment 3
#     Architecture      : Custom CNN (6 Convolutional Layers)
#     Pretrained        : None — trained from scratch
#     Best val accuracy : 0.9656
#     Best val loss     : 0.1140
#     Best epoch        : 16
#
# ============================================================
#   MULTI-RUN TRAINING — Runs 2 to 5
#   Architecture : Custom CNN (6 Convolutional Layers)
#   Each run     : fresh random weight initialisation
#   Epochs       : 25
#   LR           : 0.001
#   Dropout      : 0.5
# ============================================================
#
# ============================================================
#   RUN 2 / 5  —  Custom CNN
# ============================================================
#
# Epoch 1/25
# 276/276 [==============================] - ETA: 0s - loss: 3.7592 - accuracy: 0.3785
# Epoch 1: val_accuracy improved from -inf to 0.19531, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 199s 719ms/step - loss: 3.7592 - accuracy: 0.3785 - val_loss: 9.0254 - val_accuracy: 0.1953 - lr: 0.0010
# Epoch 2/25
# 276/276 [==============================] - ETA: 0s - loss: 2.0139 - accuracy: 0.3396
# Epoch 2: val_accuracy improved from 0.19531 to 0.39844, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 199s 719ms/step - loss: 2.0139 - accuracy: 0.3396 - val_loss: 1.8646 - val_accuracy: 0.3984 - lr: 0.0010
# Epoch 3/25
# 276/276 [==============================] - ETA: 0s - loss: 2.0472 - accuracy: 0.3094
# Epoch 3: val_accuracy did not improve from 0.39844
# 276/276 [==============================] - 198s 717ms/step - loss: 2.0472 - accuracy: 0.3094 - val_loss: 26.4509 - val_accuracy: 0.1781 - lr: 0.0010
# Epoch 4/25
# 276/276 [==============================] - ETA: 0s - loss: 2.0136 - accuracy: 0.2755
# Epoch 4: val_accuracy did not improve from 0.39844
# 276/276 [==============================] - 199s 721ms/step - loss: 2.0136 - accuracy: 0.2755 - val_loss: 24.6721 - val_accuracy: 0.2016 - lr: 0.0010
# Epoch 5/25
# 276/276 [==============================] - ETA: 0s - loss: 1.8598 - accuracy: 0.3569
# Epoch 5: val_accuracy did not improve from 0.39844
# 276/276 [==============================] - 270s 979ms/step - loss: 1.8598 - accuracy: 0.3569 - val_loss: 2.6279 - val_accuracy: 0.3844 - lr: 0.0010
# Epoch 6/25
# 276/276 [==============================] - ETA: 0s - loss: 1.7793 - accuracy: 0.3719
# Epoch 6: val_accuracy improved from 0.39844 to 0.40938, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 315s 1s/step - loss: 1.7793 - accuracy: 0.3719 - val_loss: 2.2837 - val_accuracy: 0.4094 - lr: 0.0010
# Epoch 7/25
# 276/276 [==============================] - ETA: 0s - loss: 1.8021 - accuracy: 0.3488
# Epoch 7: val_accuracy did not improve from 0.40938
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 312s 1s/step - loss: 1.8021 - accuracy: 0.3488 - val_loss: 2.4217 - val_accuracy: 0.3766 - lr: 0.0010
# Epoch 8/25
# 276/276 [==============================] - ETA: 0s - loss: 1.5228 - accuracy: 0.4497
# Epoch 8: val_accuracy improved from 0.40938 to 0.45625, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 312s 1s/step - loss: 1.5228 - accuracy: 0.4497 - val_loss: 1.6415 - val_accuracy: 0.4563 - lr: 5.0000e-04
# Epoch 9/25
# 276/276 [==============================] - ETA: 0s - loss: 1.5374 - accuracy: 0.4329
# Epoch 9: val_accuracy did not improve from 0.45625
# 276/276 [==============================] - 310s 1s/step - loss: 1.5374 - accuracy: 0.4329 - val_loss: 1.6378 - val_accuracy: 0.4484 - lr: 5.0000e-04
# Epoch 10/25
# 276/276 [==============================] - ETA: 0s - loss: 1.5294 - accuracy: 0.4476
# Epoch 10: val_accuracy did not improve from 0.45625
# 276/276 [==============================] - 311s 1s/step - loss: 1.5294 - accuracy: 0.4476 - val_loss: 7.8543 - val_accuracy: 0.3594 - lr: 5.0000e-04
# Epoch 11/25
# 276/276 [==============================] - ETA: 0s - loss: 1.4354 - accuracy: 0.4839
# Epoch 11: val_accuracy improved from 0.45625 to 0.45781, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 311s 1s/step - loss: 1.4354 - accuracy: 0.4839 - val_loss: 1.5510 - val_accuracy: 0.4578 - lr: 5.0000e-04
# Epoch 12/25
# 276/276 [==============================] - ETA: 0s - loss: 1.3469 - accuracy: 0.5136
# Epoch 12: val_accuracy improved from 0.45781 to 0.52188, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 311s 1s/step - loss: 1.3469 - accuracy: 0.5136 - val_loss: 1.5173 - val_accuracy: 0.5219 - lr: 5.0000e-04
# Epoch 13/25
# 276/276 [==============================] - ETA: 0s - loss: 1.2975 - accuracy: 0.5227
# Epoch 13: val_accuracy did not improve from 0.52188
# 276/276 [==============================] - 310s 1s/step - loss: 1.2975 - accuracy: 0.5227 - val_loss: 1.4449 - val_accuracy: 0.5188 - lr: 5.0000e-04
# Epoch 14/25
# 276/276 [==============================] - ETA: 0s - loss: 1.3123 - accuracy: 0.5212
# Epoch 14: val_accuracy did not improve from 0.52188
# 276/276 [==============================] - 310s 1s/step - loss: 1.3123 - accuracy: 0.5212 - val_loss: 8.2650 - val_accuracy: 0.4078 - lr: 5.0000e-04
# Epoch 15/25
# 276/276 [==============================] - ETA: 0s - loss: 1.2507 - accuracy: 0.5378
# Epoch 15: val_accuracy improved from 0.52188 to 0.55469, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 311s 1s/step - loss: 1.2507 - accuracy: 0.5378 - val_loss: 1.3724 - val_accuracy: 0.5547 - lr: 5.0000e-04
# Epoch 16/25
# 276/276 [==============================] - ETA: 0s - loss: 1.2291 - accuracy: 0.5533
# Epoch 16: val_accuracy improved from 0.55469 to 0.56563, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 311s 1s/step - loss: 1.2291 - accuracy: 0.5533 - val_loss: 1.2592 - val_accuracy: 0.5656 - lr: 5.0000e-04
# Epoch 17/25
# 276/276 [==============================] - ETA: 0s - loss: 1.3465 - accuracy: 0.5456
# Epoch 17: val_accuracy did not improve from 0.56563
# 276/276 [==============================] - 309s 1s/step - loss: 1.3465 - accuracy: 0.5456 - val_loss: 1.7437 - val_accuracy: 0.4859 - lr: 5.0000e-04
# Epoch 18/25
# 276/276 [==============================] - ETA: 0s - loss: 1.3708 - accuracy: 0.5076
# Epoch 18: val_accuracy did not improve from 0.56563
# 276/276 [==============================] - 310s 1s/step - loss: 1.3708 - accuracy: 0.5076 - val_loss: 1.3050 - val_accuracy: 0.5469 - lr: 5.0000e-04
# Epoch 19/25
# 276/276 [==============================] - ETA: 0s - loss: 1.2151 - accuracy: 0.5566
# Epoch 19: val_accuracy improved from 0.56563 to 0.58906, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 311s 1s/step - loss: 1.2151 - accuracy: 0.5566 - val_loss: 1.2633 - val_accuracy: 0.5891 - lr: 5.0000e-04
# Epoch 20/25
# 276/276 [==============================] - ETA: 0s - loss: 1.1814 - accuracy: 0.5679
# Epoch 20: val_accuracy improved from 0.58906 to 0.60312, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 311s 1s/step - loss: 1.1814 - accuracy: 0.5679 - val_loss: 1.2108 - val_accuracy: 0.6031 - lr: 5.0000e-04
# Epoch 21/25
# 276/276 [==============================] - ETA: 0s - loss: 1.0850 - accuracy: 0.6005
# Epoch 21: val_accuracy did not improve from 0.60312
# 276/276 [==============================] - 311s 1s/step - loss: 1.0850 - accuracy: 0.6005 - val_loss: 1.1970 - val_accuracy: 0.5703 - lr: 5.0000e-04
# Epoch 22/25
# 276/276 [==============================] - ETA: 0s - loss: 1.0876 - accuracy: 0.5996
# Epoch 22: val_accuracy did not improve from 0.60312
# 276/276 [==============================] - 311s 1s/step - loss: 1.0876 - accuracy: 0.5996 - val_loss: 1.1747 - val_accuracy: 0.4938 - lr: 5.0000e-04
# Epoch 23/25
# 276/276 [==============================] - ETA: 0s - loss: 1.0099 - accuracy: 0.6285
# Epoch 23: val_accuracy did not improve from 0.60312
# 276/276 [==============================] - 310s 1s/step - loss: 1.0099 - accuracy: 0.6285 - val_loss: 1.2670 - val_accuracy: 0.5359 - lr: 5.0000e-04
# Epoch 24/25
# 276/276 [==============================] - ETA: 0s - loss: 0.8896 - accuracy: 0.6675
# Epoch 24: val_accuracy did not improve from 0.60312
# 276/276 [==============================] - 310s 1s/step - loss: 0.8896 - accuracy: 0.6675 - val_loss: 1.2333 - val_accuracy: 0.5781 - lr: 5.0000e-04
# Epoch 25/25
# 276/276 [==============================] - ETA: 0s - loss: 0.8440 - accuracy: 0.6750
# Epoch 25: val_accuracy improved from 0.60312 to 0.62344, saving model to D:\Mold Studies\Models\custom_cnn_run2_best.keras
# 276/276 [==============================] - 311s 1s/step - loss: 0.8440 - accuracy: 0.6750 - val_loss: 0.9855 - val_accuracy: 0.6234 - lr: 5.0000e-04
#
#   Run 2 complete
#     Epochs run        : 25 / 25
#     Best epoch        : 25
#     Best val accuracy : 0.6234
#     Best val loss     : 0.9855
#     Saved to          : D:\Mold Studies\Models\custom_cnn_run2_best.keras
#
# ============================================================
#   RUN 3 / 5  —  Custom CNN
# ============================================================
#
# Epoch 1/25
# 276/276 [==============================] - ETA: 0s - loss: 6.3571 - accuracy: 0.4747
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 193s 697ms/step - loss: 0.7314 - accuracy: 0.7490 - val_loss: 4.2889 - val_accuracy: 0.4672 - lr: 0.0010
# Epoch 19/25
# 276/276 [==============================] - ETA: 0s - loss: 0.6010 - accuracy: 0.7787
# Epoch 19: val_accuracy improved from 0.81094 to 0.94687, saving model to D:\Mold Studies\Models\custom_cnn_run3_best.keras
# 276/276 [==============================] - 195s 706ms/step - loss: 0.6010 - accuracy: 0.7787 - val_loss: 0.4046 - val_accuracy: 0.9469 - lr: 5.0000e-04
# Epoch 20/25
# 276/276 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.8113
# Epoch 20: val_accuracy did not improve from 0.94687
# 276/276 [==============================] - 193s 699ms/step - loss: 0.5443 - accuracy: 0.8113 - val_loss: 1.1695 - val_accuracy: 0.8516 - lr: 5.0000e-04
# Epoch 21/25
# 276/276 [==============================] - ETA: 0s - loss: 0.5258 - accuracy: 0.8196
# Epoch 21: val_accuracy improved from 0.94687 to 0.95312, saving model to D:\Mold Studies\Models\custom_cnn_run3_best.keras
# 276/276 [==============================] - 193s 700ms/step - loss: 0.5258 - accuracy: 0.8196 - val_loss: 0.3906 - val_accuracy: 0.9531 - lr: 5.0000e-04
# Epoch 22/25
# 276/276 [==============================] - ETA: 0s - loss: 0.5036 - accuracy: 0.8237
# Epoch 22: val_accuracy did not improve from 0.95312
# 276/276 [==============================] - 192s 697ms/step - loss: 0.5036 - accuracy: 0.8237 - val_loss: 0.4038 - val_accuracy: 0.9438 - lr: 5.0000e-04
# Epoch 23/25
# 276/276 [==============================] - ETA: 0s - loss: 0.4707 - accuracy: 0.8432
# Epoch 23: val_accuracy did not improve from 0.95312
# 276/276 [==============================] - 188s 683ms/step - loss: 0.4707 - accuracy: 0.8432 - val_loss: 0.5725 - val_accuracy: 0.8516 - lr: 5.0000e-04
# Epoch 24/25
# 276/276 [==============================] - ETA: 0s - loss: 0.4534 - accuracy: 0.8409
# Epoch 24: val_accuracy did not improve from 0.95312
# 276/276 [==============================] - 188s 681ms/step - loss: 0.4534 - accuracy: 0.8409 - val_loss: 0.5605 - val_accuracy: 0.8875 - lr: 5.0000e-04
# Epoch 25/25
# 276/276 [==============================] - ETA: 0s - loss: 0.4647 - accuracy: 0.8425
# Epoch 25: val_accuracy improved from 0.95312 to 0.95781, saving model to D:\Mold Studies\Models\custom_cnn_run3_best.keras
# 276/276 [==============================] - 189s 683ms/step - loss: 0.4647 - accuracy: 0.8425 - val_loss: 0.3034 - val_accuracy: 0.9578 - lr: 5.0000e-04
#
#   Run 3 complete
#     Epochs run        : 25 / 25
#     Best epoch        : 25
#     Best val accuracy : 0.9578
#     Best val loss     : 0.3034
#     Saved to          : D:\Mold Studies\Models\custom_cnn_run3_best.keras
#
# ============================================================
#   RUN 4 / 5  —  Custom CNN
# ============================================================
#
# Epoch 1/25
# 276/276 [==============================] - ETA: 0s - loss: 6.0005 - accuracy: 0.5929
# Epoch 1: val_accuracy improved from -inf to 0.14375, saving model to D:\Mold Studies\Models\custom_cnn_run4_best.keras
# 276/276 [==============================] - 190s 684ms/step - loss: 6.0005 - accuracy: 0.5929 - val_loss: 3.4675 - val_accuracy: 0.1437 - lr: 0.0010
# Epoch 2/25
# 276/276 [==============================] - ETA: 0s - loss: 1.5671 - accuracy: 0.5833
# Epoch 2: val_accuracy improved from 0.14375 to 0.62656, saving model to D:\Mold Studies\Models\custom_cnn_run4_best.keras
# 276/276 [==============================] - 312s 1s/step - loss: 0.1886 - accuracy: 0.9372 - val_loss: 0.2379 - val_accuracy: 0.9234 - lr: 2.5000e-04
# Epoch 21/25
# 276/276 [==============================] - ETA: 0s - loss: 0.1736 - accuracy: 0.9421
# Epoch 21: val_accuracy did not improve from 0.96875
# 276/276 [==============================] - 312s 1s/step - loss: 0.1736 - accuracy: 0.9421 - val_loss: 0.1071 - val_accuracy: 0.9672 - lr: 2.5000e-04
# Epoch 22/25
# 276/276 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.9466
# Epoch 22: val_accuracy improved from 0.96875 to 0.97031, saving model to D:\Mold Studies\Models\custom_cnn_run4_best.keras
# 276/276 [==============================] - 311s 1s/step - loss: 0.1687 - accuracy: 0.9466 - val_loss: 0.1169 - val_accuracy: 0.9703 - lr: 2.5000e-04
# Epoch 23/25
# 276/276 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9461
# Epoch 23: val_accuracy did not improve from 0.97031
# 276/276 [==============================] - 307s 1s/step - loss: 0.1530 - accuracy: 0.9461 - val_loss: 0.1206 - val_accuracy: 0.9672 - lr: 2.5000e-04
# Epoch 24/25
# 276/276 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9416
# Epoch 24: val_accuracy did not improve from 0.97031
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 [==============================] - 307s 1s/step - loss: 0.1749 - accuracy: 0.9416 - val_loss: 0.0997 - val_accuracy: 0.9688 - lr: 2.5000e-04
# Epoch 25/25
# 276/276 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9489
# Epoch 25: val_accuracy did not improve from 0.97031
# 276/276 [==============================] - 307s 1s/step - loss: 0.1505 - accuracy: 0.9489 - val_loss: 0.1258 - val_accuracy: 0.9688 - lr: 1.2500e-04
#
#   Run 4 complete
#     Epochs run        : 25 / 25
#     Best epoch        : 22
#     Best val accuracy : 0.9703
#     Best val loss     : 0.0974
#     Saved to          : D:\Mold Studies\Models\custom_cnn_run4_best.keras
#
# ============================================================
#   RUN 5 / 5  —  Custom CNN
# ============================================================
#
# Epoch 1/25
# 276/276 [==============================] - ETA: 0s - loss: 7.0277 - accuracy: 0.5638
# Epoch 1: val_accuracy improved from -inf to 0.15937, saving model to D:\Mold Studies\Models\custom_cnn_run5_best.keras
# 276/276 [==============================] - 337s 1s/step - loss: 7.0277 - accuracy: 0.5638 - val_loss: 17.2956 - val_accuracy: 0.1594 - lr: 0.0010
# Epoch 2/25
# 276/276 [==============================] - ETA: 0s - loss: 1.5459 - accuracy: 0.6115
# Epoch 2: val_accuracy improved from 0.15937 to 0.68281, saving model to D:\Mold Studies\Models\custom_cnn_run5_best.keras
# 276/276 [==============================] - 212s 767ms/step - loss: 1.5459 - accuracy: 0.6115 - val_loss: 1.4176 - val_accuracy: 0.6828 - lr: 0.0010
# Epoch 3/25
# 276/276 [==============================] - ETA: 0s - loss: 1.1716 - accuracy: 0.6825
# Epoch 3: val_accuracy did not improve from 0.68281
# 276/276 [==============================] - 204s 739ms/step - loss: 1.1716 - accuracy: 0.6825 - val_loss: 3.0552 - val_accuracy: 0.5594 - lr: 0.0010
# 276/276 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.9084
# Epoch 22: val_accuracy did not improve from 0.95625
# 276/276 [==============================] - 195s 707ms/step - loss: 0.2839 - accuracy: 0.9084 - val_loss: 0.3022 - val_accuracy: 0.9062 - lr: 5.0000e-04
# Epoch 23/25
# 276/276 [==============================] - ETA: 0s - loss: 0.2585 - accuracy: 0.9148
# Epoch 23: val_accuracy did not improve from 0.95625
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 [==============================] - 204s 741ms/step - loss: 0.2585 - accuracy: 0.9148 - val_loss: 0.1508 - val_accuracy: 0.9547 - lr: 5.0000e-04
# Epoch 24/25
# 276/276 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.9215
# Epoch 24: val_accuracy improved from 0.95625 to 0.96719, saving model to D:\Mold Studies\Models\custom_cnn_run5_best.keras
# 276/276 [==============================] - 193s 701ms/step - loss: 0.2193 - accuracy: 0.9215 - val_loss: 0.1066 - val_accuracy: 0.9672 - lr: 2.5000e-04
# Epoch 25/25
# 276/276 [==============================] - ETA: 0s - loss: 0.2310 - accuracy: 0.9193
# Epoch 25: val_accuracy did not improve from 0.96719
# 276/276 [==============================] - 291s 1s/step - loss: 0.2310 - accuracy: 0.9193 - val_loss: 0.1208 - val_accuracy: 0.9625 - lr: 2.5000e-04
#
#   Run 5 complete
#     Epochs run        : 25 / 25
#     Best epoch        : 24
#     Best val accuracy : 0.9672
#     Best val loss     : 0.1066
#     Saved to          : D:\Mold Studies\Models\custom_cnn_run5_best.keras
#
# ============================================================
#   ALL RUNS COMPLETE — Custom CNN Summary
# ============================================================
#   Run       Val Acc   Val Loss   Best Epoch Checkpoint
#   ──────────────────────────────────────────────────────────────────────
#   1          0.9656     0.1140           16 custom_cnn_run1_best.keras
#   2          0.6234     0.9855           25 custom_cnn_run2_best.keras
#   3          0.9578     0.3034           25 custom_cnn_run3_best.keras
#   4          0.9703     0.0974           22 custom_cnn_run4_best.keras
#   5          0.9672     0.1066           24 custom_cnn_run5_best.keras
#
#   ────────────────────────────────────────────────────────────
#   Mean val accuracy  : 0.8969
#   Std  val accuracy  : 0.1368
#   Mean val loss      : 0.3214
#   Std  val loss      : 0.3408
#
#   Best single run    : Run 4 — Val Acc 0.9703
# ============================================================
#
#   ✓ Fragment 3b complete.
#   ensemble_checkpoints = ['D:\\Mold Studies\\Models\\custom_cnn_run1_best.keras', 'D:\\Mold Studies\\Models\\custom_cnn_run2_best.keras', 'D:\\Mold Studies\\Models\\custom_cnn_run3_best.keras', 'D:\\Mold Studies\\Models\\custom_cnn_run4_best.keras', 'D:\\Mold Studies\\Models\\custom_cnn_run5_best.keras']
#
#      Proceed to Fragment 4 — Evaluation & Metrics.

# %%
"""
Fragment 4 — Evaluation & Metrics
===================================
Custom CNN (6 Layers) Mould/Fruit Multiclass Classification Pipeline

Evaluates all 5 trained runs against the test set.
Metrics computed per run and averaged across all runs:
    - Confusion Matrix
    - Accuracy
    - Precision
    - Recall
    - Specificity
    - F1 Score
    - ROC / AUC (one-vs-rest per class)
    - Learning Rate Curve

TEST DATA — loaded fresh here, never seen during training.
"""

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import (
    confusion_matrix,
    roc_curve,
    auc,
)
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ── Configuration ─────────────────────────────────────────────────────────────

DATA_DIR   = r"D:\Mold Studies\Mould Studies Multiclass"
TEST_DIR   = os.path.join(DATA_DIR, "test")
SAVE_DIR   = r"D:\Mold Studies\Models"
PLOT_DIR   = os.path.join(SAVE_DIR, "plots", "custom_cnn")

os.makedirs(PLOT_DIR, exist_ok=True)

# ── Step 1: Load Test Generator ───────────────────────────────────────────────
# Custom CNN uses simple rescale — no preprocess_input needed
# Must match the preprocessing used in Fragment 1

test_datagen = ImageDataGenerator(rescale=1.0 / 255)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size = IMG_SIZE,
    batch_size  = BATCH_SIZE,
    class_mode  = "categorical",
    shuffle     = False,        # must be False for correct label alignment
)

CLASS_NAMES = list(test_generator.class_indices.keys())
NUM_CLASSES = len(CLASS_NAMES)

print("=" * 60)
print("  Step 1 — Test Generator Ready")
print("=" * 60)
print(f"  Architecture  : Custom CNN (6 Convolutional Layers)")
print(f"  Preprocessing : rescale 1/255")
print(f"  Test samples  : {test_generator.samples}")
print(f"  Classes       : {CLASS_NAMES}")
print(f"  Source        : {TEST_DIR}")
print("=" * 60)

# ── Step 2: Helper Functions ──────────────────────────────────────────────────

def compute_metrics(y_true, y_pred, y_prob):
    """
    Computes full evaluation metrics from predictions.
    Returns a dictionary of all metrics.
    """
    cm = confusion_matrix(y_true, y_pred)

    per_class = {}
    for i, cls in enumerate(CLASS_NAMES):
        tp = cm[i, i]
        fp = cm[:, i].sum() - tp
        fn = cm[i, :].sum() - tp
        tn = cm.sum() - tp - fp - fn

        precision   = tp / (tp + fp + 1e-7)
        recall      = tp / (tp + fn + 1e-7)
        specificity = tn / (tn + fp + 1e-7)
        f1          = 2 * precision * recall / (precision + recall + 1e-7)

        per_class[cls] = {
            "precision"  : precision,
            "recall"     : recall,
            "specificity": specificity,
            "f1"         : f1,
        }

    macro_precision   = np.mean([v["precision"]   for v in per_class.values()])
    macro_recall      = np.mean([v["recall"]      for v in per_class.values()])
    macro_specificity = np.mean([v["specificity"] for v in per_class.values()])
    macro_f1          = np.mean([v["f1"]          for v in per_class.values()])
    accuracy          = np.sum(y_true == y_pred) / len(y_true)

    # ROC / AUC — one-vs-rest per class
    y_true_bin = label_binarize(y_true, classes=list(range(NUM_CLASSES)))
    roc_auc    = {}
    for i, cls in enumerate(CLASS_NAMES):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
        roc_auc[cls] = {
            "fpr": fpr,
            "tpr": tpr,
            "auc": auc(fpr, tpr)
        }

    return {
        "cm"               : cm,
        "per_class"        : per_class,
        "accuracy"         : accuracy,
        "macro_precision"  : macro_precision,
        "macro_recall"     : macro_recall,
        "macro_specificity": macro_specificity,
        "macro_f1"         : macro_f1,
        "roc_auc"          : roc_auc,
    }


def plot_confusion_matrix(cm, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(12, 10))
    im = ax.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
    plt.colorbar(im, ax=ax)

    ax.set(
        xticks      = np.arange(NUM_CLASSES),
        yticks      = np.arange(NUM_CLASSES),
        xticklabels = CLASS_NAMES,
        yticklabels = CLASS_NAMES,
        title       = f"Custom CNN — Confusion Matrix — Run {run_idx}",
        ylabel      = "True Label",
        xlabel      = "Predicted Label",
    )
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right")

    thresh = cm.max() / 2.0
    for i in range(NUM_CLASSES):
        for j in range(NUM_CLASSES):
            ax.text(j, i, format(cm[i, j], "d"),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    path = os.path.join(save_dir, f"custom_cnn_confusion_matrix_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    print(f"  Saved: {path}")


def plot_roc_curves(roc_auc, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(12, 8))

    for cls in CLASS_NAMES:
        ax.plot(
            roc_auc[cls]["fpr"],
            roc_auc[cls]["tpr"],
            label=f"{cls} (AUC = {roc_auc[cls]['auc']:.3f})"
        )

    ax.plot([0, 1], [0, 1], "k--", label="Random classifier")
    ax.set(
        title  = f"Custom CNN — ROC Curves — Run {run_idx}",
        xlabel = "False Positive Rate",
        ylabel = "True Positive Rate",
    )
    ax.legend(loc="lower right", fontsize=8)
    plt.tight_layout()
    path = os.path.join(save_dir, f"custom_cnn_roc_curves_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    print(f"  Saved: {path}")


def plot_metrics_table(metrics, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(14, 5))
    ax.axis("off")

    rows = []
    for cls in CLASS_NAMES:
        pc = metrics["per_class"][cls]
        rows.append([
            cls,
            f"{pc['precision']:.4f}",
            f"{pc['recall']:.4f}",
            f"{pc['specificity']:.4f}",
            f"{pc['f1']:.4f}",
            f"{metrics['roc_auc'][cls]['auc']:.4f}",
        ])

    rows.append([
        "MACRO AVG",
        f"{metrics['macro_precision']:.4f}",
        f"{metrics['macro_recall']:.4f}",
        f"{metrics['macro_specificity']:.4f}",
        f"{metrics['macro_f1']:.4f}",
        f"{np.mean([metrics['roc_auc'][c]['auc'] for c in CLASS_NAMES]):.4f}",
    ])

    col_labels = ["Class", "Precision", "Recall",
                  "Specificity", "F1", "AUC"]

    table = ax.table(
        cellText  = rows,
        colLabels = col_labels,
        loc       = "center",
        cellLoc   = "center",
    )
    table.auto_set_font_size(False)
    table.set_fontsize(9)
    table.scale(1.2, 1.8)

    for j in range(len(col_labels)):
        table[len(rows), j].set_facecolor("#d0e8ff")

    ax.set_title(
        f"Custom CNN — Per-Class Metrics — Run {run_idx}  "
        f"(Accuracy: {metrics['accuracy']:.4f})",
        fontsize=12, pad=20
    )

    plt.tight_layout()
    path = os.path.join(save_dir, f"custom_cnn_metrics_table_run{run_idx}.png")
    plt.savefig(path, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"  Saved: {path}")


def plot_learning_curves(csv_path, run_idx, save_dir):
    import pandas as pd

    if not os.path.exists(csv_path):
        print(f"  ⚠️  CSV log not found for Run {run_idx}: {csv_path}")
        return

    log = pd.read_csv(csv_path)

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle(f"Custom CNN — Learning Curves — Run {run_idx}", fontsize=13)

    # Accuracy
    axes[0].plot(log["epoch"], log["accuracy"],     label="Train Accuracy")
    axes[0].plot(log["epoch"], log["val_accuracy"], label="Val Accuracy")
    axes[0].set(title="Accuracy", xlabel="Epoch", ylabel="Accuracy")
    axes[0].legend()

    # Loss
    axes[1].plot(log["epoch"], log["loss"],     label="Train Loss")
    axes[1].plot(log["epoch"], log["val_loss"], label="Val Loss")
    axes[1].set(title="Loss", xlabel="Epoch", ylabel="Loss")
    axes[1].legend()

    # Learning Rate
    if "lr" in log.columns:
        axes[2].plot(log["epoch"], log["lr"],
                     color="darkorange", label="LR")
        axes[2].set(title="Learning Rate", xlabel="Epoch", ylabel="LR")
        axes[2].set_yscale("log")
        axes[2].legend()
    else:
        axes[2].text(0.5, 0.5, "LR not logged",
                     ha="center", va="center",
                     transform=axes[2].transAxes)
        axes[2].set_title("Learning Rate")

    plt.tight_layout()
    path = os.path.join(save_dir, f"custom_cnn_learning_curves_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    print(f"  Saved: {path}")

# ── Step 3: Evaluate All 5 Runs ───────────────────────────────────────────────

all_metrics = []

for r in all_run_results:
    run_idx  = r["run"]
    ckpt     = os.path.join(SAVE_DIR, r["checkpoint"])
    csv_path = os.path.join(SAVE_DIR, f"custom_cnn_run{run_idx}_log.csv")

    print(f"\n{'='*60}")
    print(f"  Evaluating Custom CNN Run {run_idx} / {TOTAL_RUNS}")
    print(f"  Checkpoint : {ckpt}")
    print(f"{'='*60}")

    # Load model
    run_model = tf.keras.models.load_model(ckpt)

    # Reset generator — must be done before every predict
    test_generator.reset()

    # Predict
    y_prob = run_model.predict(
        test_generator,
        steps   = np.ceil(test_generator.samples / BATCH_SIZE),
        verbose = 1,
    )
    y_pred = np.argmax(y_prob, axis=1)
    y_true = test_generator.classes

    # Compute metrics
    metrics        = compute_metrics(y_true, y_pred, y_prob)
    metrics["run"] = run_idx
    all_metrics.append(metrics)

    # Print run summary
    print(f"\n  Architecture : Custom CNN (6 Convolutional Layers)")
    print(f"  Run          : {run_idx}")
    print(f"  Accuracy     : {metrics['accuracy']:.4f}")
    print(f"  Precision    : {metrics['macro_precision']:.4f}")
    print(f"  Recall       : {metrics['macro_recall']:.4f}")
    print(f"  Specificity  : {metrics['macro_specificity']:.4f}")
    print(f"  F1 Score     : {metrics['macro_f1']:.4f}")
    print(f"  Mean AUC     : "
          f"{np.mean([metrics['roc_auc'][c]['auc'] for c in CLASS_NAMES]):.4f}")

    # Plots
    plot_confusion_matrix(metrics["cm"],    run_idx, PLOT_DIR)
    plot_roc_curves(metrics["roc_auc"],     run_idx, PLOT_DIR)
    plot_metrics_table(metrics,             run_idx, PLOT_DIR)
    plot_learning_curves(csv_path,          run_idx, PLOT_DIR)

# ── Step 4: Statistical Summary Across All 5 Runs ────────────────────────────

print(f"\n{'='*60}")
print(f"  STATISTICAL SUMMARY — Custom CNN — All {TOTAL_RUNS} Runs")
print(f"{'='*60}")

metric_keys = {
    "Accuracy"   : "accuracy",
    "Precision"  : "macro_precision",
    "Recall"     : "macro_recall",
    "Specificity": "macro_specificity",
    "F1 Score"   : "macro_f1",
}

for label, key in metric_keys.items():
    vals = [m[key] for m in all_metrics]
    print(f"  {label:<14}: "
          f"mean={np.mean(vals):.4f}  "
          f"std={np.std(vals):.4f}  "
          f"min={np.min(vals):.4f}  "
          f"max={np.max(vals):.4f}")

mean_aucs = [
    np.mean([m["roc_auc"][c]["auc"] for c in CLASS_NAMES])
    for m in all_metrics
]
print(f"  {'AUC':<14}: "
      f"mean={np.mean(mean_aucs):.4f}  "
      f"std={np.std(mean_aucs):.4f}  "
      f"min={np.min(mean_aucs):.4f}  "
      f"max={np.max(mean_aucs):.4f}")

print(f"{'='*60}")

# ── Step 5: Best Run ──────────────────────────────────────────────────────────

best_metrics = max(all_metrics, key=lambda x: x["accuracy"])
print(f"\n  Best run     : Run {best_metrics['run']}")
print(f"  Accuracy     : {best_metrics['accuracy']:.4f}")
print(f"  F1 Score     : {best_metrics['macro_f1']:.4f}")
print(f"  Mean AUC     : "
      f"{np.mean([best_metrics['roc_auc'][c]['auc'] for c in CLASS_NAMES]):.4f}")

# ── Step 6: Expose for cross-model comparison ─────────────────────────────────

custom_cnn_all_metrics     = all_metrics
custom_cnn_all_run_results = all_run_results

print(f"\n  All plots saved to : {PLOT_DIR}")
print(f"\n  ✓ Fragment 4 complete.")
print(f"     custom_cnn_all_metrics and custom_cnn_all_run_results")
print(f"     are ready for Fragment 5 — Model Comparison.\n")
# Out:
# Found 658 images belonging to 11 classes.
# ============================================================
#   Step 1 — Test Generator Ready
# ============================================================
#   Architecture  : Custom CNN (6 Convolutional Layers)
#   Preprocessing : rescale 1/255
#   Test samples  : 658
#   Classes       : ['Blackberry', 'Blueberry', 'Carrots', 'Cheese', 'Cream Cheese', 'Mixed Bread', 'Onion', 'Orange', 'Raspberry', 'Toast', 'Tomatoes']
#   Source        : D:\Mold Studies\Mould Studies Multiclass\test
# ============================================================
#
# ============================================================
#   Evaluating Custom CNN Run 1 / 5
#   Checkpoint : D:\Mold Studies\Models\custom_cnn_run1_best.keras
# ============================================================
# 21/21 [==============================] - 7s 314ms/step
#
#   Architecture : Custom CNN (6 Convolutional Layers)
#   Run          : 1
#   Accuracy     : 0.9286
#   Precision    : 0.9111
#   Recall       : 0.9415
#   Specificity  : 0.9930
#   F1 Score     : 0.9216
#   Mean AUC     : 0.9982
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_confusion_matrix_run1.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_roc_curves_run1.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_metrics_table_run1.png
#   ⚠️  CSV log not found for Run 1: D:\Mold Studies\Models\custom_cnn_run1_log.csv
#
# ============================================================
#   Evaluating Custom CNN Run 2 / 5
#   Checkpoint : D:\Mold Studies\Models\custom_cnn_run2_best.keras
# ============================================================
# 21/21 [==============================] - 6s 276ms/step
#
#   Architecture : Custom CNN (6 Convolutional Layers)
#   Run          : 2
#   Accuracy     : 0.5988
#   Precision    : 0.7140
#   Recall       : 0.6739
#   Specificity  : 0.9571
#   F1 Score     : 0.6452
#   Mean AUC     : 0.9100
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_confusion_matrix_run2.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_roc_curves_run2.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_metrics_table_run2.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_learning_curves_run2.png
#
# ============================================================
#   Evaluating Custom CNN Run 3 / 5
#   Checkpoint : D:\Mold Studies\Models\custom_cnn_run3_best.keras
# ============================================================
# 21/21 [==============================] - 6s 290ms/step
#
#   Architecture : Custom CNN (6 Convolutional Layers)
#   Run          : 3
#   Accuracy     : 0.9483
#   Precision    : 0.9520
#   Recall       : 0.9506
#   Specificity  : 0.9947
#   F1 Score     : 0.9503
#   Mean AUC     : 0.9973
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_confusion_matrix_run3.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_roc_curves_run3.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_metrics_table_run3.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_learning_curves_run3.png
#
# ============================================================
#   Evaluating Custom CNN Run 4 / 5
#   Checkpoint : D:\Mold Studies\Models\custom_cnn_run4_best.keras
# ============================================================
# 21/21 [==============================] - 4s 163ms/step
#
#   Architecture : Custom CNN (6 Convolutional Layers)
#   Run          : 4
#   Accuracy     : 0.9726
#   Precision    : 0.9682
#   Recall       : 0.9726
#   Specificity  : 0.9973
#   F1 Score     : 0.9697
#   Mean AUC     : 0.9990
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_confusion_matrix_run4.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_roc_curves_run4.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_metrics_table_run4.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_learning_curves_run4.png
#
# ============================================================
#   Evaluating Custom CNN Run 5 / 5
#   Checkpoint : D:\Mold Studies\Models\custom_cnn_run5_best.keras
# ============================================================
# 21/21 [==============================] - 3s 159ms/step
#
#   Architecture : Custom CNN (6 Convolutional Layers)
#   Run          : 5
#   Accuracy     : 0.9605
#   Precision    : 0.9554
#   Recall       : 0.9622
#   Specificity  : 0.9961
#   F1 Score     : 0.9573
#   Mean AUC     : 0.9990
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_confusion_matrix_run5.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_roc_curves_run5.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_metrics_table_run5.png
#   Saved: D:\Mold Studies\Models\plots\custom_cnn\custom_cnn_learning_curves_run5.png
#
# ============================================================
#   STATISTICAL SUMMARY — Custom CNN — All 5 Runs
# ============================================================
#   Accuracy      : mean=0.8818  std=0.1422  min=0.5988  max=0.9726
#   Precision     : mean=0.9001  std=0.0950  min=0.7140  max=0.9682
#   Recall        : mean=0.9002  std=0.1136  min=0.6739  max=0.9726
#   Specificity   : mean=0.9876  std=0.0153  min=0.9571  max=0.9973
#   F1 Score      : mean=0.8888  std=0.1228  min=0.6452  max=0.9697
#   AUC           : mean=0.9807  std=0.0353  min=0.9100  max=0.9990
# ============================================================
#
#   Best run     : Run 4
#   Accuracy     : 0.9726
#   F1 Score     : 0.9697
#   Mean AUC     : 0.9990
#
#   All plots saved to : D:\Mold Studies\Models\plots\custom_cnn
#
#   ✓ Fragment 4 complete.
#      custom_cnn_all_metrics and custom_cnn_all_run_results
#      are ready for Fragment 5 — Model Comparison.

# %%
"""
Per-Run Results Table — Custom CNN (6 Convolutional Layers)
============================================================
Prints best training accuracy, best validation accuracy per run,
and full test metrics per run in a single consolidated table.
"""

import numpy as np
import pandas as pd

# ── Step 1: Collect per-run training history metrics ─────────────────────────
# Training accuracy is read from the CSV logs saved during training

train_accs = {}

for r in all_run_results:
    run_idx  = r["run"]
    csv_path = os.path.join(SAVE_DIR, f"custom_cnn_run{run_idx}_log.csv")

    if os.path.exists(csv_path):
        log = pd.read_csv(csv_path)
        train_accs[run_idx] = max(log["accuracy"])
    else:
        # Run 1 log is named differently
        csv_run1 = os.path.join(SAVE_DIR, "custom_cnn_training_log.csv")
        if os.path.exists(csv_run1):
            log = pd.read_csv(csv_run1)
            train_accs[run_idx] = max(log["accuracy"])
        else:
            train_accs[run_idx] = float("nan")

# ── Step 2: Build table rows ──────────────────────────────────────────────────

col_run   = 6
col_train = 12
col_val   = 12
col_test  = 12
col_prec  = 12
col_sens  = 12
col_f1    = 10
col_auc   = 10

divider = "=" * (col_run + col_train + col_val + col_test +
                 col_prec + col_sens + col_f1 + col_auc + 9)
thin    = "─" * (col_run + col_train + col_val + col_test +
                 col_prec + col_sens + col_f1 + col_auc + 9)

print(divider)
print("  PER-RUN RESULTS — Custom CNN (6 Convolutional Layers)")
print(divider)
print(
    f"  {'Run':<{col_run}}"
    f"{'Train Acc':>{col_train}}"
    f"{'Val Acc':>{col_val}}"
    f"{'Test Acc':>{col_test}}"
    f"{'Precision':>{col_prec}}"
    f"{'Sensitivity':>{col_sens}}"
    f"{'F1 Score':>{col_f1}}"
    f"{'AUC':>{col_auc}}"
)
print(thin)

# ── Per-run rows ──────────────────────────────────────────────────────────────

for r, m in zip(all_run_results, all_metrics):
    run_idx     = r["run"]
    train_acc   = train_accs.get(run_idx, float("nan"))
    val_acc     = r["best_val_acc"]
    test_acc    = m["accuracy"]
    precision   = m["macro_precision"]
    sensitivity = m["macro_recall"]     # sensitivity = recall
    f1          = m["macro_f1"]
    mean_auc    = np.mean([m["roc_auc"][c]["auc"] for c in CLASS_NAMES])

    print(
        f"  {run_idx:<{col_run}}"
        f"{train_acc:>{col_train}.4f}"
        f"{val_acc:>{col_val}.4f}"
        f"{test_acc:>{col_test}.4f}"
        f"{precision:>{col_prec}.4f}"
        f"{sensitivity:>{col_sens}.4f}"
        f"{f1:>{col_f1}.4f}"
        f"{mean_auc:>{col_auc}.4f}"
    )

print(thin)

# ── Step 3: Statistical Summary ───────────────────────────────────────────────

train_vals = [train_accs[r["run"]] for r in all_run_results]
val_vals   = [r["best_val_acc"]    for r in all_run_results]
test_vals  = [m["accuracy"]        for m in all_metrics]
prec_vals  = [m["macro_precision"] for m in all_metrics]
sens_vals  = [m["macro_recall"]    for m in all_metrics]
f1_vals    = [m["macro_f1"]        for m in all_metrics]
auc_vals   = [
    np.mean([m["roc_auc"][c]["auc"] for c in CLASS_NAMES])
    for m in all_metrics
]

print(f"\n  {'─'*30}  Statistical Summary  {'─'*30}")
print(
    f"  {'Metric':<{col_run+4}}"
    f"{'Mean':>{col_train}}"
    f"{'Std':>{col_val}}"
    f"{'Min':>{col_test}}"
    f"{'Max':>{col_prec}}"
)
print(thin)

stat_metrics = {
    "Train Acc"  : train_vals,
    "Val Acc"    : val_vals,
    "Test Acc"   : test_vals,
    "Precision"  : prec_vals,
    "Sensitivity": sens_vals,
    "F1 Score"   : f1_vals,
    "AUC"        : auc_vals,
}

for label, vals in stat_metrics.items():
    clean_vals = [v for v in vals if not np.isnan(v)]
    print(
        f"  {label:<{col_run+4}}"
        f"{np.mean(clean_vals):>{col_train}.4f}"
        f"{np.std(clean_vals):>{col_val}.4f}"
        f"{np.min(clean_vals):>{col_test}.4f}"
        f"{np.max(clean_vals):>{col_prec}.4f}"
    )

print(divider)
print(f"\n  ✓ Summary table complete.")
print(f"     custom_cnn_all_metrics ready for Fragment 5 — Model Comparison.\n")
# Out:
# ===============================================================================================
#   PER-RUN RESULTS — Custom CNN (6 Convolutional Layers)
# ===============================================================================================
#   Run      Train Acc     Val Acc    Test Acc   Precision Sensitivity  F1 Score       AUC
# ───────────────────────────────────────────────────────────────────────────────────────────────
#   1           0.9497      0.9656      0.9286      0.9111      0.9415    0.9216    0.9982
#   2           0.6750      0.6234      0.5988      0.7140      0.6739    0.6452    0.9100
#   3           0.8432      0.9578      0.9483      0.9520      0.9506    0.9503    0.9973
#   4           0.9489      0.9703      0.9726      0.9682      0.9726    0.9697    0.9990
#   5           0.9215      0.9672      0.9605      0.9554      0.9622    0.9573    0.9990
# ───────────────────────────────────────────────────────────────────────────────────────────────
#
#   ──────────────────────────────  Statistical Summary  ──────────────────────────────
#   Metric            Mean         Std         Min         Max
# ───────────────────────────────────────────────────────────────────────────────────────────────
#   Train Acc       0.8677      0.1038      0.6750      0.9497
#   Val Acc         0.8969      0.1368      0.6234      0.9703
#   Test Acc        0.8818      0.1422      0.5988      0.9726
#   Precision       0.9001      0.0950      0.7140      0.9682
#   Sensitivity      0.9002      0.1136      0.6739      0.9726
#   F1 Score        0.8888      0.1228      0.6452      0.9697
#   AUC             0.9807      0.0353      0.9100      0.9990
# ===============================================================================================
#
#   ✓ Summary table complete.
#      custom_cnn_all_metrics ready for Fragment 5 — Model Comparison.
