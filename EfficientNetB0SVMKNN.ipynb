# %%
"""
Fragment 1 — Data Loading
==========================
EfficientNetB0 Binary Hybrid Pipeline — Feature Extraction + ML Classification

- Loads train, val and test data from disk
- Augmented folder already exists — no new augmentation
- Uses EfficientNet preprocess_input to match training preprocessing
- All three sets loaded here since feature extraction
  requires passing images through EfficientNetB0 once
- shuffle=False on all sets — required for correct label
  alignment during feature extraction
- Binary classification — Mold vs No Mold
"""

import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input

# ── Configuration ─────────────────────────────────────────────────────────────

DATA_DIR   = r"D:\Mold Studies Binary\Mould Binary Classification"
AUG_DIR    = os.path.join(DATA_DIR, "augmented")
VALID_DIR  = os.path.join(DATA_DIR, "val")
TEST_DIR   = os.path.join(DATA_DIR, "test")

IMG_SIZE   = (224, 224)
BATCH_SIZE = 32

# ── Safety Guards ─────────────────────────────────────────────────────────────

assert os.path.exists(AUG_DIR), \
    f"Augmented folder not found: {AUG_DIR}"
assert os.path.exists(VALID_DIR), \
    f"Validation folder not found: {VALID_DIR}"
assert os.path.exists(TEST_DIR), \
    f"Test folder not found: {TEST_DIR}"

# ── Step 1: Build Generators ──────────────────────────────────────────────────

def build_generators(aug_dir: str, valid_dir: str, test_dir: str):
    """
    Builds generators for all three sets.
    All use EfficientNet preprocess_input — critical for
    EfficientNetB0 as simple rescale gives worse results.
    Must be consistent across all sets.
    shuffle=False on all sets — critical for correct label
    alignment when extracting features batch by batch.
    class_mode = 'binary' — Mold vs No Mold.
    """

    train_datagen   = ImageDataGenerator(
                          preprocessing_function=preprocess_input)
    train_generator = train_datagen.flow_from_directory(
        aug_dir,
        target_size = IMG_SIZE,
        batch_size  = BATCH_SIZE,
        class_mode  = "binary",
        shuffle     = False,
    )

    valid_datagen   = ImageDataGenerator(
                          preprocessing_function=preprocess_input)
    valid_generator = valid_datagen.flow_from_directory(
        valid_dir,
        target_size = IMG_SIZE,
        batch_size  = BATCH_SIZE,
        class_mode  = "binary",
        shuffle     = False,
    )

    test_datagen   = ImageDataGenerator(
                         preprocessing_function=preprocess_input)
    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size = IMG_SIZE,
        batch_size  = BATCH_SIZE,
        class_mode  = "binary",
        shuffle     = False,
    )

    return train_generator, valid_generator, test_generator

# ── Step 2: Run and Summarise ─────────────────────────────────────────────────

train_generator, valid_generator, test_generator = build_generators(
    AUG_DIR, VALID_DIR, TEST_DIR
)

CLASS_NAMES = list(train_generator.class_indices.keys())
NUM_CLASSES = len(CLASS_NAMES)

print("=" * 60)
print("  Fragment 1 — Data Generators Ready")
print("=" * 60)
print(f"  Pipeline      : Binary — Mold vs No Mold")
print(f"  Model         : EfficientNetB0 + SVM / KNN (Hybrid)")
print(f"  Train source  : augmented/   (shared, no new aug)")
print(f"  Valid source  : val/")
print(f"  Test source   : test/")
print(f"  Preprocessing : EfficientNet preprocess_input")
print(f"  Shuffle       : False on all sets (required for")
print(f"                  correct label alignment)")
print(f"  Train samples : {train_generator.samples}")
print(f"  Valid samples : {valid_generator.samples}")
print(f"  Test samples  : {test_generator.samples}")
print(f"  Classes       : {CLASS_NAMES}")
print(f"  Class indices : {train_generator.class_indices}")
print(f"  Image size    : {IMG_SIZE}")
print(f"  Batch size    : {BATCH_SIZE}")
print("=" * 60)

print("\n  ✓ Fragment 1 complete.")
print("     train_generator, valid_generator and test_generator are ready.")
print("     Proceed to Fragment 2 — EfficientNetB0 Feature Extraction.\n")
# Out:
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 51838 images belonging to 2 classes.
# Found 648 images belonging to 2 classes.
# Found 649 images belonging to 2 classes.
# ============================================================
#   Fragment 1 — Data Generators Ready
# ============================================================
#   Pipeline      : Binary — Mold vs No Mold
#   Model         : EfficientNetB0 + SVM / KNN (Hybrid)
#   Train source  : augmented/   (shared, no new aug)
#   Valid source  : val/
#   Test source   : test/
#   Preprocessing : EfficientNet preprocess_input
#   Shuffle       : False on all sets (required for
#                   correct label alignment)
#   Train samples : 51838
#   Valid samples : 648
#   Test samples  : 649
#   Classes       : ['Mold', 'No mold']
#   Class indices : {'Mold': 0, 'No mold': 1}
#   Image size    : (224, 224)
#   Batch size    : 32
# ============================================================
#
#   ✓ Fragment 1 complete.
#      train_generator, valid_generator and test_generator are ready.
#      Proceed to Fragment 2 — EfficientNetB0 Feature Extraction.

# %%
"""
Fragment 2 — EfficientNetB0 Binary Feature Extraction
======================================================
EfficientNetB0 Binary Hybrid Pipeline — Feature Extraction + ML Classification

- Loads EfficientNetB0 with ImageNet weights
- Removes classification head — keeps convolutional base only
- Uses GlobalAveragePooling2D to produce 1280 features per image
- Passes all three sets through EfficientNetB0 to extract features
- Features saved to disk as .npy files for reuse by
  Fragment 3 (SVM) and Fragment 4 (KNN)
- Extracted features reused without rerunning EfficientNetB0
"""

import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D

# ── Configuration ─────────────────────────────────────────────────────────────

IMG_SIZE    = (224, 224)
IMG_SHAPE   = IMG_SIZE + (3,)
NUM_CLASSES = len(train_generator.class_indices)
CLASS_NAMES = list(train_generator.class_indices.keys())

SAVE_DIR    = r"D:\Mold Studies Binary\Models"
FEATURE_DIR = os.path.join(SAVE_DIR, "features", "efficientnetb0_binary")

os.makedirs(FEATURE_DIR, exist_ok=True)

# ── Step 1: Build EfficientNetB0 Feature Extractor ───────────────────────────

def build_feature_extractor():
    """
    Loads EfficientNetB0 with ImageNet weights and removes the
    classification head entirely.

    EfficientNetB0 base output shape : (7, 7, 1280)
    After GlobalAveragePooling2D     : (1280,) features per image

    EfficientNetB0 produces 1280 features — same dimensionality
    as MobileNetV2 but richer due to compound scaling across
    depth, width and resolution simultaneously.
    All layers are frozen — EfficientNetB0 is used purely as a
    fixed feature extractor, not trained further.
    BatchNorm layers intentionally kept frozen — EfficientNetB0
    uses BatchNorm extensively in its MBConv blocks and
    unfreezing them causes training instability.
    """

    base_model = EfficientNetB0(
        input_shape = IMG_SHAPE,
        include_top = False,
        weights     = "imagenet"
    )

    base_model.trainable = False

    x      = base_model.output
    output = GlobalAveragePooling2D(name="gap")(x)

    feature_extractor = Model(
        inputs  = base_model.input,
        outputs = output,
        name    = "efficientnetb0_binary_feature_extractor"
    )

    return feature_extractor, base_model

feature_extractor, base_model = build_feature_extractor()

total_params     = feature_extractor.count_params()
trainable_params = sum(tf.size(w).numpy()
                       for w in feature_extractor.trainable_weights)
frozen_params    = sum(tf.size(w).numpy()
                       for w in feature_extractor.non_trainable_weights)

print("=" * 60)
print("  Fragment 2 — EfficientNetB0 Binary Feature Extractor")
print("=" * 60)
print(f"  Pipeline         : Binary — Mold vs No Mold")
print(f"  Architecture     : EfficientNetB0")
print(f"  Weights          : ImageNet ✓")
print(f"  Input shape      : {IMG_SHAPE}")
print(f"  Base output      : (7, 7, 1280)")
print(f"  After GAP        : 1280 features per image")
print(f"  Total base layers: {len(base_model.layers)}")
print(f"  All layers frozen: ✓")
print(f"  BatchNorm frozen : ✓ (critical — used in every MBConv block)")
print(f"  Total params     : {total_params:,}")
print(f"  Trainable        : {trainable_params:,}")
print(f"  Frozen           : {frozen_params:,}")
print("=" * 60)

# ── Step 2: Feature Extraction Function ──────────────────────────────────────

def extract_features(generator, extractor, set_name):
    """
    Passes all images through the EfficientNetB0 feature extractor.
    Returns feature matrix X and label array y.
    Generator must have shuffle=False for correct alignment.
    Features saved to disk as .npy files.
    If features already exist on disk they are loaded
    instead of recomputed — safe to rerun.
    """

    feat_path  = os.path.join(FEATURE_DIR, f"X_{set_name}.npy")
    label_path = os.path.join(FEATURE_DIR, f"y_{set_name}.npy")

    if os.path.exists(feat_path) and os.path.exists(label_path):
        print(f"  ✓ {set_name:<8} — loading from disk")
        X = np.load(feat_path)
        y = np.load(label_path)
        return X, y

    print(f"  Extracting {set_name} features...")
    generator.reset()

    X = extractor.predict(
        generator,
        steps   = np.ceil(generator.samples / generator.batch_size),
        verbose = 1,
    )
    y = generator.classes

    np.save(feat_path,  X)
    np.save(label_path, y)
    print(f"  ✓ {set_name:<8} — saved to disk  shape: {X.shape}")

    return X, y

# ── Step 3: Extract All Three Sets ───────────────────────────────────────────

print("\n" + "=" * 60)
print("  Step 2 — Extracting Features")
print("=" * 60)
print(f"  Feature dir : {FEATURE_DIR}")
print(f"  Note        : if features already exist on disk")
print(f"                they will be loaded instead of")
print(f"                recomputed — safe to rerun\n")

X_train, y_train = extract_features(train_generator,
                                     feature_extractor, "train")
X_val,   y_val   = extract_features(valid_generator,
                                     feature_extractor, "val")
X_test,  y_test  = extract_features(test_generator,
                                     feature_extractor, "test")

# ── Step 4: Summary ───────────────────────────────────────────────────────────

print("\n" + "=" * 60)
print("  Step 3 — Feature Extraction Complete")
print("=" * 60)
print(f"  Pipeline      : Binary — Mold vs No Mold")
print(f"  Architecture  : EfficientNetB0 (frozen, no head)")
print(f"  X_train shape : {X_train.shape}")
print(f"  X_val shape   : {X_val.shape}")
print(f"  X_test shape  : {X_test.shape}")
print(f"  Features      : {X_train.shape[1]:,} per image")
print(f"  Classes       : {CLASS_NAMES}")
print(f"  Saved to      : {FEATURE_DIR}")
print("=" * 60)

print("\n  ✓ Fragment 2 complete.")
print("     X_train, X_val, X_test, y_train, y_val, y_test are ready.")
print("     Proceed to Fragment 3 — SVM Classification.\n")
print("     Fragment 4 — KNN Classification will reuse")
print("     the same features without rerunning EfficientNetB0.\n")
# Out:
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# ============================================================
#   Fragment 2 — EfficientNetB0 Binary Feature Extractor
# ============================================================
#   Pipeline         : Binary — Mold vs No Mold
#   Architecture     : EfficientNetB0
#   Weights          : ImageNet ✓
#   Input shape      : (224, 224, 3)
#   Base output      : (7, 7, 1280)
#   After GAP        : 1280 features per image
#   Total base layers: 238
#   All layers frozen: ✓
#   BatchNorm frozen : ✓ (critical — used in every MBConv block)
#   Total params     : 4,049,571
#   Trainable        : 0
#   Frozen           : 4,049,571
# ============================================================
#
# ============================================================
#   Step 2 — Extracting Features
# ============================================================
#   Feature dir : D:\Mold Studies Binary\Models\features\efficientnetb0_binary
#   Note        : if features already exist on disk
#                 they will be loaded instead of
#                 recomputed — safe to rerun
#
#   Extracting train features...
# 1620/1620 [==============================] - 623s 384ms/step
#   ✓ train    — saved to disk  shape: (51838, 1280)
#   Extracting val features...
# 21/21 [==============================] - 4s 164ms/step
#   ✓ val      — saved to disk  shape: (648, 1280)
#   Extracting test features...
# 21/21 [==============================] - 4s 171ms/step
#   ✓ test     — saved to disk  shape: (649, 1280)
#
# ============================================================
#   Step 3 — Feature Extraction Complete
# ============================================================
#   Pipeline      : Binary — Mold vs No Mold
#   Architecture  : EfficientNetB0 (frozen, no head)
#   X_train shape : (51838, 1280)
#   X_val shape   : (648, 1280)
#   X_test shape  : (649, 1280)
#   Features      : 1,280 per image
#   Classes       : ['Mold', 'No mold']
#   Saved to      : D:\Mold Studies Binary\Models\features\efficientnetb0_binary
# ============================================================
#
#   ✓ Fragment 2 complete.
#      X_train, X_val, X_test, y_train, y_val, y_test are ready.
#      Proceed to Fragment 3 — SVM Classification.
#
#      Fragment 4 — KNN Classification will reuse
#      the same features without rerunning EfficientNetB0.

# %%
"""
Fragment 3 — SVM Classification on EfficientNetB0 Binary Features (5 Runs)
============================================================================
EfficientNetB0 Binary Hybrid Pipeline — Feature Extraction + SVM

- Loads EfficientNetB0 binary extracted features from disk
- Trains SVM 5 times using different random seeds
- Each run shuffles train features differently
- Evaluates on test features — never seen during training
- Computes full binary metrics + 95% confidence intervals
"""

import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    confusion_matrix,
    roc_curve,
    auc,
)
import scipy.stats as stats

# ── Configuration ─────────────────────────────────────────────────────────────

SAVE_DIR   = r"D:\Mold Studies Binary\Models"
PLOT_DIR   = os.path.join(SAVE_DIR, "plots", "efficientnetb0_binary_svm")
TOTAL_RUNS = 5
SEEDS      = [27, 42, 99, 123, 256]

os.makedirs(PLOT_DIR, exist_ok=True)

# ── SVM Parameters ────────────────────────────────────────────────────────────

SVM_KERNEL = "linear"
SVM_C      = 1.0
SVM_GAMMA  = "scale"
THRESHOLD  = 0.5

# ── Step 1: Helper Functions ──────────────────────────────────────────────────

def compute_metrics_binary(y_true, y_pred, y_prob):
    """
    Computes full binary evaluation metrics.
    y_prob is the probability for the positive class (column 1).
    """
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()

    precision   = tp / (tp + fp + 1e-7)
    recall      = tp / (tp + fn + 1e-7)
    specificity = tn / (tn + fp + 1e-7)
    f1          = 2 * precision * recall / (precision + recall + 1e-7)
    accuracy    = (tp + tn) / (tp + tn + fp + fn + 1e-7)

    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc     = auc(fpr, tpr)

    return {
        "cm"         : cm,
        "tp"         : int(tp),
        "tn"         : int(tn),
        "fp"         : int(fp),
        "fn"         : int(fn),
        "accuracy"   : accuracy,
        "precision"  : precision,
        "recall"     : recall,
        "specificity": specificity,
        "f1"         : f1,
        "fpr"        : fpr,
        "tpr"        : tpr,
        "auc"        : roc_auc,
    }


def plot_confusion_matrix(cm, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(7, 6))
    im = ax.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
    plt.colorbar(im, ax=ax)
    ax.set(
        xticks      = np.arange(NUM_CLASSES),
        yticks      = np.arange(NUM_CLASSES),
        xticklabels = CLASS_NAMES,
        yticklabels = CLASS_NAMES,
        title       = f"EfficientNetB0 Binary + SVM — Confusion Matrix — Run {run_idx}",
        ylabel      = "True Label",
        xlabel      = "Predicted Label",
    )
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right")
    thresh = cm.max() / 2.0
    for i in range(NUM_CLASSES):
        for j in range(NUM_CLASSES):
            ax.text(j, i, format(cm[i, j], "d"),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"efficientnetb0_binary_svm_confusion_matrix_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    plt.close()
    print(f"  Saved: {path}")


def plot_roc_curve(metrics, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(
        metrics["fpr"],
        metrics["tpr"],
        color = "steelblue",
        lw    = 2,
        label = f"ROC Curve (AUC = {metrics['auc']:.4f})"
    )
    ax.plot([0, 1], [0, 1], "k--", label="Random classifier")
    ax.set(
        title  = f"EfficientNetB0 Binary + SVM — ROC Curve — Run {run_idx}",
        xlabel = "False Positive Rate",
        ylabel = "True Positive Rate (Sensitivity)",
        xlim   = [0.0, 1.0],
        ylim   = [0.0, 1.05],
    )
    ax.legend(loc="lower right", fontsize=9)
    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"efficientnetb0_binary_svm_roc_curve_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    plt.close()
    print(f"  Saved: {path}")


def plot_metrics_table(metrics, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(12, 4))
    ax.axis("off")
    rows = [[
        CLASS_NAMES[1],
        f"{metrics['precision']:.4f}",
        f"{metrics['recall']:.4f}",
        f"{metrics['specificity']:.4f}",
        f"{metrics['f1']:.4f}",
        f"{metrics['auc']:.4f}",
        f"{metrics['tp']}",
        f"{metrics['fp']}",
        f"{metrics['fn']}",
        f"{metrics['tn']}",
    ]]
    col_labels = ["Class", "Precision", "Sensitivity",
                  "Specificity", "F1", "AUC",
                  "TP", "FP", "FN", "TN"]
    table = ax.table(
        cellText  = rows,
        colLabels = col_labels,
        loc       = "center",
        cellLoc   = "center",
    )
    table.auto_set_font_size(False)
    table.set_fontsize(9)
    table.scale(1.2, 2.0)
    for j in range(len(col_labels)):
        table[0, j].set_facecolor("#d0e8ff")
    ax.set_title(
        f"EfficientNetB0 Binary + SVM — Metrics — Run {run_idx}  "
        f"(Accuracy: {metrics['accuracy']:.4f})",
        fontsize=12, pad=20
    )
    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"efficientnetb0_binary_svm_metrics_table_run{run_idx}.png")
    plt.savefig(path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close()
    print(f"  Saved: {path}")

# ── Step 2: 5-Run Training Loop ───────────────────────────────────────────────

print("=" * 60)
print("  Fragment 3 — EfficientNetB0 Binary + SVM  (5 Runs)")
print("=" * 60)
print(f"  Pipeline       : Binary — Mold vs No Mold")
print(f"  Feature source : EfficientNetB0 extracted (1280 features)")
print(f"  Kernel         : {SVM_KERNEL}")
print(f"  C              : {SVM_C}")
print(f"  Threshold      : {THRESHOLD}")
print(f"  Seeds          : {SEEDS}")
print("=" * 60)

all_metrics     = []
all_run_results = []

for run_idx, seed in enumerate(SEEDS, 1):

    print(f"\n{'='*60}")
    print(f"  RUN {run_idx} / {TOTAL_RUNS}  —  EfficientNetB0 Binary + SVM")
    print(f"  Seed : {seed}")
    print(f"{'='*60}\n")

    MAX_TRAIN = 3000

    rng     = np.random.RandomState(seed)
    indices = rng.permutation(len(X_train))[:MAX_TRAIN]
    X_tr    = X_train[indices]
    y_tr    = y_train[indices]

    scaler  = StandardScaler()
    X_tr_sc = scaler.fit_transform(X_tr)
    X_te_sc = scaler.transform(X_test)

    print(f"  Training SVM on EfficientNetB0 binary features...")
    svm = SVC(
        kernel       = SVM_KERNEL,
        C            = SVM_C,
        gamma        = SVM_GAMMA,
        probability  = True,
        random_state = seed,
    )
    svm.fit(X_tr_sc, y_tr)
    print(f"  ✓ Training complete")

    y_pred = svm.predict(X_te_sc)
    y_prob = svm.predict_proba(X_te_sc)[:, 1]

    metrics         = compute_metrics_binary(y_test, y_pred, y_prob)
    metrics["run"]  = run_idx
    metrics["seed"] = seed
    all_metrics.append(metrics)

    all_run_results.append({
        "run"        : run_idx,
        "seed"       : seed,
        "accuracy"   : metrics["accuracy"],
        "precision"  : metrics["precision"],
        "recall"     : metrics["recall"],
        "specificity": metrics["specificity"],
        "f1"         : metrics["f1"],
        "auc"        : metrics["auc"],
    })

    print(f"\n  Run {run_idx} Results")
    print(f"    Accuracy     : {metrics['accuracy']:.4f}")
    print(f"    Precision    : {metrics['precision']:.4f}")
    print(f"    Sensitivity  : {metrics['recall']:.4f}")
    print(f"    Specificity  : {metrics['specificity']:.4f}")
    print(f"    F1 Score     : {metrics['f1']:.4f}")
    print(f"    AUC          : {metrics['auc']:.4f}")
    print(f"    TP={metrics['tp']}  TN={metrics['tn']}  "
          f"FP={metrics['fp']}  FN={metrics['fn']}")

    plot_confusion_matrix(metrics["cm"],  run_idx, PLOT_DIR)
    plot_roc_curve(metrics,               run_idx, PLOT_DIR)
    plot_metrics_table(metrics,           run_idx, PLOT_DIR)

# ── Step 3: Per-Run Summary Table ─────────────────────────────────────────────

col_run  = 6
col_seed = 8
col_acc  = 12
col_prec = 12
col_sens = 14
col_spec = 14
col_f1   = 10
col_auc  = 10

divider = "=" * (col_run + col_seed + col_acc + col_prec +
                 col_sens + col_spec + col_f1 + col_auc + 8)
thin    = "─" * (col_run + col_seed + col_acc + col_prec +
                 col_sens + col_spec + col_f1 + col_auc + 8)

print(f"\n{divider}")
print("  PER-RUN RESULTS — EfficientNetB0 Binary + SVM")
print(divider)
print(
    f"  {'Run':<{col_run}}"
    f"{'Seed':>{col_seed}}"
    f"{'Accuracy':>{col_acc}}"
    f"{'Precision':>{col_prec}}"
    f"{'Sensitivity':>{col_sens}}"
    f"{'Specificity':>{col_spec}}"
    f"{'F1 Score':>{col_f1}}"
    f"{'AUC':>{col_auc}}"
)
print(thin)

for r in all_run_results:
    print(
        f"  {r['run']:<{col_run}}"
        f"{r['seed']:>{col_seed}}"
        f"{r['accuracy']:>{col_acc}.4f}"
        f"{r['precision']:>{col_prec}.4f}"
        f"{r['recall']:>{col_sens}.4f}"
        f"{r['specificity']:>{col_spec}.4f}"
        f"{r['f1']:>{col_f1}.4f}"
        f"{r['auc']:>{col_auc}.4f}"
    )

print(thin)

# ── Step 4: Statistical Summary with Confidence Intervals ─────────────────────

print(f"\n{'─'*28}  Statistical Summary  {'─'*28}")
print(
    f"  {'Metric':<14}"
    f"{'Mean':>10}"
    f"{'Std':>10}"
    f"{'Min':>10}"
    f"{'Max':>10}"
    f"{'95% CI':>20}"
)
print(thin)

stat_metrics = {
    "Accuracy"   : [r["accuracy"]    for r in all_run_results],
    "Precision"  : [r["precision"]   for r in all_run_results],
    "Sensitivity": [r["recall"]      for r in all_run_results],
    "Specificity": [r["specificity"] for r in all_run_results],
    "F1 Score"   : [r["f1"]          for r in all_run_results],
    "AUC"        : [r["auc"]         for r in all_run_results],
}

for label, vals in stat_metrics.items():
    vals = np.array(vals)
    mean = np.mean(vals)
    std  = np.std(vals)
    mn   = np.min(vals)
    mx   = np.max(vals)
    ci   = stats.t.interval(
               0.95,
               df    = len(vals) - 1,
               loc   = mean,
               scale = stats.sem(vals)
           )
    print(
        f"  {label:<14}"
        f"{mean:>10.4f}"
        f"{std:>10.4f}"
        f"{mn:>10.4f}"
        f"{mx:>10.4f}"
        f"  [{ci[0]:.4f}, {ci[1]:.4f}]"
    )

print(divider)

# ── Step 5: Best Run ──────────────────────────────────────────────────────────

best_run = max(all_run_results, key=lambda x: x["auc"])

print(f"\n  Best run     : Run {best_run['run']} (by AUC)  "
      f"seed={best_run['seed']}")
print(f"  Accuracy     : {best_run['accuracy']:.4f}")
print(f"  Sensitivity  : {best_run['recall']:.4f}")
print(f"  Specificity  : {best_run['specificity']:.4f}")
print(f"  F1 Score     : {best_run['f1']:.4f}")
print(f"  AUC          : {best_run['auc']:.4f}")

# ── Step 6: Expose for comparison ─────────────────────────────────────────────

efficientnetb0_binary_svm_all_metrics     = all_metrics
efficientnetb0_binary_svm_all_run_results = all_run_results

print(f"\n  All plots saved to : {PLOT_DIR}")
print(f"\n  ✓ Fragment 3 complete.")
print(f"     efficientnetb0_binary_svm_all_metrics and")
print(f"     efficientnetb0_binary_svm_all_run_results ready.")
print(f"     Proceed to Fragment 4 — KNN on EfficientNetB0 binary features.\n")
# Out:
# ============================================================
#   Fragment 3 — EfficientNetB0 Binary + SVM  (5 Runs)
# ============================================================
#   Pipeline       : Binary — Mold vs No Mold
#   Feature source : EfficientNetB0 extracted (1280 features)
#   Kernel         : linear
#   C              : 1.0
#   Threshold      : 0.5
#   Seeds          : [27, 42, 99, 123, 256]
# ============================================================
#
# ============================================================
#   RUN 1 / 5  —  EfficientNetB0 Binary + SVM
#   Seed : 27
# ============================================================
#
#   Training SVM on EfficientNetB0 binary features...
#   ✓ Training complete
#
#   Run 1 Results
#     Accuracy     : 0.9230
#     Precision    : 0.9328
#     Sensitivity  : 0.9328
#     Specificity  : 0.9097
#     F1 Score     : 0.9328
#     AUC          : 0.9794
#     TP=347  TN=252  FP=25  FN=25
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_confusion_matrix_run1.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_roc_curve_run1.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_metrics_table_run1.png
#
# ============================================================
#   RUN 2 / 5  —  EfficientNetB0 Binary + SVM
#   Seed : 42
# ============================================================
#
#   Training SVM on EfficientNetB0 binary features...
#   ✓ Training complete
#
#   Run 2 Results
#     Accuracy     : 0.9260
#     Precision    : 0.9332
#     Sensitivity  : 0.9382
#     Specificity  : 0.9097
#     F1 Score     : 0.9357
#     AUC          : 0.9742
#     TP=349  TN=252  FP=25  FN=23
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_confusion_matrix_run2.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_roc_curve_run2.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_metrics_table_run2.png
#
# ============================================================
#   RUN 3 / 5  —  EfficientNetB0 Binary + SVM
#   Seed : 99
# ============================================================
#
#   Training SVM on EfficientNetB0 binary features...
#   ✓ Training complete
#
#   Run 3 Results
#     Accuracy     : 0.9337
#     Precision    : 0.9363
#     Sensitivity  : 0.9489
#     Specificity  : 0.9134
#     F1 Score     : 0.9426
#     AUC          : 0.9742
#     TP=353  TN=253  FP=24  FN=19
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_confusion_matrix_run3.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_roc_curve_run3.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_metrics_table_run3.png
#
# ============================================================
#   RUN 4 / 5  —  EfficientNetB0 Binary + SVM
#   Seed : 123
# ============================================================
#
#   Training SVM on EfficientNetB0 binary features...
#   ✓ Training complete
#
#   Run 4 Results
#     Accuracy     : 0.9322
#     Precision    : 0.9339
#     Sensitivity  : 0.9489
#     Specificity  : 0.9097
#     F1 Score     : 0.9413
#     AUC          : 0.9686
#     TP=353  TN=252  FP=25  FN=19
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_confusion_matrix_run4.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_roc_curve_run4.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_metrics_table_run4.png
#
# ============================================================
#   RUN 5 / 5  —  EfficientNetB0 Binary + SVM
#   Seed : 256
# ============================================================
#
#   Training SVM on EfficientNetB0 binary features...
#   ✓ Training complete
#
#   Run 5 Results
#     Accuracy     : 0.9230
#     Precision    : 0.9328
#     Sensitivity  : 0.9328
#     Specificity  : 0.9097
#     F1 Score     : 0.9328
#     AUC          : 0.9793
#     TP=347  TN=252  FP=25  FN=25
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_confusion_matrix_run5.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_roc_curve_run5.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm\efficientnetb0_binary_svm_metrics_table_run5.png
#
# ==============================================================================================
#   PER-RUN RESULTS — EfficientNetB0 Binary + SVM
# ==============================================================================================
#   Run       Seed    Accuracy   Precision   Sensitivity   Specificity  F1 Score       AUC
# ──────────────────────────────────────────────────────────────────────────────────────────────
#   1           27      0.9230      0.9328        0.9328        0.9097    0.9328    0.9794
#   2           42      0.9260      0.9332        0.9382        0.9097    0.9357    0.9742
#   3           99      0.9337      0.9363        0.9489        0.9134    0.9426    0.9742
#   4          123      0.9322      0.9339        0.9489        0.9097    0.9413    0.9686
#   5          256      0.9230      0.9328        0.9328        0.9097    0.9328    0.9793
# ──────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────  Statistical Summary  ────────────────────────────
#   Metric              Mean       Std       Min       Max              95% CI
# ──────────────────────────────────────────────────────────────────────────────────────────────
#   Accuracy          0.9276    0.0046    0.9230    0.9337  [0.9212, 0.9339]
#   Precision         0.9338    0.0013    0.9328    0.9363  [0.9319, 0.9356]
#   Sensitivity       0.9403    0.0073    0.9328    0.9489  [0.9302, 0.9504]
#   Specificity       0.9105    0.0014    0.9097    0.9134  [0.9085, 0.9125]
#   F1 Score          0.9370    0.0042    0.9328    0.9426  [0.9312, 0.9428]
#   AUC               0.9751    0.0040    0.9686    0.9794  [0.9696, 0.9807]
# ==============================================================================================
#
#   Best run     : Run 1 (by AUC)  seed=27
#   Accuracy     : 0.9230
#   Sensitivity  : 0.9328
#   Specificity  : 0.9097
#   F1 Score     : 0.9328
#   AUC          : 0.9794
#
#   All plots saved to : D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_svm
#
#   ✓ Fragment 3 complete.
#      efficientnetb0_binary_svm_all_metrics and
#      efficientnetb0_binary_svm_all_run_results ready.
#      Proceed to Fragment 4 — KNN on EfficientNetB0 binary features.

# %%
"""
Fragment 4 — KNN Classification on EfficientNetB0 Binary Features (5 Runs)
============================================================================
EfficientNetB0 Binary Hybrid Pipeline — Feature Extraction + KNN

- Reuses EfficientNetB0 binary extracted features already on disk
- Trains KNN 5 times using different random seeds
- Each run shuffles train features differently
- Evaluates on test features — never seen during training
- Computes full binary metrics + 95% confidence intervals
"""

import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    confusion_matrix,
    roc_curve,
    auc,
)
import scipy.stats as stats

# ── Configuration ─────────────────────────────────────────────────────────────

SAVE_DIR   = r"D:\Mold Studies Binary\Models"
PLOT_DIR   = os.path.join(SAVE_DIR, "plots", "efficientnetb0_binary_knn")
TOTAL_RUNS = 5
SEEDS      = [27, 42, 99, 123, 256]

os.makedirs(PLOT_DIR, exist_ok=True)

# ── KNN Parameters ────────────────────────────────────────────────────────────

KNN_N_NEIGHBORS = 5
KNN_METRIC      = "euclidean"
KNN_WEIGHTS     = "distance"
THRESHOLD       = 0.5

# ── Step 1: Helper Functions ──────────────────────────────────────────────────

def compute_metrics_binary(y_true, y_pred, y_prob):
    """
    Computes full binary evaluation metrics.
    y_prob is the probability for the positive class (column 1).
    """
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()

    precision   = tp / (tp + fp + 1e-7)
    recall      = tp / (tp + fn + 1e-7)
    specificity = tn / (tn + fp + 1e-7)
    f1          = 2 * precision * recall / (precision + recall + 1e-7)
    accuracy    = (tp + tn) / (tp + tn + fp + fn + 1e-7)

    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc     = auc(fpr, tpr)

    return {
        "cm"         : cm,
        "tp"         : int(tp),
        "tn"         : int(tn),
        "fp"         : int(fp),
        "fn"         : int(fn),
        "accuracy"   : accuracy,
        "precision"  : precision,
        "recall"     : recall,
        "specificity": specificity,
        "f1"         : f1,
        "fpr"        : fpr,
        "tpr"        : tpr,
        "auc"        : roc_auc,
    }


def plot_confusion_matrix(cm, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(7, 6))
    im = ax.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
    plt.colorbar(im, ax=ax)
    ax.set(
        xticks      = np.arange(NUM_CLASSES),
        yticks      = np.arange(NUM_CLASSES),
        xticklabels = CLASS_NAMES,
        yticklabels = CLASS_NAMES,
        title       = f"EfficientNetB0 Binary + KNN — Confusion Matrix — Run {run_idx}",
        ylabel      = "True Label",
        xlabel      = "Predicted Label",
    )
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right")
    thresh = cm.max() / 2.0
    for i in range(NUM_CLASSES):
        for j in range(NUM_CLASSES):
            ax.text(j, i, format(cm[i, j], "d"),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"efficientnetb0_binary_knn_confusion_matrix_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    plt.close()
    print(f"  Saved: {path}")


def plot_roc_curve(metrics, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(
        metrics["fpr"],
        metrics["tpr"],
        color = "steelblue",
        lw    = 2,
        label = f"ROC Curve (AUC = {metrics['auc']:.4f})"
    )
    ax.plot([0, 1], [0, 1], "k--", label="Random classifier")
    ax.set(
        title  = f"EfficientNetB0 Binary + KNN — ROC Curve — Run {run_idx}",
        xlabel = "False Positive Rate",
        ylabel = "True Positive Rate (Sensitivity)",
        xlim   = [0.0, 1.0],
        ylim   = [0.0, 1.05],
    )
    ax.legend(loc="lower right", fontsize=9)
    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"efficientnetb0_binary_knn_roc_curve_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    plt.close()
    print(f"  Saved: {path}")


def plot_metrics_table(metrics, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(12, 4))
    ax.axis("off")
    rows = [[
        CLASS_NAMES[1],
        f"{metrics['precision']:.4f}",
        f"{metrics['recall']:.4f}",
        f"{metrics['specificity']:.4f}",
        f"{metrics['f1']:.4f}",
        f"{metrics['auc']:.4f}",
        f"{metrics['tp']}",
        f"{metrics['fp']}",
        f"{metrics['fn']}",
        f"{metrics['tn']}",
    ]]
    col_labels = ["Class", "Precision", "Sensitivity",
                  "Specificity", "F1", "AUC",
                  "TP", "FP", "FN", "TN"]
    table = ax.table(
        cellText  = rows,
        colLabels = col_labels,
        loc       = "center",
        cellLoc   = "center",
    )
    table.auto_set_font_size(False)
    table.set_fontsize(9)
    table.scale(1.2, 2.0)
    for j in range(len(col_labels)):
        table[0, j].set_facecolor("#d0e8ff")
    ax.set_title(
        f"EfficientNetB0 Binary + KNN — Metrics — Run {run_idx}  "
        f"(Accuracy: {metrics['accuracy']:.4f})",
        fontsize=12, pad=20
    )
    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"efficientnetb0_binary_knn_metrics_table_run{run_idx}.png")
    plt.savefig(path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close()
    print(f"  Saved: {path}")

# ── Step 2: 5-Run Training Loop ───────────────────────────────────────────────

print("=" * 60)
print("  Fragment 4 — EfficientNetB0 Binary + KNN  (5 Runs)")
print("=" * 60)
print(f"  Pipeline       : Binary — Mold vs No Mold")
print(f"  Feature source : EfficientNetB0 extracted (1280 features)")
print(f"  N Neighbours   : {KNN_N_NEIGHBORS}")
print(f"  Metric         : {KNN_METRIC}")
print(f"  Weights        : {KNN_WEIGHTS}")
print(f"  Seeds          : {SEEDS}")
print("=" * 60)

all_metrics     = []
all_run_results = []

for run_idx, seed in enumerate(SEEDS, 1):

    print(f"\n{'='*60}")
    print(f"  RUN {run_idx} / {TOTAL_RUNS}  —  EfficientNetB0 Binary + KNN")
    print(f"  Seed : {seed}")
    print(f"{'='*60}\n")

    MAX_TRAIN = 3000

    rng     = np.random.RandomState(seed)
    indices = rng.permutation(len(X_train))[:MAX_TRAIN]
    X_tr    = X_train[indices]
    y_tr    = y_train[indices]

    scaler  = StandardScaler()
    X_tr_sc = scaler.fit_transform(X_tr)
    X_te_sc = scaler.transform(X_test)

    print(f"  Training KNN on EfficientNetB0 binary features...")
    knn = KNeighborsClassifier(
        n_neighbors = KNN_N_NEIGHBORS,
        metric      = KNN_METRIC,
        weights     = KNN_WEIGHTS,
        n_jobs      = -1,
    )
    knn.fit(X_tr_sc, y_tr)
    print(f"  ✓ Training complete")

    print(f"  Predicting...")
    y_pred = knn.predict(X_te_sc)
    y_prob = knn.predict_proba(X_te_sc)[:, 1]

    metrics         = compute_metrics_binary(y_test, y_pred, y_prob)
    metrics["run"]  = run_idx
    metrics["seed"] = seed
    all_metrics.append(metrics)

    all_run_results.append({
        "run"        : run_idx,
        "seed"       : seed,
        "accuracy"   : metrics["accuracy"],
        "precision"  : metrics["precision"],
        "recall"     : metrics["recall"],
        "specificity": metrics["specificity"],
        "f1"         : metrics["f1"],
        "auc"        : metrics["auc"],
    })

    print(f"\n  Run {run_idx} Results")
    print(f"    Accuracy     : {metrics['accuracy']:.4f}")
    print(f"    Precision    : {metrics['precision']:.4f}")
    print(f"    Sensitivity  : {metrics['recall']:.4f}")
    print(f"    Specificity  : {metrics['specificity']:.4f}")
    print(f"    F1 Score     : {metrics['f1']:.4f}")
    print(f"    AUC          : {metrics['auc']:.4f}")
    print(f"    TP={metrics['tp']}  TN={metrics['tn']}  "
          f"FP={metrics['fp']}  FN={metrics['fn']}")

    plot_confusion_matrix(metrics["cm"],  run_idx, PLOT_DIR)
    plot_roc_curve(metrics,               run_idx, PLOT_DIR)
    plot_metrics_table(metrics,           run_idx, PLOT_DIR)

# ── Step 3: Per-Run Summary Table ─────────────────────────────────────────────

col_run  = 6
col_seed = 8
col_acc  = 12
col_prec = 12
col_sens = 14
col_spec = 14
col_f1   = 10
col_auc  = 10

divider = "=" * (col_run + col_seed + col_acc + col_prec +
                 col_sens + col_spec + col_f1 + col_auc + 8)
thin    = "─" * (col_run + col_seed + col_acc + col_prec +
                 col_sens + col_spec + col_f1 + col_auc + 8)

print(f"\n{divider}")
print("  PER-RUN RESULTS — EfficientNetB0 Binary + KNN")
print(divider)
print(
    f"  {'Run':<{col_run}}"
    f"{'Seed':>{col_seed}}"
    f"{'Accuracy':>{col_acc}}"
    f"{'Precision':>{col_prec}}"
    f"{'Sensitivity':>{col_sens}}"
    f"{'Specificity':>{col_spec}}"
    f"{'F1 Score':>{col_f1}}"
    f"{'AUC':>{col_auc}}"
)
print(thin)

for r in all_run_results:
    print(
        f"  {r['run']:<{col_run}}"
        f"{r['seed']:>{col_seed}}"
        f"{r['accuracy']:>{col_acc}.4f}"
        f"{r['precision']:>{col_prec}.4f}"
        f"{r['recall']:>{col_sens}.4f}"
        f"{r['specificity']:>{col_spec}.4f}"
        f"{r['f1']:>{col_f1}.4f}"
        f"{r['auc']:>{col_auc}.4f}"
    )

print(thin)

# ── Step 4: Statistical Summary with Confidence Intervals ─────────────────────

print(f"\n{'─'*28}  Statistical Summary  {'─'*28}")
print(
    f"  {'Metric':<14}"
    f"{'Mean':>10}"
    f"{'Std':>10}"
    f"{'Min':>10}"
    f"{'Max':>10}"
    f"{'95% CI':>20}"
)
print(thin)

stat_metrics = {
    "Accuracy"   : [r["accuracy"]    for r in all_run_results],
    "Precision"  : [r["precision"]   for r in all_run_results],
    "Sensitivity": [r["recall"]      for r in all_run_results],
    "Specificity": [r["specificity"] for r in all_run_results],
    "F1 Score"   : [r["f1"]          for r in all_run_results],
    "AUC"        : [r["auc"]         for r in all_run_results],
}

for label, vals in stat_metrics.items():
    vals = np.array(vals)
    mean = np.mean(vals)
    std  = np.std(vals)
    mn   = np.min(vals)
    mx   = np.max(vals)
    ci   = stats.t.interval(
               0.95,
               df    = len(vals) - 1,
               loc   = mean,
               scale = stats.sem(vals)
           )
    print(
        f"  {label:<14}"
        f"{mean:>10.4f}"
        f"{std:>10.4f}"
        f"{mn:>10.4f}"
        f"{mx:>10.4f}"
        f"  [{ci[0]:.4f}, {ci[1]:.4f}]"
    )

print(divider)

# ── Step 5: SVM vs KNN Comparison ─────────────────────────────────────────────

print(f"\n{'='*60}")
print(f"  EfficientNetB0 Binary HYBRID — SVM vs KNN Comparison")
print(f"{'='*60}")
print(f"  {'Metric':<14} {'SVM Mean':>12} {'KNN Mean':>12} {'Winner':>10}")
print(f"  {'─'*50}")

comparison_metrics = {
    "Accuracy"   : "accuracy",
    "Precision"  : "precision",
    "Sensitivity": "recall",
    "Specificity": "specificity",
    "F1 Score"   : "f1",
    "AUC"        : "auc",
}

for label, key in comparison_metrics.items():
    svm_mean = np.mean(
        [r[key] for r in efficientnetb0_binary_svm_all_run_results])
    knn_mean = np.mean([r[key] for r in all_run_results])
    winner   = "SVM" if svm_mean >= knn_mean else "KNN"
    print(
        f"  {label:<14}"
        f"{svm_mean:>12.4f}"
        f"{knn_mean:>12.4f}"
        f"{winner:>10}"
    )

print(f"{'='*60}")

# ── Step 6: Expose for comparison ─────────────────────────────────────────────

efficientnetb0_binary_knn_all_metrics     = all_metrics
efficientnetb0_binary_knn_all_run_results = all_run_results

print(f"\n  All plots saved to : {PLOT_DIR}")
print(f"\n  ✓ Fragment 4 complete.")
print(f"     efficientnetb0_binary_knn_all_metrics and")
print(f"     efficientnetb0_binary_knn_all_run_results ready.")
print(f"     Proceed to Binary Fragment 5 — Cross-Model Comparison.\n")
# Out:
# ============================================================
#   Fragment 4 — EfficientNetB0 Binary + KNN  (5 Runs)
# ============================================================
#   Pipeline       : Binary — Mold vs No Mold
#   Feature source : EfficientNetB0 extracted (1280 features)
#   N Neighbours   : 5
#   Metric         : euclidean
#   Weights        : distance
#   Seeds          : [27, 42, 99, 123, 256]
# ============================================================
#
# ============================================================
#   RUN 1 / 5  —  EfficientNetB0 Binary + KNN
#   Seed : 27
# ============================================================
#
#   Training KNN on EfficientNetB0 binary features...
#   ✓ Training complete
#   Predicting...
#
#   Run 1 Results
#     Accuracy     : 0.8998
#     Precision    : 0.9252
#     Sensitivity  : 0.8978
#     Specificity  : 0.9025
#     F1 Score     : 0.9113
#     AUC          : 0.9693
#     TP=334  TN=250  FP=27  FN=38
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_confusion_matrix_run1.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_roc_curve_run1.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_metrics_table_run1.png
#
# ============================================================
#   RUN 2 / 5  —  EfficientNetB0 Binary + KNN
#   Seed : 42
# ============================================================
#
#   Training KNN on EfficientNetB0 binary features...
#   ✓ Training complete
#   Predicting...
#
#   Run 2 Results
#     Accuracy     : 0.9060
#     Precision    : 0.9081
#     Sensitivity  : 0.9301
#     Specificity  : 0.8736
#     F1 Score     : 0.9190
#     AUC          : 0.9711
#     TP=346  TN=242  FP=35  FN=26
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_confusion_matrix_run2.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_roc_curve_run2.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_metrics_table_run2.png
#
# ============================================================
#   RUN 3 / 5  —  EfficientNetB0 Binary + KNN
#   Seed : 99
# ============================================================
#
#   Training KNN on EfficientNetB0 binary features...
#   ✓ Training complete
#   Predicting...
#
#   Run 3 Results
#     Accuracy     : 0.9276
#     Precision    : 0.9452
#     Sensitivity  : 0.9274
#     Specificity  : 0.9278
#     F1 Score     : 0.9362
#     AUC          : 0.9799
#     TP=345  TN=257  FP=20  FN=27
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_confusion_matrix_run3.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_roc_curve_run3.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_metrics_table_run3.png
#
# ============================================================
#   RUN 4 / 5  —  EfficientNetB0 Binary + KNN
#   Seed : 123
# ============================================================
#
#   Training KNN on EfficientNetB0 binary features...
#   ✓ Training complete
#   Predicting...
#
#   Run 4 Results
#     Accuracy     : 0.8952
#     Precision    : 0.9108
#     Sensitivity  : 0.9059
#     Specificity  : 0.8809
#     F1 Score     : 0.9084
#     AUC          : 0.9644
#     TP=337  TN=244  FP=33  FN=35
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_confusion_matrix_run4.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_roc_curve_run4.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_metrics_table_run4.png
#
# ============================================================
#   RUN 5 / 5  —  EfficientNetB0 Binary + KNN
#   Seed : 256
# ============================================================
#
#   Training KNN on EfficientNetB0 binary features...
#   ✓ Training complete
#   Predicting...
#
#   Run 5 Results
#     Accuracy     : 0.9014
#     Precision    : 0.9231
#     Sensitivity  : 0.9032
#     Specificity  : 0.8989
#     F1 Score     : 0.9130
#     AUC          : 0.9690
#     TP=336  TN=249  FP=28  FN=36
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_confusion_matrix_run5.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_roc_curve_run5.png
#   Saved: D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn\efficientnetb0_binary_knn_metrics_table_run5.png
#
# ==============================================================================================
#   PER-RUN RESULTS — EfficientNetB0 Binary + KNN
# ==============================================================================================
#   Run       Seed    Accuracy   Precision   Sensitivity   Specificity  F1 Score       AUC
# ──────────────────────────────────────────────────────────────────────────────────────────────
#   1           27      0.8998      0.9252        0.8978        0.9025    0.9113    0.9693
#   2           42      0.9060      0.9081        0.9301        0.8736    0.9190    0.9711
#   3           99      0.9276      0.9452        0.9274        0.9278    0.9362    0.9799
#   4          123      0.8952      0.9108        0.9059        0.8809    0.9084    0.9644
#   5          256      0.9014      0.9231        0.9032        0.8989    0.9130    0.9690
# ──────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────  Statistical Summary  ────────────────────────────
#   Metric              Mean       Std       Min       Max              95% CI
# ──────────────────────────────────────────────────────────────────────────────────────────────
#   Accuracy          0.9060    0.0113    0.8952    0.9276  [0.8903, 0.9217]
#   Precision         0.9225    0.0132    0.9081    0.9452  [0.9042, 0.9408]
#   Sensitivity       0.9129    0.0132    0.8978    0.9301  [0.8945, 0.9313]
#   Specificity       0.8968    0.0189    0.8736    0.9278  [0.8705, 0.9230]
#   F1 Score          0.9176    0.0099    0.9084    0.9362  [0.9038, 0.9314]
#   AUC               0.9707    0.0051    0.9644    0.9799  [0.9637, 0.9778]
# ==============================================================================================
#
# ============================================================
#   EfficientNetB0 Binary HYBRID — SVM vs KNN Comparison
# ============================================================
#   Metric             SVM Mean     KNN Mean     Winner
#   ──────────────────────────────────────────────────
#   Accuracy            0.9276      0.9060       SVM
#   Precision           0.9338      0.9225       SVM
#   Sensitivity         0.9403      0.9129       SVM
#   Specificity         0.9105      0.8968       SVM
#   F1 Score            0.9370      0.9176       SVM
#   AUC                 0.9751      0.9707       SVM
# ============================================================
#
#   All plots saved to : D:\Mold Studies Binary\Models\plots\efficientnetb0_binary_knn
#
#   ✓ Fragment 4 complete.
#      efficientnetb0_binary_knn_all_metrics and
#      efficientnetb0_binary_knn_all_run_results ready.
#      Proceed to Binary Fragment 5 — Cross-Model Comparison.
