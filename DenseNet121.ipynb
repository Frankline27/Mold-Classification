# %%
"""
Fragment 1 — Data Loading with Dynamic Per-Class Augmentation
==============================================================
DenseNet121 Binary Mould Classification Pipeline — Mold vs No Mold

- Discovers mold and no mold classes automatically
- Augments each class up to MAX_TOTAL images then stops
- Saves augmented images to a separate 'augmented' folder
- Builds train and validation generators for model training
- Binary classification — sigmoid output, binary cross-entropy
"""

import os
import numpy as np
from pathlib import Path
from tensorflow.keras.preprocessing.image import (
    ImageDataGenerator,
    load_img,
    img_to_array,
)

# ── Configuration ─────────────────────────────────────────────────────────────

MODEL_NAME  = "DenseNet121"
DATA_DIR    = r"D:\Mold Studies Binary\Mould Binary Classification"
TRAIN_DIR   = os.path.join(DATA_DIR, "train")
VALID_DIR   = os.path.join(DATA_DIR, "val")
AUG_DIR     = os.path.join(DATA_DIR, "augmented")

IMG_SIZE    = (224, 224)
BATCH_SIZE  = 32
MAX_TOTAL   = 5000

# ── Augmentation Parameters ───────────────────────────────────────────────────

AUG_PARAMS = dict(
    rotation_range      = 20,
    width_shift_range   = 0.1,
    height_shift_range  = 0.1,
    horizontal_flip     = True,
    vertical_flip       = False,
    zoom_range          = 0.15,
    brightness_range    = [0.75, 1.25],
    shear_range         = 0.1,
    channel_shift_range = 10,
    fill_mode           = "nearest",
)

# ── Step 1: Discover Classes ──────────────────────────────────────────────────

def discover_classes(train_dir: str) -> list:
    classes = sorted([
        d.name for d in Path(train_dir).iterdir()
        if d.is_dir()
    ])
    print("=" * 60)
    print(f"  Step 1 — Discovered Classes")
    print("=" * 60)
    print(f"  Model         : {MODEL_NAME}")
    print(f"  Pipeline      : Binary — Mold vs No Mold")
    print()
    for i, cls in enumerate(classes, 1):
        src_count = sum(
            1 for f in (Path(train_dir) / cls).iterdir()
            if f.suffix.lower() in {".jpg", ".jpeg", ".png",
                                    ".bmp", ".tiff", ".webp"}
        )
        needed = max(0, MAX_TOTAL - src_count)
        print(f"  {i:>2}. {cls:<22} originals: {src_count:>4}"
              f"   to generate: {needed:>4}")
    print("=" * 60)
    return classes

# ── Step 2: Augment and Save to Disk ─────────────────────────────────────────

def augment_and_save(train_dir: str, aug_dir: str, classes: list,
                     aug_params: dict) -> None:
    aug_gen  = ImageDataGenerator(**aug_params)
    IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".tiff", ".webp"}

    print("\n" + "=" * 65)
    print(f"  Step 2 — Augmenting & Saving Images to Disk")
    print("=" * 65)
    print(f"  Model       : {MODEL_NAME}")
    print(f"  Source      : {train_dir}")
    print(f"  Destination : {aug_dir}")
    print(f"  Max total   : {MAX_TOTAL} images per class")
    print("=" * 65)

    total_original  = 0
    total_augmented = 0

    for cls in classes:
        src_cls_dir = Path(train_dir) / cls
        dst_cls_dir = Path(aug_dir)   / cls
        dst_cls_dir.mkdir(parents=True, exist_ok=True)

        image_files = [
            f for f in src_cls_dir.iterdir()
            if f.suffix.lower() in IMG_EXTS
            and "_aug_" not in f.stem
        ]

        for img_path in image_files:
            dst = dst_cls_dir / img_path.name
            if not dst.exists():
                img = load_img(img_path, target_size=IMG_SIZE)
                img.save(dst)

        cls_original  = len(image_files)
        cls_aug_count = 0
        needed        = MAX_TOTAL - cls_original

        if needed <= 0:
            print(f"  {cls:<22} | Original: {cls_original:>4}  "
                  f"Augmented:    0  "
                  f"Total: {cls_original:>4}  (no aug needed)")
            total_original += cls_original
            continue

        aug_counter = 0

        while cls_aug_count < needed:
            img_path    = image_files[aug_counter % len(image_files)]
            aug_counter += 1

            img = load_img(img_path, target_size=IMG_SIZE)
            arr = np.expand_dims(img_to_array(img), axis=0)

            aug_iter = aug_gen.flow(
                arr,
                batch_size  = 1,
                save_to_dir = str(dst_cls_dir),
                save_prefix = f"aug_{img_path.stem}_{aug_counter:04d}",
                save_format = "jpg",
            )
            next(aug_iter)
            cls_aug_count += 1

        total_original  += cls_original
        total_augmented += cls_aug_count

        print(f"  {cls:<22} | Original: {cls_original:>4}  "
              f"Augmented: {cls_aug_count:>4}  "
              f"Total: {cls_original + cls_aug_count:>4}")

    print("\n" + "=" * 65)
    print(f"  {'TOTAL':<22} | Original: {total_original:>4}  "
          f"Augmented: {total_augmented:>4}  "
          f"Total: {total_original + total_augmented:>4}")
    print("=" * 65)
    print(f"\n  ✓ Augmented images saved to: {aug_dir}\n")

# ── Step 3: Build Generators ──────────────────────────────────────────────────

def build_generators(aug_dir: str, valid_dir: str):
    """
    DenseNet121 requires preprocess_input from densenet module.
    Applied here instead of simple rescale 1/255.
    class_mode = 'binary' for mold/no mold classification.
    """
    from tensorflow.keras.applications.densenet import preprocess_input

    train_datagen   = ImageDataGenerator(
                          preprocessing_function=preprocess_input)
    train_generator = train_datagen.flow_from_directory(
        aug_dir,
        target_size = IMG_SIZE,
        batch_size  = BATCH_SIZE,
        class_mode  = "binary",
        shuffle     = True,
    )

    valid_datagen   = ImageDataGenerator(
                          preprocessing_function=preprocess_input)
    valid_generator = valid_datagen.flow_from_directory(
        valid_dir,
        target_size = IMG_SIZE,
        batch_size  = BATCH_SIZE,
        class_mode  = "binary",
        shuffle     = False,
    )

    print("\n" + "=" * 60)
    print(f"  Step 3 — Data Generators Ready")
    print("=" * 60)
    print(f"  Model         : {MODEL_NAME}")
    print(f"  Pipeline      : Binary — Mold vs No Mold")
    print(f"  Preprocessing : preprocess_input (DenseNet121)")
    print(f"  Train source  : augmented/")
    print(f"  Valid source  : val/")
    print(f"  Train samples : {train_generator.samples}")
    print(f"  Valid samples : {valid_generator.samples}")
    print(f"  Class indices : {train_generator.class_indices}")
    print(f"  Image size    : {IMG_SIZE}")
    print(f"  Batch size    : {BATCH_SIZE}")
    print(f"  Class mode    : binary (0/1 labels)")
    print("=" * 60)

    return train_generator, valid_generator

# ── Run Fragment 1 ────────────────────────────────────────────────────────────

classes = discover_classes(TRAIN_DIR)
augment_and_save(TRAIN_DIR, AUG_DIR, classes, AUG_PARAMS)
train_generator, valid_generator = build_generators(AUG_DIR, VALID_DIR)

CLASS_NAMES = list(train_generator.class_indices.keys())
NUM_CLASSES = len(CLASS_NAMES)

print("\n  ✓ Fragment 1 complete.")
print(f"     Model         : {MODEL_NAME}")
print(f"     Classes       : {CLASS_NAMES}")
print(f"     Class mode    : binary (0/1 labels)")
print(f"     train_generator and valid_generator ready.")
print(f"     Proceed to Fragment 2 — {MODEL_NAME} Model Training.\n")
# Out:
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ============================================================
#   Step 1 — Discovered Classes
# ============================================================
#   Model         : DenseNet121
#   Pipeline      : Binary — Mold vs No Mold
#
#    1. Mold                   originals: 1288   to generate: 3712
#    2. No mold                originals: 1736   to generate: 3264
# ============================================================
#
# =================================================================
#   Step 2 — Augmenting & Saving Images to Disk
# =================================================================
#   Model       : DenseNet121
#   Source      : D:\Mold Studies Binary\Mould Binary Classification\train
#   Destination : D:\Mold Studies Binary\Mould Binary Classification\augmented
#   Max total   : 5000 images per class
# =================================================================
#   Mold                   | Original: 1288  Augmented: 3712  Total: 5000
#   No mold                | Original: 1736  Augmented: 3264  Total: 5000
#
# =================================================================
#   TOTAL                  | Original: 3024  Augmented: 6976  Total: 10000
# =================================================================
#
#   ✓ Augmented images saved to: D:\Mold Studies Binary\Mould Binary Classification\augmented
#
# Found 65785 images belonging to 2 classes.
# Found 648 images belonging to 2 classes.
#
# ============================================================
#   Step 3 — Data Generators Ready
# ============================================================
#   Model         : DenseNet121
#   Pipeline      : Binary — Mold vs No Mold
#   Preprocessing : preprocess_input (DenseNet121)
#   Train source  : augmented/
#   Valid source  : val/
#   Train samples : 65785
#   Valid samples : 648
#   Class indices : {'Mold': 0, 'No mold': 1}
#   Image size    : (224, 224)
#   Batch size    : 32
#   Class mode    : binary (0/1 labels)
# ============================================================
#
#   ✓ Fragment 1 complete.
#      Model         : DenseNet121
#      Classes       : ['Mold', 'No mold']
#      Class mode    : binary (0/1 labels)
#      train_generator and valid_generator ready.
#      Proceed to Fragment 2 — DenseNet121 Model Training.

# %%
import tensorflow as tf
import os

path = r"D:\Mold Studies Binary\Models\densenet121_binary_best.keras"
print(f"File size: {os.path.getsize(path) / 1024 / 1024:.1f} MB")

# Try loading it
model = tf.keras.models.load_model(path)
print("Output shape:", model.output_shape)
print("Total params:", model.count_params())
# Out:
# File size: 31.6 MB
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Output shape: (None, 1)
# Total params: 7337025

# %%
"""
Fragment 2 — DenseNet121 Model Building with Transfer Learning
==============================================================
Binary Mould Classification Pipeline — Mold vs No Mold

- Loads DenseNet121 with ImageNet weights
- Accepts learning rate, dropout rate and unfreeze depth as inputs
- Freezes base layers except last N unfrozen layers
- BatchNormalization layers always kept frozen (DenseNet requirement)
- Adds custom binary classification head
- Sigmoid output with binary cross-entropy loss
- Compiled and ready for training
"""

import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D,
    Dense,
    Dropout,
    BatchNormalization,
)
from tensorflow.keras.optimizers import Adam

# ── Configuration ─────────────────────────────────────────────────────────────

IMG_SIZE    = (224, 224)
IMG_SHAPE   = IMG_SIZE + (3,)
NUM_CLASSES = len(train_generator.class_indices)
CLASS_NAMES = list(train_generator.class_indices.keys())

# ── Default values ────────────────────────────────────────────────────────────

DEFAULT_LEARNING_RATE   = 1e-4
DEFAULT_DROPOUT_RATE    = 0.3
DEFAULT_UNFREEZE_LAYERS = 0
EPOCHS                  = 25

# ── Step 1: Model Builder ─────────────────────────────────────────────────────

def build_densenet121_binary(learning_rate, dropout_rate, unfreeze_layers,
                              epochs=EPOCHS):
    """
    Builds and compiles DenseNet121 for binary classification.

    Parameters
    ----------
    learning_rate   : float — Adam optimizer learning rate
    dropout_rate    : float — dropout applied in classification head
    unfreeze_layers : int   — number of base layers unfrozen from the top
                              0 = fully frozen, feature extraction only
    epochs          : int   — number of training epochs

    DenseNet121 note:
    - BatchNormalization layers are always kept frozen regardless of
      unfreeze_layers setting — unfreezing BN in DenseNet degrades
      performance due to its dense connectivity pattern
    - Output: Dense(1, sigmoid) with binary_crossentropy loss
    """

    # ── Load DenseNet121 with ImageNet weights ────────────────────────────────
    base_model = DenseNet121(
        input_shape = IMG_SHAPE,
        include_top = False,
        weights     = "imagenet"
    )

    # ── Freeze all base layers first ──────────────────────────────────────────
    base_model.trainable = False

    # ── Unfreeze last N layers — always skip BatchNorm ────────────────────────
    if unfreeze_layers > 0:
        for layer in base_model.layers[-unfreeze_layers:]:
            if not isinstance(layer, tf.keras.layers.BatchNormalization):
                layer.trainable = True

    # ── Binary classification head ────────────────────────────────────────────
    x      = base_model.output
    x      = GlobalAveragePooling2D(name="global_avg_pool")(x)
    x      = BatchNormalization(name="head_batch_norm")(x)
    x      = Dense(256, activation="relu", name="dense_256")(x)
    x      = Dropout(dropout_rate, name="dropout_1")(x)
    x      = Dense(128, activation="relu", name="dense_128")(x)
    x      = Dropout(dropout_rate / 2, name="dropout_2")(x)
    output = Dense(1, activation="sigmoid", name="output")(x)

    # ── Assemble model ────────────────────────────────────────────────────────
    model = Model(inputs=base_model.input, outputs=output)

    # ── Compile ───────────────────────────────────────────────────────────────
    model.compile(
        optimizer = Adam(learning_rate=learning_rate),
        loss      = "binary_crossentropy",
        metrics   = [
            "accuracy",
            tf.keras.metrics.AUC(name="auc"),
        ]
    )

    return model

# ── Step 2: Build default model and print summary ─────────────────────────────

model = build_densenet121_binary(
    learning_rate   = DEFAULT_LEARNING_RATE,
    dropout_rate    = DEFAULT_DROPOUT_RATE,
    unfreeze_layers = DEFAULT_UNFREEZE_LAYERS,
)

total_params     = model.count_params()
trainable_params = sum(tf.size(w).numpy() for w in model.trainable_weights)
frozen_params    = sum(tf.size(w).numpy() for w in model.non_trainable_weights)

unfrozen_base = sum(
    1 for l in model.layers
    if l.trainable and l.name not in
    ["global_avg_pool", "head_batch_norm",
     "dense_256", "dropout_1",
     "dense_128", "dropout_2", "output"]
)

print("=" * 60)
print("  Fragment 2 — DenseNet121 Binary Classification")
print("=" * 60)

print("\n  ── Inputs ──────────────────────────────────────────")
print(f"  Learning rate    : {DEFAULT_LEARNING_RATE}")
print(f"  Dropout rate     : {DEFAULT_DROPOUT_RATE}")
print(f"  Unfreeze layers  : {DEFAULT_UNFREEZE_LAYERS}")

print("\n  ── Base Model ──────────────────────────────────────")
print(f"  Architecture     : DenseNet121")
print(f"  Weights          : ImageNet ✓")
print(f"  Input shape      : {IMG_SHAPE}")
print(f"  Unfrozen layers  : {unfrozen_base}")
print(f"  BN always frozen : ✓ (DenseNet requirement)")

print("\n  ── Classification Head ─────────────────────────────")
print(f"  GlobalAveragePooling2D")
print(f"  BatchNormalization")
print(f"  Dense(256, relu)")
print(f"  Dropout({DEFAULT_DROPOUT_RATE})")
print(f"  Dense(128, relu)")
print(f"  Dropout({DEFAULT_DROPOUT_RATE / 2})")
print(f"  Dense(1, sigmoid)  ← binary output")

print("\n  ── Loss & Metrics ──────────────────────────────────")
print(f"  Loss             : binary_crossentropy")
print(f"  Metrics          : accuracy, AUC")
print(f"  Classes          : {CLASS_NAMES}")
print(f"  Class indices    : {train_generator.class_indices}")

print("\n  ── Parameters ──────────────────────────────────────")
print(f"  Total params     : {total_params:,}")
print(f"  Trainable        : {trainable_params:,}")
print(f"  Frozen           : {frozen_params:,}")

print("\n  ── Training ────────────────────────────────────────")
print(f"  Epochs           : {EPOCHS}")
print(f"  Optimizer        : Adam(lr={DEFAULT_LEARNING_RATE})")
print("=" * 60)

print("\n  ✓ Fragment 2 complete. build_densenet121_binary() is ready.")
print("     Proceed to Fragment 3 — Training.\n")
# Out:
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# ============================================================
#   Fragment 2 — DenseNet121 Binary Classification
# ============================================================
#
#   ── Inputs ──────────────────────────────────────────
#   Learning rate    : 0.0001
#   Dropout rate     : 0.3
#   Unfreeze layers  : 0
#
#   ── Base Model ──────────────────────────────────────
#   Architecture     : DenseNet121
#   Weights          : ImageNet ✓
#   Input shape      : (224, 224, 3)
#   Unfrozen layers  : 0
#   BN always frozen : ✓ (DenseNet requirement)
#
#   ── Classification Head ─────────────────────────────
#   GlobalAveragePooling2D
#   BatchNormalization
#   Dense(256, relu)
#   Dropout(0.3)
#   Dense(128, relu)
#   Dropout(0.15)
#   Dense(1, sigmoid)  ← binary output
#
#   ── Loss & Metrics ──────────────────────────────────
#   Loss             : binary_crossentropy
#   Metrics          : accuracy, AUC
#   Classes          : ['Mold', 'No mold']
#   Class indices    : {'Mold': 0, 'No mold': 1}
#
#   ── Parameters ──────────────────────────────────────
#   Total params     : 7,337,025
#   Trainable        : 297,473
#   Frozen           : 7,039,552
#
#   ── Training ────────────────────────────────────────
#   Epochs           : 25
#   Optimizer        : Adam(lr=0.0001)
# ============================================================
#
#   ✓ Fragment 2 complete. build_densenet121_binary() is ready.
#      Proceed to Fragment 3 — Training.

# %%
"""
Fragment 3 — Callbacks & Model Training
========================================
DenseNet121 Binary Mould Classification Pipeline — Mold vs No Mold

- Defines all callbacks:
    * ModelCheckpoint    — saves best model based on val_auc
    * EarlyStopping      — stops training if no improvement
    * ReduceLROnPlateau  — reduces LR when val_loss stalls
    * CSVLogger          — logs all metrics per epoch to CSV
- Trains DenseNet121 binary classifier
- Validates on val set only
"""

import os
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    EarlyStopping,
    ReduceLROnPlateau,
    CSVLogger,
)

# ── Configuration ─────────────────────────────────────────────────────────────

SAVE_DIR     = r"D:\Mold Studies Binary\Models"
MODEL_NAME   = "densenet121_binary_best.keras"
CSV_LOG_NAME = "densenet121_binary_training_log.csv"

os.makedirs(SAVE_DIR, exist_ok=True)

MODEL_PATH = os.path.join(SAVE_DIR, MODEL_NAME)
CSV_PATH   = os.path.join(SAVE_DIR, CSV_LOG_NAME)

# ── Callback Parameters ───────────────────────────────────────────────────────

ES_PATIENCE     = 10
ES_MIN_DELTA    = 1e-4

RLROP_FACTOR    = 0.5
RLROP_PATIENCE  = 5
RLROP_MIN_LR    = 1e-7
RLROP_MIN_DELTA = 1e-4

# ── Step 1: Define Callbacks ──────────────────────────────────────────────────

checkpoint = ModelCheckpoint(
    filepath          = MODEL_PATH,
    monitor           = "val_auc",
    save_best_only    = True,
    save_weights_only = False,
    mode              = "max",
    verbose           = 1,
)

early_stopping = EarlyStopping(
    monitor              = "val_auc",
    patience             = ES_PATIENCE,
    min_delta            = ES_MIN_DELTA,
    mode                 = "max",
    restore_best_weights = True,
    verbose              = 1,
)

reduce_lr = ReduceLROnPlateau(
    monitor   = "val_loss",
    factor    = RLROP_FACTOR,
    patience  = RLROP_PATIENCE,
    min_lr    = RLROP_MIN_LR,
    min_delta = RLROP_MIN_DELTA,
    mode      = "min",
    verbose   = 1,
)

csv_logger = CSVLogger(
    filename  = CSV_PATH,
    separator = ",",
    append    = False,
)

callbacks = [checkpoint, early_stopping, reduce_lr, csv_logger]

print("=" * 60)
print("  Step 1 — Callbacks Configured")
print("=" * 60)
print(f"  ModelCheckpoint  : best val_auc → {MODEL_PATH}")
print(f"  EarlyStopping    : patience={ES_PATIENCE} epochs, "
      f"restores best weights")
print(f"  ReduceLROnPlateau: factor={RLROP_FACTOR} after "
      f"{RLROP_PATIENCE} stale epochs, floor={RLROP_MIN_LR}")
print(f"  CSVLogger        : epoch log → {CSV_PATH}")
print("=" * 60)

# ── Step 2: Training Configuration ───────────────────────────────────────────

print("\n" + "=" * 60)
print("  Step 2 — Training Configuration")
print("=" * 60)
print(f"  Pipeline         : Binary — Mold vs No Mold")
print(f"  Architecture     : DenseNet121")
print(f"  Train samples    : {train_generator.samples}")
print(f"  Valid samples    : {valid_generator.samples}")
print(f"  Classes          : {CLASS_NAMES}")
print(f"  Class indices    : {train_generator.class_indices}")
print(f"  Epochs           : {EPOCHS}")
print(f"  Batch size       : {BATCH_SIZE}")
print(f"  Learning rate    : {DEFAULT_LEARNING_RATE:.6f}")
print(f"  Dropout rate     : {DEFAULT_DROPOUT_RATE:.4f}")
print(f"  Unfreeze layers  : {DEFAULT_UNFREEZE_LAYERS}")
print(f"  Loss             : binary_crossentropy")
print(f"  Monitor          : val_auc")
print("=" * 60 + "\n")

# ── Step 3: Build Final Model ─────────────────────────────────────────────────

model = build_densenet121_binary(
    learning_rate   = DEFAULT_LEARNING_RATE,
    dropout_rate    = DEFAULT_DROPOUT_RATE,
    unfreeze_layers = DEFAULT_UNFREEZE_LAYERS,
    epochs          = EPOCHS,
)

# ── Step 4: Train ─────────────────────────────────────────────────────────────

history = model.fit(
    train_generator,
    epochs           = EPOCHS,
    validation_data  = valid_generator,
    callbacks        = callbacks,
    steps_per_epoch  = train_generator.samples  // BATCH_SIZE,
    validation_steps = valid_generator.samples  // BATCH_SIZE,
)

# ── Step 5: Training Summary ──────────────────────────────────────────────────

best_val_auc  = max(history.history["val_auc"])
best_val_acc  = max(history.history["val_accuracy"])
best_val_loss = min(history.history["val_loss"])
epochs_run    = len(history.history["accuracy"])
best_epoch    = history.history["val_auc"].index(best_val_auc) + 1

print("\n" + "=" * 60)
print("  Step 5 — Training Complete")
print("=" * 60)
print(f"  Epochs run       : {epochs_run} / {EPOCHS}")
print(f"  Best epoch       : {best_epoch}")
print(f"  Best val AUC     : {best_val_auc:.4f}")
print(f"  Best val accuracy: {best_val_acc:.4f}  ({best_val_acc * 100:.2f}%)")
print(f"  Best val loss    : {best_val_loss:.4f}")
print(f"  Best model saved : {MODEL_PATH}")
print(f"  Training log     : {CSV_PATH}")
print("=" * 60)

print("\n  ✓ Fragment 3 complete. history and model are ready.")
print("     Proceed to Fragment 3b — Multi-Run Training.\n")
# Out:
# ============================================================
#   Step 1 — Callbacks Configured
# ============================================================
#   ModelCheckpoint  : best val_auc → D:\Mold Studies Binary\Models\densenet121_binary_best.keras
#   EarlyStopping    : patience=10 epochs, restores best weights
#   ReduceLROnPlateau: factor=0.5 after 5 stale epochs, floor=1e-07
#   CSVLogger        : epoch log → D:\Mold Studies Binary\Models\densenet121_binary_training_log.csv
# ============================================================
#
# ============================================================
#   Step 2 — Training Configuration
# ============================================================
#   Pipeline         : Binary — Mold vs No Mold
#   Architecture     : DenseNet121
#   Train samples    : 16976
#   Valid samples    : 648
#   Classes          : ['Mold', 'No mold']
#   Class indices    : {'Mold': 0, 'No mold': 1}
#   Epochs           : 25
#   Batch size       : 32
#   Learning rate    : 0.000100
#   Dropout rate     : 0.3000
#   Unfreeze layers  : 0
#   Loss             : binary_crossentropy
#   Monitor          : val_auc
# ============================================================
#
# Epoch 1/25
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\HomePC\miniconda3\envs\tf-cpu\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 530/530 [==============================] - ETA: 0s - loss: 0.3608 - accuracy: 0.8358 - auc: 0.9207
# Epoch 1: val_auc improved from -inf to 0.97660, saving model to D:\Mold Studies Binary\Models\densenet121_binary_best.keras
# 530/530 [==============================] - 282s 527ms/step - loss: 0.3608 - accuracy: 0.8358 - auc: 0.9207 - val_loss: 0.2077 - val_accuracy: 0.9187 - val_auc: 0.9766 - lr: 1.0000e-04
# Epoch 2/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9215 - auc: 0.9780
# Epoch 2: val_auc improved from 0.97660 to 0.99018, saving model to D:\Mold Studies Binary\Models\densenet121_binary_best.keras
# 530/530 [==============================] - 239s 451ms/step - loss: 0.1940 - accuracy: 0.9215 - auc: 0.9780 - val_loss: 0.1313 - val_accuracy: 0.9453 - val_auc: 0.9902 - lr: 1.0000e-04
# Epoch 3/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 0.9424 - auc: 0.9877
# Epoch 3: val_auc improved from 0.99018 to 0.99179, saving model to D:\Mold Studies Binary\Models\densenet121_binary_best.keras
# 530/530 [==============================] - 237s 447ms/step - loss: 0.1449 - accuracy: 0.9424 - auc: 0.9877 - val_loss: 0.1149 - val_accuracy: 0.9594 - val_auc: 0.9918 - lr: 1.0000e-04
# Epoch 4/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9572 - auc: 0.9926
# Epoch 4: val_auc improved from 0.99179 to 0.99416, saving model to D:\Mold Studies Binary\Models\densenet121_binary_best.keras
# 530/530 [==============================] - 237s 447ms/step - loss: 0.1127 - accuracy: 0.9572 - auc: 0.9926 - val_loss: 0.0987 - val_accuracy: 0.9625 - val_auc: 0.9942 - lr: 1.0000e-04
# Epoch 5/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9611 - auc: 0.9942
# Epoch 5: val_auc improved from 0.99416 to 0.99423, saving model to D:\Mold Studies Binary\Models\densenet121_binary_best.keras
# 530/530 [==============================] - 237s 447ms/step - loss: 0.0989 - accuracy: 0.9611 - auc: 0.9942 - val_loss: 0.0931 - val_accuracy: 0.9688 - val_auc: 0.9942 - lr: 1.0000e-04
# Epoch 6/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9723 - auc: 0.9964
# Epoch 6: val_auc improved from 0.99423 to 0.99545, saving model to D:\Mold Studies Binary\Models\densenet121_binary_best.keras
# 530/530 [==============================] - 238s 449ms/step - loss: 0.0768 - accuracy: 0.9723 - auc: 0.9964 - val_loss: 0.0838 - val_accuracy: 0.9703 - val_auc: 0.9954 - lr: 1.0000e-04
# Epoch 7/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9737 - auc: 0.9971
# Epoch 7: val_auc improved from 0.99545 to 0.99657, saving model to D:\Mold Studies Binary\Models\densenet121_binary_best.keras
# 530/530 [==============================] - 237s 448ms/step - loss: 0.0691 - accuracy: 0.9737 - auc: 0.9971 - val_loss: 0.0778 - val_accuracy: 0.9719 - val_auc: 0.9966 - lr: 1.0000e-04
# Epoch 8/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9768 - auc: 0.9978
# Epoch 8: val_auc did not improve from 0.99657
# 530/530 [==============================] - 238s 449ms/step - loss: 0.0599 - accuracy: 0.9768 - auc: 0.9978 - val_loss: 0.0761 - val_accuracy: 0.9719 - val_auc: 0.9965 - lr: 1.0000e-04
# Epoch 9/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9801 - auc: 0.9983
# Epoch 9: val_auc did not improve from 0.99657
# 530/530 [==============================] - 237s 446ms/step - loss: 0.0529 - accuracy: 0.9801 - auc: 0.9983 - val_loss: 0.0746 - val_accuracy: 0.9688 - val_auc: 0.9950 - lr: 1.0000e-04
# Epoch 10/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9851 - auc: 0.9988
# Epoch 10: val_auc did not improve from 0.99657
# 530/530 [==============================] - 248s 467ms/step - loss: 0.0434 - accuracy: 0.9851 - auc: 0.9988 - val_loss: 0.0774 - val_accuracy: 0.9719 - val_auc: 0.9953 - lr: 1.0000e-04
# Epoch 11/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9873 - auc: 0.9992
# Epoch 11: val_auc improved from 0.99657 to 0.99707, saving model to D:\Mold Studies Binary\Models\densenet121_binary_best.keras
# 530/530 [==============================] - 243s 459ms/step - loss: 0.0381 - accuracy: 0.9873 - auc: 0.9992 - val_loss: 0.0746 - val_accuracy: 0.9734 - val_auc: 0.9971 - lr: 1.0000e-04
# Epoch 12/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 0.9864 - auc: 0.9990
# Epoch 12: val_auc did not improve from 0.99707
# 530/530 [==============================] - 255s 482ms/step - loss: 0.0379 - accuracy: 0.9864 - auc: 0.9990 - val_loss: 0.0819 - val_accuracy: 0.9719 - val_auc: 0.9955 - lr: 1.0000e-04
# Epoch 13/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9890 - auc: 0.9995
# Epoch 13: val_auc did not improve from 0.99707
# 530/530 [==============================] - 360s 680ms/step - loss: 0.0307 - accuracy: 0.9890 - auc: 0.9995 - val_loss: 0.0815 - val_accuracy: 0.9719 - val_auc: 0.9955 - lr: 1.0000e-04
# Epoch 14/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9904 - auc: 0.9995
# Epoch 14: val_auc did not improve from 0.99707
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 530/530 [==============================] - 359s 678ms/step - loss: 0.0281 - accuracy: 0.9904 - auc: 0.9995 - val_loss: 0.0831 - val_accuracy: 0.9719 - val_auc: 0.9969 - lr: 1.0000e-04
# Epoch 15/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9917 - auc: 0.9997
# Epoch 15: val_auc did not improve from 0.99707
# 530/530 [==============================] - 372s 702ms/step - loss: 0.0227 - accuracy: 0.9917 - auc: 0.9997 - val_loss: 0.0826 - val_accuracy: 0.9734 - val_auc: 0.9940 - lr: 5.0000e-05
# Epoch 16/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9940 - auc: 0.9997
# Epoch 16: val_auc did not improve from 0.99707
# 530/530 [==============================] - 236s 445ms/step - loss: 0.0201 - accuracy: 0.9940 - auc: 0.9997 - val_loss: 0.0838 - val_accuracy: 0.9750 - val_auc: 0.9956 - lr: 5.0000e-05
# Epoch 17/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9927 - auc: 0.9997
# Epoch 17: val_auc improved from 0.99707 to 0.99718, saving model to D:\Mold Studies Binary\Models\densenet121_binary_best.keras
# 530/530 [==============================] - 250s 472ms/step - loss: 0.0205 - accuracy: 0.9927 - auc: 0.9997 - val_loss: 0.0836 - val_accuracy: 0.9719 - val_auc: 0.9972 - lr: 5.0000e-05
# Epoch 18/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9948 - auc: 0.9998
# Epoch 18: val_auc did not improve from 0.99718
# 530/530 [==============================] - 375s 707ms/step - loss: 0.0159 - accuracy: 0.9948 - auc: 0.9998 - val_loss: 0.0851 - val_accuracy: 0.9750 - val_auc: 0.9958 - lr: 5.0000e-05
# Epoch 19/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9943 - auc: 0.9998
# Epoch 19: val_auc did not improve from 0.99718
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 530/530 [==============================] - 380s 718ms/step - loss: 0.0169 - accuracy: 0.9943 - auc: 0.9998 - val_loss: 0.0885 - val_accuracy: 0.9750 - val_auc: 0.9941 - lr: 5.0000e-05
# Epoch 20/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9956 - auc: 0.9999
# Epoch 20: val_auc did not improve from 0.99718
# 530/530 [==============================] - 273s 515ms/step - loss: 0.0148 - accuracy: 0.9956 - auc: 0.9999 - val_loss: 0.0866 - val_accuracy: 0.9734 - val_auc: 0.9943 - lr: 2.5000e-05
# Epoch 21/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9947 - auc: 0.9999
# Epoch 21: val_auc did not improve from 0.99718
# 530/530 [==============================] - 370s 697ms/step - loss: 0.0154 - accuracy: 0.9947 - auc: 0.9999 - val_loss: 0.0832 - val_accuracy: 0.9750 - val_auc: 0.9945 - lr: 2.5000e-05
# Epoch 22/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9955 - auc: 0.9999
# Epoch 22: val_auc did not improve from 0.99718
# 530/530 [==============================] - 314s 592ms/step - loss: 0.0139 - accuracy: 0.9955 - auc: 0.9999 - val_loss: 0.0884 - val_accuracy: 0.9719 - val_auc: 0.9943 - lr: 2.5000e-05
# Epoch 23/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9949 - auc: 0.9998
# Epoch 23: val_auc did not improve from 0.99718
# 530/530 [==============================] - 245s 463ms/step - loss: 0.0154 - accuracy: 0.9949 - auc: 0.9998 - val_loss: 0.0920 - val_accuracy: 0.9734 - val_auc: 0.9924 - lr: 2.5000e-05
# Epoch 24/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9958 - auc: 0.9999
# Epoch 24: val_auc did not improve from 0.99718
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 530/530 [==============================] - 231s 436ms/step - loss: 0.0132 - accuracy: 0.9958 - auc: 0.9999 - val_loss: 0.0841 - val_accuracy: 0.9734 - val_auc: 0.9912 - lr: 2.5000e-05
# Epoch 25/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9958 - auc: 0.9999
# Epoch 25: val_auc did not improve from 0.99718
# 530/530 [==============================] - 231s 435ms/step - loss: 0.0138 - accuracy: 0.9958 - auc: 0.9999 - val_loss: 0.0850 - val_accuracy: 0.9734 - val_auc: 0.9911 - lr: 1.2500e-05
#
# ============================================================
#   Step 5 — Training Complete
# ============================================================
#   Epochs run       : 25 / 25
#   Best epoch       : 17
#   Best val AUC     : 0.9972
#   Best val accuracy: 0.9750  (97.50%)
#   Best val loss    : 0.0746
#   Best model saved : D:\Mold Studies Binary\Models\densenet121_binary_best.keras
#   Training log     : D:\Mold Studies Binary\Models\densenet121_binary_training_log.csv
# ============================================================
#
#   ✓ Fragment 3 complete. history and model are ready.
#      Proceed to Fragment 3b — Multi-Run Training.

# %%
"""
Fragment 3b — Multi-Run Training (DenseNet121 Binary)
======================================================
Binary Mould Classification Pipeline — Mold vs No Mold

Runs 4 additional independent training loops (Runs 2–5).
Run 1 was completed in Fragment 3 and its model is already saved.
Each run starts from fresh ImageNet weights with randomly
reinitialised classification head.

OUTPUT: 5 models saved to disk
    densenet121_binary_run1_best.keras   (copied from Fragment 3)
    densenet121_binary_run2_best.keras
    densenet121_binary_run3_best.keras
    densenet121_binary_run4_best.keras
    densenet121_binary_run5_best.keras
"""

import os
import shutil
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    EarlyStopping,
    ReduceLROnPlateau,
    CSVLogger,
)

# ── Configuration ─────────────────────────────────────────────────────────────

SAVE_DIR   = r"D:\Mold Studies Binary\Models"
TOTAL_RUNS = 5

os.makedirs(SAVE_DIR, exist_ok=True)

# ── Step 1: Rename Fragment 3 model → Run 1 ──────────────────────────────────

src = os.path.join(SAVE_DIR, "densenet121_binary_best.keras")
dst = os.path.join(SAVE_DIR, "densenet121_binary_run1_best.keras")

if os.path.exists(src) and not os.path.exists(dst):
    shutil.copy2(src, dst)
    print(f"  Copied  : densenet121_binary_best.keras "
          f"→ densenet121_binary_run1_best.keras")
elif os.path.exists(dst):
    print(f"  Already exists : densenet121_binary_run1_best.keras "
          f"— skipping copy")
else:
    print(f"  WARNING : densenet121_binary_best.keras not found")
    print(f"            Ensure Fragment 3 completed successfully "
          f"before continuing")

# ── Step 2: Collect Run 1 results from Fragment 3 ────────────────────────────

all_run_results = [
    {
        "run"          : 1,
        "best_val_auc" : best_val_auc,
        "best_val_acc" : best_val_acc,
        "best_val_loss": best_val_loss,
        "best_epoch"   : best_epoch,
        "checkpoint"   : "densenet121_binary_run1_best.keras"
    }
]

print(f"\n  Run 1 loaded from Fragment 3")
print(f"    Best val AUC      : {best_val_auc:.4f}")
print(f"    Best val accuracy : {best_val_acc:.4f}")
print(f"    Best val loss     : {best_val_loss:.4f}")
print(f"    Best epoch        : {best_epoch}")

# ── Step 3: Runs 2–5 ──────────────────────────────────────────────────────────

print(f"\n{'='*60}")
print(f"  MULTI-RUN TRAINING — Runs 2 to {TOTAL_RUNS}")
print(f"  Architecture : DenseNet121")
print(f"  Each run     : fresh ImageNet weights, random head init")
print(f"  Epochs       : {EPOCHS}")
print(f"  LR           : {DEFAULT_LEARNING_RATE}")
print(f"  Dropout      : {DEFAULT_DROPOUT_RATE}")
print(f"  Unfreeze     : {DEFAULT_UNFREEZE_LAYERS} layers")
print(f"  Monitor      : val_auc")
print(f"{'='*60}")

for run_idx in range(2, TOTAL_RUNS + 1):

    print(f"\n{'='*60}")
    print(f"  RUN {run_idx} / {TOTAL_RUNS}")
    print(f"{'='*60}\n")

    ckpt_path = os.path.join(SAVE_DIR,
                             f"densenet121_binary_run{run_idx}_best.keras")
    csv_path  = os.path.join(SAVE_DIR,
                             f"densenet121_binary_run{run_idx}_log.csv")

    run_model = build_densenet121_binary(
        learning_rate   = DEFAULT_LEARNING_RATE,
        dropout_rate    = DEFAULT_DROPOUT_RATE,
        unfreeze_layers = DEFAULT_UNFREEZE_LAYERS,
        epochs          = EPOCHS,
    )

    run_callbacks = [
        ModelCheckpoint(
            filepath          = ckpt_path,
            monitor           = "val_auc",
            save_best_only    = True,
            save_weights_only = False,
            save_format       = "keras",
            mode              = "max",
            verbose           = 1,
        ),
        EarlyStopping(
            monitor              = "val_auc",
            patience             = ES_PATIENCE,
            min_delta            = ES_MIN_DELTA,
            mode                 = "max",
            restore_best_weights = True,
            verbose              = 1,
        ),
        ReduceLROnPlateau(
            monitor   = "val_loss",
            factor    = RLROP_FACTOR,
            patience  = RLROP_PATIENCE,
            min_lr    = RLROP_MIN_LR,
            min_delta = RLROP_MIN_DELTA,
            mode      = "min",
            verbose   = 1,
        ),
        CSVLogger(
            filename  = csv_path,
            separator = ",",
            append    = False,
        ),
    ]

    run_history = run_model.fit(
        train_generator,
        validation_data  = valid_generator,
        epochs           = EPOCHS,
        callbacks        = run_callbacks,
        steps_per_epoch  = train_generator.samples  // BATCH_SIZE,
        validation_steps = valid_generator.samples  // BATCH_SIZE,
    )

    run_best_val_auc  = max(run_history.history["val_auc"])
    run_best_val_acc  = max(run_history.history["val_accuracy"])
    run_best_val_loss = min(run_history.history["val_loss"])
    run_best_epoch    = run_history.history["val_auc"].index(
                            run_best_val_auc) + 1
    run_epochs_run    = len(run_history.history["accuracy"])

    run_model.save(ckpt_path)

    all_run_results.append({
        "run"          : run_idx,
        "best_val_auc" : run_best_val_auc,
        "best_val_acc" : run_best_val_acc,
        "best_val_loss": run_best_val_loss,
        "best_epoch"   : run_best_epoch,
        "checkpoint"   : f"densenet121_binary_run{run_idx}_best.keras"
    })

    print(f"\n  Run {run_idx} complete")
    print(f"    Epochs run        : {run_epochs_run} / {EPOCHS}")
    print(f"    Best epoch        : {run_best_epoch}")
    print(f"    Best val AUC      : {run_best_val_auc:.4f}")
    print(f"    Best val accuracy : {run_best_val_acc:.4f}")
    print(f"    Best val loss     : {run_best_val_loss:.4f}")
    print(f"    Saved to          : {ckpt_path}")

# ── Step 4: Summary across all 5 runs ────────────────────────────────────────

val_aucs   = [r["best_val_auc"]  for r in all_run_results]
val_accs   = [r["best_val_acc"]  for r in all_run_results]
val_losses = [r["best_val_loss"] for r in all_run_results]

print(f"\n{'='*60}")
print(f"  ALL RUNS COMPLETE — Summary")
print(f"{'='*60}")
print(f"  {'Run':<6} {'Val AUC':>10} {'Val Acc':>10} "
      f"{'Val Loss':>10} {'Best Epoch':>12} {'Checkpoint'}")
print(f"  {'─'*80}")

for r in all_run_results:
    print(f"  {r['run']:<6} {r['best_val_auc']:>10.4f} "
          f"{r['best_val_acc']:>10.4f} {r['best_val_loss']:>10.4f} "
          f"{r['best_epoch']:>12} {r['checkpoint']}")

best_run = max(all_run_results, key=lambda x: x["best_val_auc"])

print(f"\n  {'─'*60}")
print(f"  Mean val AUC       : {np.mean(val_aucs):.4f}")
print(f"  Std  val AUC       : {np.std(val_aucs):.4f}")
print(f"  Mean val accuracy  : {np.mean(val_accs):.4f}")
print(f"  Std  val accuracy  : {np.std(val_accs):.4f}")
print(f"  Mean val loss      : {np.mean(val_losses):.4f}")
print(f"  Std  val loss      : {np.std(val_losses):.4f}")
print(f"\n  Best single run    : Run {best_run['run']} "
      f"— Val AUC {best_run['best_val_auc']:.4f}")
print(f"{'='*60}")

ensemble_checkpoints = [
    os.path.join(SAVE_DIR, r["checkpoint"]) for r in all_run_results
]

print(f"\n  ✓ Fragment 3b complete.")
print(f"  ensemble_checkpoints = {ensemble_checkpoints}")
print(f"\n     Proceed to Fragment 4 — Evaluation & Metrics.\n")
# Out:
#   Copied  : densenet121_binary_best.keras → densenet121_binary_run1_best.keras
#
#   Run 1 loaded from Fragment 3
#     Best val AUC      : 0.9972
#     Best val accuracy : 0.9750
#     Best val loss     : 0.0746
#     Best epoch        : 17
#
# ============================================================
#   MULTI-RUN TRAINING — Runs 2 to 5
#   Architecture : DenseNet121
#   Each run     : fresh ImageNet weights, random head init
#   Epochs       : 25
#   LR           : 0.0001
#   Dropout      : 0.3
#   Unfreeze     : 0 layers
#   Monitor      : val_auc
# ============================================================
#
# ============================================================
#   RUN 2 / 5
# ============================================================
#
# Epoch 1/25
# 530/530 [==============================] - ETA: 0s - loss: 0.3658 - accuracy: 0.8288 - auc: 0.9171
# Epoch 1: val_auc improved from -inf to 0.97592, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run2_best.keras
# 530/530 [==============================] - 236s 439ms/step - loss: 0.3658 - accuracy: 0.8288 - auc: 0.9171 - val_loss: 0.2076 - val_accuracy: 0.9219 - val_auc: 0.9759 - lr: 1.0000e-04
# Epoch 2/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1959 - accuracy: 0.9204 - auc: 0.9775
# Epoch 2: val_auc improved from 0.97592 to 0.98765, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run2_best.keras
# 530/530 [==============================] - 247s 465ms/step - loss: 0.1959 - accuracy: 0.9204 - auc: 0.9775 - val_loss: 0.1446 - val_accuracy: 0.9422 - val_auc: 0.9876 - lr: 1.0000e-04
# Epoch 3/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9446 - auc: 0.9882
# Epoch 3: val_auc improved from 0.98765 to 0.99046, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run2_best.keras
# 530/530 [==============================] - 351s 662ms/step - loss: 0.1422 - accuracy: 0.9446 - auc: 0.9882 - val_loss: 0.1253 - val_accuracy: 0.9500 - val_auc: 0.9905 - lr: 1.0000e-04
# Epoch 4/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9539 - auc: 0.9923
# Epoch 4: val_auc improved from 0.99046 to 0.99296, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run2_best.keras
# 530/530 [==============================] - 376s 709ms/step - loss: 0.1142 - accuracy: 0.9539 - auc: 0.9923 - val_loss: 0.1071 - val_accuracy: 0.9594 - val_auc: 0.9930 - lr: 1.0000e-04
# Epoch 5/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9646 - auc: 0.9949
# Epoch 5: val_auc improved from 0.99296 to 0.99456, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run2_best.keras
# 530/530 [==============================] - 418s 789ms/step - loss: 0.0922 - accuracy: 0.9646 - auc: 0.9949 - val_loss: 0.1012 - val_accuracy: 0.9719 - val_auc: 0.9946 - lr: 1.0000e-04
# Epoch 6/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9697 - auc: 0.9961
# Epoch 6: val_auc improved from 0.99456 to 0.99501, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run2_best.keras
# 530/530 [==============================] - 244s 459ms/step - loss: 0.0804 - accuracy: 0.9697 - auc: 0.9961 - val_loss: 0.0894 - val_accuracy: 0.9656 - val_auc: 0.9950 - lr: 1.0000e-04
# Epoch 7/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9757 - auc: 0.9974
# Epoch 7: val_auc improved from 0.99501 to 0.99581, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run2_best.keras
# 530/530 [==============================] - 273s 514ms/step - loss: 0.0652 - accuracy: 0.9757 - auc: 0.9974 - val_loss: 0.0861 - val_accuracy: 0.9688 - val_auc: 0.9958 - lr: 1.0000e-04
# Epoch 8/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9788 - auc: 0.9979
# Epoch 8: val_auc did not improve from 0.99581
# 530/530 [==============================] - 392s 739ms/step - loss: 0.0580 - accuracy: 0.9788 - auc: 0.9979 - val_loss: 0.0874 - val_accuracy: 0.9609 - val_auc: 0.9945 - lr: 1.0000e-04
# Epoch 9/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9818 - auc: 0.9987
# Epoch 9: val_auc did not improve from 0.99581
# 530/530 [==============================] - 402s 758ms/step - loss: 0.0482 - accuracy: 0.9818 - auc: 0.9987 - val_loss: 0.0830 - val_accuracy: 0.9688 - val_auc: 0.9947 - lr: 1.0000e-04
# Epoch 10/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9841 - auc: 0.9989
# Epoch 10: val_auc did not improve from 0.99581
# 530/530 [==============================] - 409s 772ms/step - loss: 0.0435 - accuracy: 0.9841 - auc: 0.9989 - val_loss: 0.0908 - val_accuracy: 0.9719 - val_auc: 0.9951 - lr: 1.0000e-04
# Epoch 11/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9862 - auc: 0.9991
# Epoch 11: val_auc did not improve from 0.99581
# 530/530 [==============================] - 420s 792ms/step - loss: 0.0395 - accuracy: 0.9862 - auc: 0.9991 - val_loss: 0.0972 - val_accuracy: 0.9719 - val_auc: 0.9933 - lr: 1.0000e-04
# Epoch 12/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9873 - auc: 0.9992
# Epoch 12: val_auc did not improve from 0.99581
# 530/530 [==============================] - 405s 765ms/step - loss: 0.0357 - accuracy: 0.9873 - auc: 0.9992 - val_loss: 0.0929 - val_accuracy: 0.9688 - val_auc: 0.9951 - lr: 1.0000e-04
# Epoch 13/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9895 - auc: 0.9992
# Epoch 13: val_auc did not improve from 0.99581
# 530/530 [==============================] - 416s 785ms/step - loss: 0.0320 - accuracy: 0.9895 - auc: 0.9992 - val_loss: 0.0853 - val_accuracy: 0.9688 - val_auc: 0.9955 - lr: 1.0000e-04
# Epoch 14/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9920 - auc: 0.9996
# Epoch 14: val_auc did not improve from 0.99581
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 530/530 [==============================] - 422s 796ms/step - loss: 0.0255 - accuracy: 0.9920 - auc: 0.9996 - val_loss: 0.0881 - val_accuracy: 0.9703 - val_auc: 0.9954 - lr: 1.0000e-04
# Epoch 15/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9939 - auc: 0.9997
# Epoch 15: val_auc did not improve from 0.99581
# 530/530 [==============================] - 418s 788ms/step - loss: 0.0210 - accuracy: 0.9939 - auc: 0.9997 - val_loss: 0.0822 - val_accuracy: 0.9781 - val_auc: 0.9957 - lr: 5.0000e-05
# Epoch 16/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9931 - auc: 0.9997
# Epoch 16: val_auc did not improve from 0.99581
# 530/530 [==============================] - 422s 796ms/step - loss: 0.0206 - accuracy: 0.9931 - auc: 0.9997 - val_loss: 0.0832 - val_accuracy: 0.9750 - val_auc: 0.9943 - lr: 5.0000e-05
# Epoch 17/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9933 - auc: 0.9997
# Epoch 17: val_auc did not improve from 0.99581
# Restoring model weights from the end of the best epoch: 7.
# 530/530 [==============================] - 420s 792ms/step - loss: 0.0199 - accuracy: 0.9933 - auc: 0.9997 - val_loss: 0.0828 - val_accuracy: 0.9719 - val_auc: 0.9931 - lr: 5.0000e-05
# Epoch 17: early stopping
#
#   Run 2 complete
#     Epochs run        : 17 / 25
#     Best epoch        : 7
#     Best val AUC      : 0.9958
#     Best val accuracy : 0.9781
#     Best val loss     : 0.0822
#     Saved to          : D:\Mold Studies Binary\Models\densenet121_binary_run2_best.keras
#
# ============================================================
#   RUN 3 / 5
# ============================================================
#
# Epoch 1/25
# 530/530 [==============================] - ETA: 0s - loss: 0.3643 - accuracy: 0.8373 - auc: 0.9192
# Epoch 1: val_auc improved from -inf to 0.97595, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# 530/530 [==============================] - 244s 448ms/step - loss: 0.3643 - accuracy: 0.8373 - auc: 0.9192 - val_loss: 0.2174 - val_accuracy: 0.9047 - val_auc: 0.9759 - lr: 1.0000e-04
# Epoch 2/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9181 - auc: 0.9766
# Epoch 2: val_auc improved from 0.97595 to 0.98855, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# 530/530 [==============================] - 233s 439ms/step - loss: 0.1996 - accuracy: 0.9181 - auc: 0.9766 - val_loss: 0.1414 - val_accuracy: 0.9453 - val_auc: 0.9886 - lr: 1.0000e-04
# Epoch 3/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9400 - auc: 0.9871
# Epoch 3: val_auc improved from 0.98855 to 0.99241, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# 530/530 [==============================] - 231s 436ms/step - loss: 0.1483 - accuracy: 0.9400 - auc: 0.9871 - val_loss: 0.1134 - val_accuracy: 0.9578 - val_auc: 0.9924 - lr: 1.0000e-04
# Epoch 4/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9558 - auc: 0.9922
# Epoch 4: val_auc improved from 0.99241 to 0.99424, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# 530/530 [==============================] - 231s 437ms/step - loss: 0.1145 - accuracy: 0.9558 - auc: 0.9922 - val_loss: 0.0972 - val_accuracy: 0.9578 - val_auc: 0.9942 - lr: 1.0000e-04
# Epoch 5/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9630 - auc: 0.9944
# Epoch 5: val_auc did not improve from 0.99424
# 530/530 [==============================] - 231s 435ms/step - loss: 0.0976 - accuracy: 0.9630 - auc: 0.9944 - val_loss: 0.0888 - val_accuracy: 0.9641 - val_auc: 0.9941 - lr: 1.0000e-04
# Epoch 6/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9687 - auc: 0.9961
# Epoch 6: val_auc did not improve from 0.99424
# 530/530 [==============================] - 230s 435ms/step - loss: 0.0807 - accuracy: 0.9687 - auc: 0.9961 - val_loss: 0.0885 - val_accuracy: 0.9656 - val_auc: 0.9930 - lr: 1.0000e-04
# Epoch 7/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9751 - auc: 0.9973
# Epoch 7: val_auc improved from 0.99424 to 0.99517, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# 530/530 [==============================] - 231s 436ms/step - loss: 0.0673 - accuracy: 0.9751 - auc: 0.9973 - val_loss: 0.0829 - val_accuracy: 0.9656 - val_auc: 0.9952 - lr: 1.0000e-04
# Epoch 8/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9766 - auc: 0.9978
# Epoch 8: val_auc improved from 0.99517 to 0.99520, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# 530/530 [==============================] - 231s 437ms/step - loss: 0.0613 - accuracy: 0.9766 - auc: 0.9978 - val_loss: 0.0841 - val_accuracy: 0.9734 - val_auc: 0.9952 - lr: 1.0000e-04
# Epoch 9/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9799 - auc: 0.9984
# Epoch 9: val_auc did not improve from 0.99520
# 530/530 [==============================] - 230s 435ms/step - loss: 0.0524 - accuracy: 0.9799 - auc: 0.9984 - val_loss: 0.0778 - val_accuracy: 0.9688 - val_auc: 0.9942 - lr: 1.0000e-04
# Epoch 10/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9855 - auc: 0.9991
# Epoch 10: val_auc improved from 0.99520 to 0.99562, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# 530/530 [==============================] - 231s 437ms/step - loss: 0.0405 - accuracy: 0.9855 - auc: 0.9991 - val_loss: 0.0786 - val_accuracy: 0.9719 - val_auc: 0.9956 - lr: 1.0000e-04
# Epoch 11/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9852 - auc: 0.9989
# Epoch 11: val_auc did not improve from 0.99562
# 530/530 [==============================] - 231s 436ms/step - loss: 0.0419 - accuracy: 0.9852 - auc: 0.9989 - val_loss: 0.0762 - val_accuracy: 0.9688 - val_auc: 0.9946 - lr: 1.0000e-04
# Epoch 12/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9862 - auc: 0.9991
# Epoch 12: val_auc did not improve from 0.99562
# 530/530 [==============================] - 231s 436ms/step - loss: 0.0386 - accuracy: 0.9862 - auc: 0.9991 - val_loss: 0.0711 - val_accuracy: 0.9781 - val_auc: 0.9948 - lr: 1.0000e-04
# Epoch 13/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0303 - accuracy: 0.9894 - auc: 0.9995
# Epoch 13: val_auc improved from 0.99562 to 0.99645, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# 530/530 [==============================] - 232s 437ms/step - loss: 0.0303 - accuracy: 0.9894 - auc: 0.9995 - val_loss: 0.0703 - val_accuracy: 0.9734 - val_auc: 0.9964 - lr: 1.0000e-04
# Epoch 14/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9903 - auc: 0.9996
# Epoch 14: val_auc did not improve from 0.99645
# 530/530 [==============================] - 231s 435ms/step - loss: 0.0277 - accuracy: 0.9903 - auc: 0.9996 - val_loss: 0.0778 - val_accuracy: 0.9734 - val_auc: 0.9945 - lr: 1.0000e-04
# Epoch 15/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9897 - auc: 0.9994
# Epoch 15: val_auc did not improve from 0.99645
# 530/530 [==============================] - 231s 435ms/step - loss: 0.0279 - accuracy: 0.9897 - auc: 0.9994 - val_loss: 0.0889 - val_accuracy: 0.9703 - val_auc: 0.9924 - lr: 1.0000e-04
# Epoch 16/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9926 - auc: 0.9996
# Epoch 16: val_auc did not improve from 0.99645
# 530/530 [==============================] - 231s 436ms/step - loss: 0.0219 - accuracy: 0.9926 - auc: 0.9996 - val_loss: 0.0863 - val_accuracy: 0.9703 - val_auc: 0.9945 - lr: 1.0000e-04
# Epoch 17/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9926 - auc: 0.9997
# Epoch 17: val_auc did not improve from 0.99645
# 530/530 [==============================] - 231s 435ms/step - loss: 0.0216 - accuracy: 0.9926 - auc: 0.9997 - val_loss: 0.0854 - val_accuracy: 0.9766 - val_auc: 0.9924 - lr: 1.0000e-04
# Epoch 18/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9937 - auc: 0.9998
# Epoch 18: val_auc did not improve from 0.99645
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 530/530 [==============================] - 231s 435ms/step - loss: 0.0173 - accuracy: 0.9937 - auc: 0.9998 - val_loss: 0.0810 - val_accuracy: 0.9750 - val_auc: 0.9946 - lr: 1.0000e-04
# Epoch 19/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9955 - auc: 0.9999
# Epoch 19: val_auc did not improve from 0.99645
# 530/530 [==============================] - 231s 435ms/step - loss: 0.0152 - accuracy: 0.9955 - auc: 0.9999 - val_loss: 0.0725 - val_accuracy: 0.9750 - val_auc: 0.9952 - lr: 5.0000e-05
# Epoch 20/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9959 - auc: 0.9999
# Epoch 20: val_auc did not improve from 0.99645
# 530/530 [==============================] - 231s 435ms/step - loss: 0.0132 - accuracy: 0.9959 - auc: 0.9999 - val_loss: 0.0758 - val_accuracy: 0.9781 - val_auc: 0.9933 - lr: 5.0000e-05
# Epoch 21/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9957 - auc: 0.9998
# Epoch 21: val_auc improved from 0.99645 to 0.99653, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# 530/530 [==============================] - 231s 436ms/step - loss: 0.0148 - accuracy: 0.9957 - auc: 0.9998 - val_loss: 0.0705 - val_accuracy: 0.9766 - val_auc: 0.9965 - lr: 5.0000e-05
# Epoch 22/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9963 - auc: 0.9999
# Epoch 22: val_auc did not improve from 0.99653
# 530/530 [==============================] - 231s 435ms/step - loss: 0.0123 - accuracy: 0.9963 - auc: 0.9999 - val_loss: 0.0842 - val_accuracy: 0.9750 - val_auc: 0.9917 - lr: 5.0000e-05
# Epoch 23/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9960 - auc: 0.9999
# Epoch 23: val_auc did not improve from 0.99653
# Restoring model weights from the end of the best epoch: 13.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 530/530 [==============================] - 230s 435ms/step - loss: 0.0123 - accuracy: 0.9960 - auc: 0.9999 - val_loss: 0.0851 - val_accuracy: 0.9781 - val_auc: 0.9916 - lr: 5.0000e-05
# Epoch 23: early stopping
#
#   Run 3 complete
#     Epochs run        : 23 / 25
#     Best epoch        : 21
#     Best val AUC      : 0.9965
#     Best val accuracy : 0.9781
#     Best val loss     : 0.0703
#     Saved to          : D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
#
# ============================================================
#   RUN 4 / 5
# ============================================================
#
# Epoch 1/25
# 530/530 [==============================] - ETA: 0s - loss: 0.3620 - accuracy: 0.8345 - auc: 0.9199
# Epoch 1: val_auc improved from -inf to 0.98054, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
# 530/530 [==============================] - 237s 441ms/step - loss: 0.3620 - accuracy: 0.8345 - auc: 0.9199 - val_loss: 0.1985 - val_accuracy: 0.9250 - val_auc: 0.9805 - lr: 1.0000e-04
# Epoch 2/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9201 - auc: 0.9774
# Epoch 2: val_auc improved from 0.98054 to 0.98958, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
# 530/530 [==============================] - 233s 440ms/step - loss: 0.1967 - accuracy: 0.9201 - auc: 0.9774 - val_loss: 0.1346 - val_accuracy: 0.9438 - val_auc: 0.9896 - lr: 1.0000e-04
# Epoch 3/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9442 - auc: 0.9883
# Epoch 3: val_auc improved from 0.98958 to 0.99285, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
# 530/530 [==============================] - 233s 440ms/step - loss: 0.1420 - accuracy: 0.9442 - auc: 0.9883 - val_loss: 0.1087 - val_accuracy: 0.9547 - val_auc: 0.9928 - lr: 1.0000e-04
# Epoch 4/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9547 - auc: 0.9921
# Epoch 4: val_auc did not improve from 0.99285
# 530/530 [==============================] - 233s 439ms/step - loss: 0.1157 - accuracy: 0.9547 - auc: 0.9921 - val_loss: 0.0998 - val_accuracy: 0.9703 - val_auc: 0.9928 - lr: 1.0000e-04
# Epoch 5/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9638 - auc: 0.9946
# Epoch 5: val_auc improved from 0.99285 to 0.99353, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
# 530/530 [==============================] - 234s 442ms/step - loss: 0.0955 - accuracy: 0.9638 - auc: 0.9946 - val_loss: 0.0996 - val_accuracy: 0.9672 - val_auc: 0.9935 - lr: 1.0000e-04
# Epoch 6/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9698 - auc: 0.9963
# Epoch 6: val_auc improved from 0.99353 to 0.99457, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0793 - accuracy: 0.9698 - auc: 0.9963 - val_loss: 0.0899 - val_accuracy: 0.9656 - val_auc: 0.9946 - lr: 1.0000e-04
# Epoch 7/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9733 - auc: 0.9971
# Epoch 7: val_auc improved from 0.99457 to 0.99638, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
# 530/530 [==============================] - 233s 440ms/step - loss: 0.0697 - accuracy: 0.9733 - auc: 0.9971 - val_loss: 0.0833 - val_accuracy: 0.9734 - val_auc: 0.9964 - lr: 1.0000e-04
# Epoch 8/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9780 - auc: 0.9978
# Epoch 8: val_auc did not improve from 0.99638
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0606 - accuracy: 0.9780 - auc: 0.9978 - val_loss: 0.0930 - val_accuracy: 0.9719 - val_auc: 0.9944 - lr: 1.0000e-04
# Epoch 9/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9819 - auc: 0.9983
# Epoch 9: val_auc did not improve from 0.99638
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0503 - accuracy: 0.9819 - auc: 0.9983 - val_loss: 0.0866 - val_accuracy: 0.9750 - val_auc: 0.9954 - lr: 1.0000e-04
# Epoch 10/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9832 - auc: 0.9987
# Epoch 10: val_auc improved from 0.99638 to 0.99673, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0448 - accuracy: 0.9832 - auc: 0.9987 - val_loss: 0.0851 - val_accuracy: 0.9719 - val_auc: 0.9967 - lr: 1.0000e-04
# Epoch 11/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9859 - auc: 0.9988
# Epoch 11: val_auc improved from 0.99673 to 0.99691, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0412 - accuracy: 0.9859 - auc: 0.9988 - val_loss: 0.0751 - val_accuracy: 0.9734 - val_auc: 0.9969 - lr: 1.0000e-04
# Epoch 12/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9867 - auc: 0.9989
# Epoch 12: val_auc did not improve from 0.99691
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0385 - accuracy: 0.9867 - auc: 0.9989 - val_loss: 0.1038 - val_accuracy: 0.9656 - val_auc: 0.9931 - lr: 1.0000e-04
# Epoch 13/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9887 - auc: 0.9993
# Epoch 13: val_auc did not improve from 0.99691
# 530/530 [==============================] - 232s 439ms/step - loss: 0.0315 - accuracy: 0.9887 - auc: 0.9993 - val_loss: 0.0896 - val_accuracy: 0.9719 - val_auc: 0.9925 - lr: 1.0000e-04
# Epoch 14/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9894 - auc: 0.9994
# Epoch 14: val_auc did not improve from 0.99691
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0289 - accuracy: 0.9894 - auc: 0.9994 - val_loss: 0.0833 - val_accuracy: 0.9734 - val_auc: 0.9952 - lr: 1.0000e-04
# Epoch 15/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9911 - auc: 0.9996
# Epoch 15: val_auc did not improve from 0.99691
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0256 - accuracy: 0.9911 - auc: 0.9996 - val_loss: 0.0827 - val_accuracy: 0.9750 - val_auc: 0.9926 - lr: 1.0000e-04
# Epoch 16/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9930 - auc: 0.9997
# Epoch 16: val_auc did not improve from 0.99691
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0207 - accuracy: 0.9930 - auc: 0.9997 - val_loss: 0.0890 - val_accuracy: 0.9750 - val_auc: 0.9910 - lr: 1.0000e-04
# Epoch 17/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9941 - auc: 0.9998
# Epoch 17: val_auc did not improve from 0.99691
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0177 - accuracy: 0.9941 - auc: 0.9998 - val_loss: 0.0938 - val_accuracy: 0.9750 - val_auc: 0.9926 - lr: 5.0000e-05
# Epoch 18/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9938 - auc: 0.9998
# Epoch 18: val_auc did not improve from 0.99691
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0182 - accuracy: 0.9938 - auc: 0.9998 - val_loss: 0.0980 - val_accuracy: 0.9766 - val_auc: 0.9905 - lr: 5.0000e-05
# Epoch 19/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9959 - auc: 0.9999
# Epoch 19: val_auc did not improve from 0.99691
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0155 - accuracy: 0.9959 - auc: 0.9999 - val_loss: 0.1058 - val_accuracy: 0.9781 - val_auc: 0.9892 - lr: 5.0000e-05
# Epoch 20/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9950 - auc: 0.9998
# Epoch 20: val_auc did not improve from 0.99691
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0154 - accuracy: 0.9950 - auc: 0.9998 - val_loss: 0.1034 - val_accuracy: 0.9781 - val_auc: 0.9909 - lr: 5.0000e-05
# Epoch 21/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9941 - auc: 0.9998
# Epoch 21: val_auc did not improve from 0.99691
# Restoring model weights from the end of the best epoch: 11.
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0166 - accuracy: 0.9941 - auc: 0.9998 - val_loss: 0.1029 - val_accuracy: 0.9750 - val_auc: 0.9897 - lr: 5.0000e-05
# Epoch 21: early stopping
#
#   Run 4 complete
#     Epochs run        : 21 / 25
#     Best epoch        : 11
#     Best val AUC      : 0.9969
#     Best val accuracy : 0.9781
#     Best val loss     : 0.0751
#     Saved to          : D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
#
# ============================================================
#   RUN 5 / 5
# ============================================================
#
# Epoch 1/25
# 530/530 [==============================] - ETA: 0s - loss: 0.3599 - accuracy: 0.8395 - auc: 0.9223
# Epoch 1: val_auc improved from -inf to 0.97440, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run5_best.keras
# 530/530 [==============================] - 237s 441ms/step - loss: 0.3599 - accuracy: 0.8395 - auc: 0.9223 - val_loss: 0.2170 - val_accuracy: 0.9172 - val_auc: 0.9744 - lr: 1.0000e-04
# Epoch 2/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1903 - accuracy: 0.9239 - auc: 0.9790
# Epoch 2: val_auc improved from 0.97440 to 0.98905, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run5_best.keras
# 530/530 [==============================] - 233s 440ms/step - loss: 0.1903 - accuracy: 0.9239 - auc: 0.9790 - val_loss: 0.1401 - val_accuracy: 0.9406 - val_auc: 0.9891 - lr: 1.0000e-04
# Epoch 3/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9426 - auc: 0.9874
# Epoch 3: val_auc improved from 0.98905 to 0.99194, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run5_best.keras
# 530/530 [==============================] - 234s 441ms/step - loss: 0.1464 - accuracy: 0.9426 - auc: 0.9874 - val_loss: 0.1161 - val_accuracy: 0.9578 - val_auc: 0.9919 - lr: 1.0000e-04
# Epoch 4/25
# 530/530 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9538 - auc: 0.9917
# Epoch 4: val_auc improved from 0.99194 to 0.99380, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run5_best.keras
# 530/530 [==============================] - 233s 440ms/step - loss: 0.1185 - accuracy: 0.9538 - auc: 0.9917 - val_loss: 0.0972 - val_accuracy: 0.9688 - val_auc: 0.9938 - lr: 1.0000e-04
# Epoch 5/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9633 - auc: 0.9951
# Epoch 5: val_auc did not improve from 0.99380
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0927 - accuracy: 0.9633 - auc: 0.9951 - val_loss: 0.0986 - val_accuracy: 0.9688 - val_auc: 0.9936 - lr: 1.0000e-04
# Epoch 6/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9694 - auc: 0.9965
# Epoch 6: val_auc did not improve from 0.99380
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0771 - accuracy: 0.9694 - auc: 0.9965 - val_loss: 0.0951 - val_accuracy: 0.9688 - val_auc: 0.9935 - lr: 1.0000e-04
# Epoch 7/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9750 - auc: 0.9973
# Epoch 7: val_auc improved from 0.99380 to 0.99556, saving model to D:\Mold Studies Binary\Models\densenet121_binary_run5_best.keras
# 530/530 [==============================] - 234s 441ms/step - loss: 0.0678 - accuracy: 0.9750 - auc: 0.9973 - val_loss: 0.0918 - val_accuracy: 0.9703 - val_auc: 0.9956 - lr: 1.0000e-04
# Epoch 8/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9795 - auc: 0.9980
# Epoch 8: val_auc did not improve from 0.99556
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0581 - accuracy: 0.9795 - auc: 0.9980 - val_loss: 0.0929 - val_accuracy: 0.9672 - val_auc: 0.9947 - lr: 1.0000e-04
# Epoch 9/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9815 - auc: 0.9985
# Epoch 9: val_auc did not improve from 0.99556
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0504 - accuracy: 0.9815 - auc: 0.9985 - val_loss: 0.0897 - val_accuracy: 0.9734 - val_auc: 0.9945 - lr: 1.0000e-04
# Epoch 10/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9825 - auc: 0.9986
# Epoch 10: val_auc did not improve from 0.99556
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0470 - accuracy: 0.9825 - auc: 0.9986 - val_loss: 0.0988 - val_accuracy: 0.9734 - val_auc: 0.9929 - lr: 1.0000e-04
# Epoch 11/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9851 - auc: 0.9989
# Epoch 11: val_auc did not improve from 0.99556
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0405 - accuracy: 0.9851 - auc: 0.9989 - val_loss: 0.0752 - val_accuracy: 0.9750 - val_auc: 0.9945 - lr: 1.0000e-04
# Epoch 12/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9880 - auc: 0.9993
# Epoch 12: val_auc did not improve from 0.99556
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0341 - accuracy: 0.9880 - auc: 0.9993 - val_loss: 0.0956 - val_accuracy: 0.9672 - val_auc: 0.9925 - lr: 1.0000e-04
# Epoch 13/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9887 - auc: 0.9994
# Epoch 13: val_auc did not improve from 0.99556
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0324 - accuracy: 0.9887 - auc: 0.9994 - val_loss: 0.0777 - val_accuracy: 0.9766 - val_auc: 0.9945 - lr: 1.0000e-04
# Epoch 14/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9903 - auc: 0.9995
# Epoch 14: val_auc did not improve from 0.99556
# 530/530 [==============================] - 233s 439ms/step - loss: 0.0280 - accuracy: 0.9903 - auc: 0.9995 - val_loss: 0.0854 - val_accuracy: 0.9750 - val_auc: 0.9943 - lr: 1.0000e-04
# Epoch 15/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9920 - auc: 0.9996
# Epoch 15: val_auc did not improve from 0.99556
# 530/530 [==============================] - 233s 440ms/step - loss: 0.0244 - accuracy: 0.9920 - auc: 0.9996 - val_loss: 0.0778 - val_accuracy: 0.9812 - val_auc: 0.9945 - lr: 1.0000e-04
# Epoch 16/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9920 - auc: 0.9996
# Epoch 16: val_auc did not improve from 0.99556
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 530/530 [==============================] - 232s 439ms/step - loss: 0.0238 - accuracy: 0.9920 - auc: 0.9996 - val_loss: 0.0827 - val_accuracy: 0.9781 - val_auc: 0.9949 - lr: 1.0000e-04
# Epoch 17/25
# 530/530 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9936 - auc: 0.9998
# Epoch 17: val_auc did not improve from 0.99556
# Restoring model weights from the end of the best epoch: 7.
# 530/530 [==============================] - 232s 438ms/step - loss: 0.0189 - accuracy: 0.9936 - auc: 0.9998 - val_loss: 0.0837 - val_accuracy: 0.9781 - val_auc: 0.9949 - lr: 5.0000e-05
# Epoch 17: early stopping
#
#   Run 5 complete
#     Epochs run        : 17 / 25
#     Best epoch        : 7
#     Best val AUC      : 0.9956
#     Best val accuracy : 0.9812
#     Best val loss     : 0.0752
#     Saved to          : D:\Mold Studies Binary\Models\densenet121_binary_run5_best.keras
#
# ============================================================
#   ALL RUNS COMPLETE — Summary
# ============================================================
#   Run       Val AUC    Val Acc   Val Loss   Best Epoch Checkpoint
#   ────────────────────────────────────────────────────────────────────────────────
#   1          0.9972     0.9750     0.0746           17 densenet121_binary_run1_best.keras
#   2          0.9958     0.9781     0.0822            7 densenet121_binary_run2_best.keras
#   3          0.9965     0.9781     0.0703           21 densenet121_binary_run3_best.keras
#   4          0.9969     0.9781     0.0751           11 densenet121_binary_run4_best.keras
#   5          0.9956     0.9812     0.0752            7 densenet121_binary_run5_best.keras
#
#   ────────────────────────────────────────────────────────────
#   Mean val AUC       : 0.9964
#   Std  val AUC       : 0.0006
#   Mean val accuracy  : 0.9781
#   Std  val accuracy  : 0.0020
#   Mean val loss      : 0.0755
#   Std  val loss      : 0.0038
#
#   Best single run    : Run 1 — Val AUC 0.9972
# ============================================================
#
#   ✓ Fragment 3b complete.
#   ensemble_checkpoints = ['D:\\Mold Studies Binary\\Models\\densenet121_binary_run1_best.keras', 'D:\\Mold Studies Binary\\Models\\densenet121_binary_run2_best.keras', 'D:\\Mold Studies Binary\\Models\\densenet121_binary_run3_best.keras', 'D:\\Mold Studies Binary\\Models\\densenet121_binary_run4_best.keras', 'D:\\Mold Studies Binary\\Models\\densenet121_binary_run5_best.keras']
#
#      Proceed to Fragment 4 — Evaluation & Metrics.

# %%
"""
Fragment 4 — Evaluation & Metrics
===================================
DenseNet121 Binary Mould Classification Pipeline — Mold vs No Mold

Evaluates all 5 trained runs against the test set.
Metrics computed per run and averaged across all runs:
    - Confusion Matrix (2x2)
    - Accuracy
    - Precision
    - Recall (Sensitivity)
    - Specificity
    - F1 Score
    - ROC / AUC (single binary curve)
    - Learning Curves (Accuracy, Loss, AUC, LR)

TEST DATA — loaded fresh here, never seen during training.
"""

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import (
    confusion_matrix,
    roc_curve,
    auc,
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.densenet import preprocess_input

# ── Configuration ─────────────────────────────────────────────────────────────

DATA_DIR   = r"D:\Mold Studies Binary\Mould Binary Classification"
TEST_DIR   = os.path.join(DATA_DIR, "test")
SAVE_DIR   = r"D:\Mold Studies Binary\Models"
PLOT_DIR   = os.path.join(SAVE_DIR, "plots", "densenet121_binary")

os.makedirs(PLOT_DIR, exist_ok=True)

THRESHOLD  = 0.5
TOTAL_RUNS = 5

# ── Step 1: Load Test Generator ───────────────────────────────────────────────

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size = IMG_SIZE,
    batch_size  = BATCH_SIZE,
    class_mode  = "binary",
    shuffle     = False,
)

CLASS_NAMES = list(test_generator.class_indices.keys())
NUM_CLASSES = len(CLASS_NAMES)

print("=" * 60)
print("  Step 1 — Test Generator Ready")
print("=" * 60)
print(f"  Architecture  : DenseNet121 Binary")
print(f"  Preprocessing : preprocess_input (DenseNet121)")
print(f"  Test samples  : {test_generator.samples}")
print(f"  Classes       : {CLASS_NAMES}")
print(f"  Class indices : {test_generator.class_indices}")
print(f"  Threshold     : {THRESHOLD}")
print(f"  Source        : {TEST_DIR}")
print("=" * 60)

# ── Step 2: Helper Functions ──────────────────────────────────────────────────

def compute_metrics_binary(y_true, y_pred, y_prob):
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()

    precision   = tp / (tp + fp + 1e-7)
    recall      = tp / (tp + fn + 1e-7)
    specificity = tn / (tn + fp + 1e-7)
    f1          = 2 * precision * recall / (precision + recall + 1e-7)
    accuracy    = (tp + tn) / (tp + tn + fp + fn + 1e-7)

    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc     = auc(fpr, tpr)

    return {
        "cm"         : cm,
        "tp"         : int(tp),
        "tn"         : int(tn),
        "fp"         : int(fp),
        "fn"         : int(fn),
        "accuracy"   : accuracy,
        "precision"  : precision,
        "recall"     : recall,
        "specificity": specificity,
        "f1"         : f1,
        "fpr"        : fpr,
        "tpr"        : tpr,
        "auc"        : roc_auc,
    }


def plot_confusion_matrix(cm, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(7, 6))
    im = ax.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
    plt.colorbar(im, ax=ax)
    ax.set(
        xticks      = np.arange(NUM_CLASSES),
        yticks      = np.arange(NUM_CLASSES),
        xticklabels = CLASS_NAMES,
        yticklabels = CLASS_NAMES,
        title       = f"DenseNet121 Binary — Confusion Matrix — Run {run_idx}",
        ylabel      = "True Label",
        xlabel      = "Predicted Label",
    )
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right")
    thresh = cm.max() / 2.0
    for i in range(NUM_CLASSES):
        for j in range(NUM_CLASSES):
            ax.text(j, i, format(cm[i, j], "d"),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"densenet121_binary_confusion_matrix_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    plt.close()
    print(f"  Saved: {path}")


def plot_roc_curve(metrics, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(
        metrics["fpr"],
        metrics["tpr"],
        color = "steelblue",
        lw    = 2,
        label = f"ROC Curve (AUC = {metrics['auc']:.4f})"
    )
    ax.plot([0, 1], [0, 1], "k--", label="Random classifier")
    ax.set(
        title  = f"DenseNet121 Binary — ROC Curve — Run {run_idx}",
        xlabel = "False Positive Rate",
        ylabel = "True Positive Rate (Sensitivity)",
        xlim   = [0.0, 1.0],
        ylim   = [0.0, 1.05],
    )
    ax.legend(loc="lower right", fontsize=9)
    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"densenet121_binary_roc_curve_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    plt.close()
    print(f"  Saved: {path}")


def plot_metrics_table(metrics, run_idx, save_dir):
    fig, ax = plt.subplots(figsize=(12, 4))
    ax.axis("off")
    rows = [[
        CLASS_NAMES[1],
        f"{metrics['precision']:.4f}",
        f"{metrics['recall']:.4f}",
        f"{metrics['specificity']:.4f}",
        f"{metrics['f1']:.4f}",
        f"{metrics['auc']:.4f}",
        f"{metrics['tp']}",
        f"{metrics['fp']}",
        f"{metrics['fn']}",
        f"{metrics['tn']}",
    ]]
    col_labels = ["Class", "Precision", "Sensitivity",
                  "Specificity", "F1", "AUC",
                  "TP", "FP", "FN", "TN"]
    table = ax.table(
        cellText  = rows,
        colLabels = col_labels,
        loc       = "center",
        cellLoc   = "center",
    )
    table.auto_set_font_size(False)
    table.set_fontsize(9)
    table.scale(1.2, 2.0)
    for j in range(len(col_labels)):
        table[0, j].set_facecolor("#d0e8ff")
    ax.set_title(
        f"DenseNet121 Binary — Metrics — Run {run_idx}  "
        f"(Accuracy: {metrics['accuracy']:.4f})",
        fontsize=12, pad=20
    )
    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"densenet121_binary_metrics_table_run{run_idx}.png")
    plt.savefig(path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close()
    print(f"  Saved: {path}")


def plot_learning_curves(csv_path, run_idx, save_dir):
    if not os.path.exists(csv_path):
        print(f"  ⚠️  CSV log not found for Run {run_idx}: {csv_path}")
        return

    log = pd.read_csv(csv_path)

    fig, axes = plt.subplots(1, 4, figsize=(22, 5))
    fig.suptitle(
        f"DenseNet121 Binary — Learning Curves — Run {run_idx}",
        fontsize=13
    )

    axes[0].plot(log["epoch"], log["accuracy"],     label="Train Accuracy")
    axes[0].plot(log["epoch"], log["val_accuracy"], label="Val Accuracy")
    axes[0].set(title="Accuracy", xlabel="Epoch", ylabel="Accuracy")
    axes[0].legend()

    axes[1].plot(log["epoch"], log["loss"],     label="Train Loss")
    axes[1].plot(log["epoch"], log["val_loss"], label="Val Loss")
    axes[1].set(title="Loss", xlabel="Epoch", ylabel="Loss")
    axes[1].legend()

    if "auc" in log.columns:
        axes[2].plot(log["epoch"], log["auc"],     label="Train AUC")
        axes[2].plot(log["epoch"], log["val_auc"], label="Val AUC")
        axes[2].set(title="AUC", xlabel="Epoch", ylabel="AUC")
        axes[2].legend()
    else:
        axes[2].text(0.5, 0.5, "AUC not logged",
                     ha="center", va="center",
                     transform=axes[2].transAxes)
        axes[2].set_title("AUC")

    if "lr" in log.columns:
        axes[3].plot(log["epoch"], log["lr"],
                     color="darkorange", label="LR")
        axes[3].set(title="Learning Rate", xlabel="Epoch", ylabel="LR")
        axes[3].set_yscale("log")
        axes[3].legend()
    else:
        axes[3].text(0.5, 0.5, "LR not logged",
                     ha="center", va="center",
                     transform=axes[3].transAxes)
        axes[3].set_title("Learning Rate")

    plt.tight_layout()
    path = os.path.join(save_dir,
                        f"densenet121_binary_learning_curves_run{run_idx}.png")
    plt.savefig(path, dpi=150)
    plt.show()
    plt.close()
    print(f"  Saved: {path}")

# ── Step 3: Evaluate All 5 Runs ───────────────────────────────────────────────

all_metrics = []

for r in all_run_results:
    run_idx  = r["run"]
    ckpt     = os.path.join(SAVE_DIR, r["checkpoint"])
    csv_path = os.path.join(
        SAVE_DIR,
        "densenet121_binary_training_log.csv" if run_idx == 1
        else f"densenet121_binary_run{run_idx}_log.csv"
    )

    print(f"\n{'='*60}")
    print(f"  Evaluating DenseNet121 Binary Run {run_idx} / {TOTAL_RUNS}")
    print(f"  Checkpoint : {ckpt}")
    print(f"{'='*60}")

    run_model = tf.keras.models.load_model(ckpt)

    test_generator.reset()

    y_prob = run_model.predict(
        test_generator,
        steps   = np.ceil(test_generator.samples / BATCH_SIZE),
        verbose = 1,
    ).squeeze()

    y_pred = (y_prob >= THRESHOLD).astype(int)
    y_true = test_generator.classes

    metrics        = compute_metrics_binary(y_true, y_pred, y_prob)
    metrics["run"] = run_idx
    all_metrics.append(metrics)

    print(f"\n  Run {run_idx} Results")
    print(f"    Accuracy     : {metrics['accuracy']:.4f}")
    print(f"    Precision    : {metrics['precision']:.4f}")
    print(f"    Sensitivity  : {metrics['recall']:.4f}")
    print(f"    Specificity  : {metrics['specificity']:.4f}")
    print(f"    F1 Score     : {metrics['f1']:.4f}")
    print(f"    AUC          : {metrics['auc']:.4f}")
    print(f"    TP={metrics['tp']}  TN={metrics['tn']}  "
          f"FP={metrics['fp']}  FN={metrics['fn']}")

    plot_confusion_matrix(metrics["cm"],  run_idx, PLOT_DIR)
    plot_roc_curve(metrics,               run_idx, PLOT_DIR)
    plot_metrics_table(metrics,           run_idx, PLOT_DIR)
    plot_learning_curves(csv_path,        run_idx, PLOT_DIR)

# ── Step 4: Statistical Summary Across All 5 Runs ────────────────────────────

print(f"\n{'='*60}")
print(f"  STATISTICAL SUMMARY — DenseNet121 Binary — All {TOTAL_RUNS} Runs")
print(f"{'='*60}")

metric_keys = {
    "Accuracy"   : "accuracy",
    "Precision"  : "precision",
    "Sensitivity": "recall",
    "Specificity": "specificity",
    "F1 Score"   : "f1",
    "AUC"        : "auc",
}

for label, key in metric_keys.items():
    vals = [m[key] for m in all_metrics]
    print(f"  {label:<14}: "
          f"mean={np.mean(vals):.4f}  "
          f"std={np.std(vals):.4f}  "
          f"min={np.min(vals):.4f}  "
          f"max={np.max(vals):.4f}")

print(f"{'='*60}")

# ── Step 5: Per-Run Summary Table ─────────────────────────────────────────────

col_run  = 6
col_acc  = 12
col_prec = 12
col_sens = 14
col_spec = 14
col_f1   = 10
col_auc  = 10

divider = "=" * (col_run + col_acc + col_prec +
                 col_sens + col_spec + col_f1 + col_auc + 8)
thin    = "─" * (col_run + col_acc + col_prec +
                 col_sens + col_spec + col_f1 + col_auc + 8)

print(f"\n{divider}")
print(f"  PER-RUN RESULTS — DenseNet121 Binary")
print(divider)
print(
    f"  {'Run':<{col_run}}"
    f"{'Accuracy':>{col_acc}}"
    f"{'Precision':>{col_prec}}"
    f"{'Sensitivity':>{col_sens}}"
    f"{'Specificity':>{col_spec}}"
    f"{'F1 Score':>{col_f1}}"
    f"{'AUC':>{col_auc}}"
)
print(thin)

for m in all_metrics:
    print(
        f"  {m['run']:<{col_run}}"
        f"{m['accuracy']:>{col_acc}.4f}"
        f"{m['precision']:>{col_prec}.4f}"
        f"{m['recall']:>{col_sens}.4f}"
        f"{m['specificity']:>{col_spec}.4f}"
        f"{m['f1']:>{col_f1}.4f}"
        f"{m['auc']:>{col_auc}.4f}"
    )

print(thin)

# ── Step 6: Best Run ──────────────────────────────────────────────────────────

best_metrics = max(all_metrics, key=lambda x: x["auc"])

print(f"\n  Best run     : Run {best_metrics['run']} (by AUC)")
print(f"  Accuracy     : {best_metrics['accuracy']:.4f}")
print(f"  Sensitivity  : {best_metrics['recall']:.4f}")
print(f"  Specificity  : {best_metrics['specificity']:.4f}")
print(f"  F1 Score     : {best_metrics['f1']:.4f}")
print(f"  AUC          : {best_metrics['auc']:.4f}")
print(f"  TP={best_metrics['tp']}  TN={best_metrics['tn']}  "
      f"FP={best_metrics['fp']}  FN={best_metrics['fn']}")

# ── Step 7: Expose for comparison ─────────────────────────────────────────────

densenet121_binary_all_metrics     = all_metrics
densenet121_binary_all_run_results = all_run_results

print(f"\n  All plots saved to : {PLOT_DIR}")
print(f"\n  ✓ Fragment 4 complete.")
print(f"     densenet121_binary_all_metrics and")
print(f"     densenet121_binary_all_run_results are ready.\n")
# Out:
# Found 649 images belonging to 2 classes.
# ============================================================
#   Step 1 — Test Generator Ready
# ============================================================
#   Architecture  : DenseNet121 Binary
#   Preprocessing : preprocess_input (DenseNet121)
#   Test samples  : 649
#   Classes       : ['Mold', 'No mold']
#   Class indices : {'Mold': 0, 'No mold': 1}
#   Threshold     : 0.5
#   Source        : D:\Mold Studies Binary\Mould Binary Classification\test
# ============================================================
#
# ============================================================
#   Evaluating DenseNet121 Binary Run 1 / 5
#   Checkpoint : D:\Mold Studies Binary\Models\densenet121_binary_run1_best.keras
# ============================================================
# 21/21 [==============================] - 9s 390ms/step
#
#   Run 1 Results
#     Accuracy     : 0.9738
#     Precision    : 0.9659
#     Sensitivity  : 0.9892
#     Specificity  : 0.9531
#     F1 Score     : 0.9774
#     AUC          : 0.9966
#     TP=368  TN=264  FP=13  FN=4
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_confusion_matrix_run1.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_roc_curve_run1.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_metrics_table_run1.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_learning_curves_run1.png
#
# ============================================================
#   Evaluating DenseNet121 Binary Run 2 / 5
#   Checkpoint : D:\Mold Studies Binary\Models\densenet121_binary_run2_best.keras
# ============================================================
# 21/21 [==============================] - 9s 379ms/step
#
#   Run 2 Results
#     Accuracy     : 0.9599
#     Precision    : 0.9413
#     Sensitivity  : 0.9919
#     Specificity  : 0.9170
#     F1 Score     : 0.9660
#     AUC          : 0.9948
#     TP=369  TN=254  FP=23  FN=3
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_confusion_matrix_run2.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_roc_curve_run2.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_metrics_table_run2.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_learning_curves_run2.png
#
# ============================================================
#   Evaluating DenseNet121 Binary Run 3 / 5
#   Checkpoint : D:\Mold Studies Binary\Models\densenet121_binary_run3_best.keras
# ============================================================
# 21/21 [==============================] - 9s 382ms/step
#
#   Run 3 Results
#     Accuracy     : 0.9707
#     Precision    : 0.9608
#     Sensitivity  : 0.9892
#     Specificity  : 0.9458
#     F1 Score     : 0.9748
#     AUC          : 0.9957
#     TP=368  TN=262  FP=15  FN=4
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_confusion_matrix_run3.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_roc_curve_run3.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_metrics_table_run3.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_learning_curves_run3.png
#
# ============================================================
#   Evaluating DenseNet121 Binary Run 4 / 5
#   Checkpoint : D:\Mold Studies Binary\Models\densenet121_binary_run4_best.keras
# ============================================================
# 21/21 [==============================] - 9s 382ms/step
#
#   Run 4 Results
#     Accuracy     : 0.9707
#     Precision    : 0.9633
#     Sensitivity  : 0.9866
#     Specificity  : 0.9495
#     F1 Score     : 0.9748
#     AUC          : 0.9953
#     TP=367  TN=263  FP=14  FN=5
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_confusion_matrix_run4.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_roc_curve_run4.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_metrics_table_run4.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_learning_curves_run4.png
#
# ============================================================
#   Evaluating DenseNet121 Binary Run 5 / 5
#   Checkpoint : D:\Mold Studies Binary\Models\densenet121_binary_run5_best.keras
# ============================================================
# 21/21 [==============================] - 9s 382ms/step
#
#   Run 5 Results
#     Accuracy     : 0.9569
#     Precision    : 0.9410
#     Sensitivity  : 0.9866
#     Specificity  : 0.9170
#     F1 Score     : 0.9633
#     AUC          : 0.9939
#     TP=367  TN=254  FP=23  FN=5
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_confusion_matrix_run5.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_roc_curve_run5.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_metrics_table_run5.png
#   Saved: D:\Mold Studies Binary\Models\plots\densenet121_binary\densenet121_binary_learning_curves_run5.png
#
# ============================================================
#   STATISTICAL SUMMARY — DenseNet121 Binary — All 5 Runs
# ============================================================
#   Accuracy      : mean=0.9664  std=0.0067  min=0.9569  max=0.9738
#   Precision     : mean=0.9545  std=0.0110  min=0.9410  max=0.9659
#   Sensitivity   : mean=0.9887  std=0.0020  min=0.9866  max=0.9919
#   Specificity   : mean=0.9365  std=0.0161  min=0.9170  max=0.9531
#   F1 Score      : mean=0.9712  std=0.0056  min=0.9633  max=0.9774
#   AUC           : mean=0.9953  std=0.0009  min=0.9939  max=0.9966
# ============================================================
#
# ======================================================================================
#   PER-RUN RESULTS — DenseNet121 Binary
# ======================================================================================
#   Run       Accuracy   Precision   Sensitivity   Specificity  F1 Score       AUC
# ──────────────────────────────────────────────────────────────────────────────────────
#   1           0.9738      0.9659        0.9892        0.9531    0.9774    0.9966
#   2           0.9599      0.9413        0.9919        0.9170    0.9660    0.9948
#   3           0.9707      0.9608        0.9892        0.9458    0.9748    0.9957
#   4           0.9707      0.9633        0.9866        0.9495    0.9748    0.9953
#   5           0.9569      0.9410        0.9866        0.9170    0.9633    0.9939
# ──────────────────────────────────────────────────────────────────────────────────────
#
#   Best run     : Run 1 (by AUC)
#   Accuracy     : 0.9738
#   Sensitivity  : 0.9892
#   Specificity  : 0.9531
#   F1 Score     : 0.9774
#   AUC          : 0.9966
#   TP=368  TN=264  FP=13  FN=4
#
#   All plots saved to : D:\Mold Studies Binary\Models\plots\densenet121_binary
#
#   ✓ Fragment 4 complete.
#      densenet121_binary_all_metrics and
#      densenet121_binary_all_run_results are ready.
